# %%
## convert bees data to format for trex detect-tracking
beedir = '/Users/jacob/Desktop/beesbook2025/example_videos_KN/'
df = pd.read_parquet(beedir+'cam-1_20251003T120750.71761.648Z--20251003T120849.991274.118Z-detections.parquet')
df = df[~(df['detection_type']=='TaggedBee')]
df = df[['frameIdx','xpos','ypos']]
df = df.rename(columns={'frameIdx':'frame', 'xpos':'x', 'ypos':'y'})
df.to_csv(beedir+'frame-x-y.csv',index=False)

# %% [markdown]
# # Behavior embedding + clustering workflow (v2)

# %% [markdown]
# Next improvements and things to add:
# - visualization of behavior labels, along with tracks (bounding box or color, in area that occurs)
# - parameters with inputset, keeping things consistent:  if a name has e.g. v1, multiple different configurations could actually go there (e.g. wavelets with 25 freqs, and with 5 freqs).  is there a more consistent way to keep track of or check this, or is this ok?
# - more input features:  VASSI - what do they use?  can Movement be used for more input features?
# - more behavioral models:  survey of existing ones

# %%
import importlib
from pathlib import Path
from IPython.display import display

import numpy as np
import pandas as pd
import subprocess
import json

from behavior import dataset as ds
import behavior.features as features      # entire features module
import behavior.analysis as analysis      # if you move analysis.py under src, or

importlib.reload(ds)
importlib.reload(features)
importlib.reload(analysis)
# Out:
# <module 'behavior.analysis' from '/Users/jacob/Documents/GitHub/EcodylicScience/behavior/src/behavior/analysis.py'>

# %% [markdown]
# ## Dataset & pipeline configuration

# %%
DATASET_CONFIGS = {
    "calms21": {
        "manifest": "/Volumes/JD-SSD/mice_data/calms21/dataset/dataset.yaml",
        "manifest_params": {
            "name": "calms21",
            "base_dir": "/Volumes/JD-SSD/mice_data/calms21/dataset/",
            "version": "0.1.0",
            "index_format": "group/sequence",
        },
        "groups": ["calms21_task1_train","calms21_task1_test"],
        "media_index": {
            "search_dirs": ["/Volumes/JD-SSD/mice_data/calms21/task1_videos_mp4/"],
            "extensions": (".mp4", ".avi"),
        },
        "tracks_index": {
            "search_dirs": ["/Volumes/JD-SSD/mice_data/calms21/data"],
            "patterns": "calms*.npy",
            "src_format": "calms21_npy",
            "multi_sequences_per_file": True,
            "group_from": "filename",
        },
        "convert_tracks": {
            "params": {"neck_idx": None, "tail_idx": None},
            "overwrite": False,
            "group_from": "filename",
        },
        "convert_labels_kind": "behavior",
        "pose_distance_params": {"n_components": 6, "pose_n": 7},
        "egocentric_params": {"neck_idx": 3, "tail_base_idx": 6},
        "wavelet_params": {
            "fps_default": 30.0,
            "f_min": 0.2,
            "f_max": 5.0,
            "n_freq": 25,
            "wavelet": "cmor1.5-1.0",
            "log_floor": -3.0,
        },
        "inputset_name": "social+ego@v1",
        "tsne_params": {"total_templates": 2000, "perplexity": 50, "n_jobs": 8},
        "kmeans_ks": [50, 100, 150],
        "ward_cuts": [20],
        "label_kind": "behavior",
        "analysis_max_frames": 300_000,
    },
    "esi11-11": {
        "manifest": "/Volumes/JD-SSD/ESI-mice/dataset1/dataset.yaml",
        "manifest_params": {
            "name": "esi11-11",
            "base_dir": "/Volumes/JD-SSD/ESI-mice/dataset1/",
            "version": "0.1.0",
            "index_format": "group/sequence",
        },
        "groups": None,
        "media_index": None,
        "tracks_index": {
            "search_dirs": ["/Volumes/JD-SSD/ESI-mice/data"],
            "patterns": "*.npz",
            "src_format": "trex_npz",
            "multi_sequences_per_file": False,
        },
        "convert_tracks": {
            "merge_per_sequence": True,
        },
        "convert_labels_kind": "behavior",
        "pose_distance_params": {"n_components": 6, "pose_n": 7},
        "egocentric_params": {"neck_idx": 3, "tail_base_idx": 6},
        "wavelet_params": {
            "fps_default": 30.0,
            "f_min": 0.2,
            "f_max": 5.0,
            "n_freq": 25,
            "wavelet": "cmor1.5-1.0",
            "log_floor": -3.0,
        },
        "inputset_name": "social+ego@v1",
        "tsne_params": {"total_templates": 2000, "perplexity": 50, "n_jobs": 8},
        "kmeans_ks": [50, 100],
        "ward_cuts": [20],
        "label_kind": "behavior",
        "analysis_max_frames": 300_000,
    },
}

ACTIVE_DATASET = "calms21"  # calms11, esi11-11
CFG = DATASET_CONFIGS[ACTIVE_DATASET]
GROUP_SCOPE = CFG.get("groups")
LABEL_KIND = CFG.get("label_kind")
print(f"Using dataset '{ACTIVE_DATASET}'")
# Out:
# Using dataset 'calms21'

# %% [markdown]
# ## Load / create dataset manifest

# %%
manifest_path = Path(CFG["manifest"])
if not manifest_path.exists():
    manifest_args = CFG.get("manifest_params")
    if not manifest_args:
        raise FileNotFoundError(f"Manifest {manifest_path} is missing and no creation params were provided.")
    created = ds.new_dataset_manifest(**manifest_args)
    print(f"Created manifest at {created}")

dataset = ds.Dataset(str(manifest_path))
dataset.load()
print(f"Loaded dataset '{dataset.name}' -> {manifest_path}")
print("Group scope:", GROUP_SCOPE or "<all groups>")
# Out:
# Loaded dataset 'calms21' -> /Volumes/JD-SSD/mice_data/calms21/dataset/dataset.yaml
# Group scope: ['calms21_task1_train', 'calms21_task1_test']

# %% [markdown]
# ## Index raw media / tracks (optional)

# %%
if CFG.get("media_index"):
    dataset.index_media(**CFG["media_index"])

if CFG.get("tracks_index"):
    dataset.index_tracks_raw(**CFG["tracks_index"])

if CFG.get("convert_tracks"):
    dataset.convert_all_tracks(**CFG["convert_tracks"])

if CFG.get("convert_labels_kind"):
    dataset.convert_all_labels(kind=CFG["convert_labels_kind"])
# Out:
# [index_media] ffprobe failed for /Volumes/JD-SSD/mice_data/calms21/task1_videos_mp4/test/._mouse071_task1_annotator1.mp4: Command '['ffprobe', '-v', 'error', '-select_streams', 'v:0', '-show_entries', 'stream=width,height,avg_frame_rate,r_frame_rate,codec_name', '-of', 'json', '/Volumes/JD-SSD/mice_data/calms21/task1_videos_mp4/test/._mouse071_task1_annotator1.mp4']' returned non-zero exit status 1.
# [index_media] ffprobe failed for /Volumes/JD-SSD/mice_data/calms21/task1_videos_mp4/test/._mouse074_task1_annotator1.mp4: Command '['ffprobe', '-v', 'error', '-select_streams', 'v:0', '-show_entries', 'stream=width,height,avg_frame_rate,r_frame_rate,codec_name', '-of', 'json', '/Volumes/JD-SSD/mice_data/calms21/task1_videos_mp4/test/._mouse074_task1_annotator1.mp4']' returned non-zero exit status 1.
# [index_media] Wrote 91 entries -> /Volumes/JD-SSD/mice_data/calms21/dataset/media/index.csv
# [index_tracks_raw] 6 -> /Volumes/JD-SSD/mice_data/calms21/dataset/tracks_raw/index.csv
# [convert_all_labels] kind=behavior wrote 292 sequences (overwrite=False).

# %% [markdown]
# ## Pair pose-distance + social wavelet

# %%
pose_params = dict(CFG.get("pose_distance_params", {"n_components": 6, "pose_n": 7}))
feat_pose = features.PairPoseDistancePCA(params=pose_params)
pose_run = dataset.run_feature(feat_pose, groups=GROUP_SCOPE)
print("pair-posedistance-pca run:", pose_run)

wavelet_params = dict(CFG.get("wavelet_params", {}))
feat_wave_social = features.PairWavelet(params=wavelet_params)
social_wave_run = dataset.run_feature(
    feat_wave_social,
    input_kind="feature",
    input_feature="pair-posedistance-pca",
    input_run_id=pose_run,
    groups=GROUP_SCOPE,
)
print("pair-wavelet (social) run:", social_wave_run)
# Out:
# [feature:pair-posedistance-pca] completed run_id=0.1-d2cdb45ffd -> /Volumes/JD-SSD/mice_data/calms21/dataset/features/pair-posedistance-pca/0.1-d2cdb45ffd
# pair-posedistance-pca run: 0.1-d2cdb45ffd
# [feature:pair-wavelet__from__pair-posedistance-pca] completed run_id=0.1-88d79630c2 -> /Volumes/JD-SSD/mice_data/calms21/dataset/features/pair-wavelet__from__pair-posedistance-pca/0.1-88d79630c2
# pair-wavelet (social) run: 0.1-88d79630c2

# %% [markdown]
# ## Pair egocentric + ego wavelet

# %%
egocentric_params = dict(CFG.get("egocentric_params", {"neck_idx": 3, "tail_base_idx": 6}))
feat_ego = features.PairEgocentricFeatures(params=egocentric_params)
ego_run = dataset.run_feature(feat_ego, groups=GROUP_SCOPE)
print("pair-egocentric run:", ego_run)

wavelet_params = dict(CFG.get("wavelet_params", {}))
feat_wave_ego = features.PairWavelet(params=wavelet_params)
ego_wave_run = dataset.run_feature(
    feat_wave_ego,
    input_kind="feature",
    input_feature="pair-egocentric",
    input_run_id=ego_run,
    groups=GROUP_SCOPE,
)
print("pair-wavelet (ego) run:", ego_wave_run)
# Out:
# [feature:pair-egocentric] completed run_id=0.1-5f7ddf53ba -> /Volumes/JD-SSD/mice_data/calms21/dataset/features/pair-egocentric/0.1-5f7ddf53ba
# pair-egocentric run: 0.1-5f7ddf53ba
# [feature:pair-wavelet__from__pair-egocentric] completed run_id=0.1-88d79630c2 -> /Volumes/JD-SSD/mice_data/calms21/dataset/features/pair-wavelet__from__pair-egocentric/0.1-88d79630c2
# pair-wavelet (ego) run: 0.1-88d79630c2

# %% [markdown]
# ## Inputset for social + ego features

# %%
INPUTSET_NAME = 'social+ego'
inputset_inputs = [
        {
            "feature": "pair-wavelet__from__pair-posedistance-pca",
            "run_id": social_wave_run,
            "pattern": "*.parquet",
            "load": {"kind": "parquet", "transpose": False},
        },
        {
            "feature": "pair-wavelet__from__pair-egocentric",
            "run_id": ego_wave_run,
            "pattern": "*.parquet",
            "load": {"kind": "parquet", "transpose": False},
        },
    ]
features.save_inputset(dataset, INPUTSET_NAME, inputset_inputs, overwrite=True)
# Out:
# PosixPath('/Volumes/JD-SSD/mice_data/calms21/dataset/inputsets/social%2Bego.json')

# %% [markdown]
# ## Global t-SNE embedding

# %%
tsne_params = dict(CFG.get("tsne_params", {}))
tsne_params["inputset"] = INPUTSET_NAME
feat_tsne = features.GlobalTSNE(params=tsne_params)
tsne_run = dataset.run_feature(
    feat_tsne,
    input_kind="inputset",
    input_feature=INPUTSET_NAME,
    groups=GROUP_SCOPE,
)
tsne_feature = f"{feat_tsne.name}__from__{INPUTSET_NAME}"
print("tsne feature:", tsne_feature)
# Out:
# [feature:global-tsne__from__social+ego@v1] completed run_id=0.2-460bef52ce -> /Volumes/JD-SSD/ESI-mice/dataset1/features/global-tsne__from__social+ego@v1/0.2-460bef52ce
# tsne feature: global-tsne__from__social+ego@v1

# %% [markdown]
# ## Global K-Means sweeps

# %%
tsne_artifact_spec = {
    "feature": tsne_feature,
    "run_id": None,
    "pattern": "global_templates_features.npz",
    "load": {"kind": "npz", "key": "templates"},
}
tsne_scaler_spec = {
    "feature": tsne_feature,
    "run_id": None,
    "pattern": "global_opentsne_embedding.joblib",
    "key": "scaler",
}

kmeans_runs = []
for k in CFG.get("kmeans_ks", [150]):
    feat_kmeans = features.GlobalKMeansClustering(params={
        "k": int(k),
        "artifact": dict(tsne_artifact_spec),
        "label_artifact_points": True,
        "assign": {
            "scaler": dict(tsne_scaler_spec),
            "inputset": INPUTSET_NAME,
        },
    })
    k_run = dataset.run_feature(
        feat_kmeans,
        input_kind="feature",
        input_feature=tsne_feature,
        groups=GROUP_SCOPE,
    )
    kmeans_runs.append({"k": int(k), "run_id": k_run})
    print(f"k-means k={k} -> {k_run}")

kmeans_feature = f"global-kmeans__from__{tsne_feature}"
# Out:
# [feature:global-kmeans__from__global-tsne__from__social+ego@v1] completed run_id=0.3-8cdda94ab0 -> /Volumes/JD-SSD/ESI-mice/dataset1/features/global-kmeans__from__global-tsne__from__social+ego@v1/0.3-8cdda94ab0
# k-means k=50 -> 0.3-8cdda94ab0
# [feature:global-kmeans__from__global-tsne__from__social+ego@v1] completed run_id=0.3-f1ab17d641 -> /Volumes/JD-SSD/ESI-mice/dataset1/features/global-kmeans__from__global-tsne__from__social+ego@v1/0.3-f1ab17d641
# k-means k=100 -> 0.3-f1ab17d641

# %% [markdown]
# ## Ward clustering + per-frame assignments

# %%
CFG.get("ward_cuts")
# Out:
# [20]

# %%
feat_ward = features.GlobalWardClustering(params={
    "artifact": dict(tsne_artifact_spec),
})
ward_run = dataset.run_feature(
    feat_ward,
    input_kind="feature",
    input_feature=tsne_feature,
    groups=GROUP_SCOPE,
)
print("ward run:", ward_run)

ward_feature = f"global-ward__from__{tsne_feature}"
ward_assign_runs = []
for cut in [20, 40, 60, 80]:
    assign = features.WardAssignClustering(params={
        "ward_model": {
            "feature": ward_feature,
            "run_id": ward_run,
            "pattern": "model.joblib",
        },
        "artifact": dict(tsne_artifact_spec),
        "scaler": dict(tsne_scaler_spec),
        "inputset": INPUTSET_NAME,
        "n_clusters": int(cut),
        "recalc": False,
    })
    assign_run = dataset.run_feature(
        assign,
        input_kind="inputset",
        input_feature=INPUTSET_NAME,
        groups=GROUP_SCOPE,
    )
    ward_assign_runs.append({"n_clusters": int(cut), "run_id": assign_run})
    print(f"ward-assign k={cut} -> {assign_run}")

ward_assign_feature = f"ward-assign__from__{ward_feature}"
last_ward_assign_run = ward_assign_runs[-1]["run_id"] if ward_assign_runs else None
# Out:
# [feature:global-ward__from__global-tsne__from__social+ego@v1] completed run_id=0.1-a3746fba33 -> /Volumes/JD-SSD/ESI-mice/dataset1/features/global-ward__from__global-tsne__from__social+ego@v1/0.1-a3746fba33
# ward run: 0.1-a3746fba33
# [feature:ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1] completed run_id=0.1-f34589737b -> /Volumes/JD-SSD/ESI-mice/dataset1/features/ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1/0.1-f34589737b
# ward-assign k=20 -> 0.1-f34589737b
# [feature:ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1] completed run_id=0.1-a934c82a2f -> /Volumes/JD-SSD/ESI-mice/dataset1/features/ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1/0.1-a934c82a2f
# ward-assign k=40 -> 0.1-a934c82a2f
# [feature:ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1] completed run_id=0.1-59fb4dd5c6 -> /Volumes/JD-SSD/ESI-mice/dataset1/features/ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1/0.1-59fb4dd5c6
# ward-assign k=60 -> 0.1-59fb4dd5c6
# [feature:ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1] completed run_id=0.1-a22c8ea69f -> /Volumes/JD-SSD/ESI-mice/dataset1/features/ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1/0.1-a22c8ea69f
# ward-assign k=80 -> 0.1-a22c8ea69f

# %% [markdown]
# ## Cached run summaries

# %%
try:
    kmeans_summary = analysis.list_feature_runs(dataset, kmeans_feature)
except FileNotFoundError:
    kmeans_summary = pd.DataFrame()

try:
    ward_summary = analysis.list_feature_runs(dataset, ward_assign_feature)
except FileNotFoundError:
    ward_summary = pd.DataFrame()

if not kmeans_summary.empty:
    display(kmeans_summary[[c for c in ["run_id", "k", "finished_at", "model_path"] if c in kmeans_summary.columns]])
else:
    print("No k-means runs discovered yet.")

if not ward_summary.empty:
    display(ward_summary[[c for c in ["run_id", "n_clusters", "finished_at", "model_path"] if c in ward_summary.columns]])
else:
    print("No ward-assign runs discovered yet.")
# Out:
#            run_id    k                       finished_at  \
# 0  0.3-f1ab17d641  100  2025-11-13T10:08:41.899660+00:00
# 1  0.3-8cdda94ab0   50  2025-11-13T10:08:41.245462+00:00
#
#                                           model_path
# 0  /Volumes/JD-SSD/ESI-mice/dataset1/features/glo...
# 1  /Volumes/JD-SSD/ESI-mice/dataset1/features/glo...
#            run_id  n_clusters                       finished_at  \
# 0  0.1-a22c8ea69f          80  2025-11-13T10:09:47.927784+00:00
# 1  0.1-59fb4dd5c6          60  2025-11-13T10:09:47.619304+00:00
# 2  0.1-a934c82a2f          40  2025-11-13T10:09:47.310784+00:00
# 3  0.1-f34589737b          20  2025-11-13T10:08:54.193278+00:00
#
#                                           model_path
# 0  /Volumes/JD-SSD/ESI-mice/dataset1/features/war...
# 1  /Volumes/JD-SSD/ESI-mice/dataset1/features/war...
# 2  /Volumes/JD-SSD/ESI-mice/dataset1/features/war...
# 3  /Volumes/JD-SSD/ESI-mice/dataset1/features/war...

# %% [markdown]
# ## Quantitative cluster ⇄ label agreement

# %%
if not LABEL_KIND:
    print("No label_kind configured; skipping agreement metrics.")
else:
    kmeans_metrics = []
    if 'kmeans_summary' in globals() and not kmeans_summary.empty:
        for _, row in kmeans_summary.iterrows():
            metrics = analysis.compute_cluster_label_agreement(
                dataset,
                cluster_feature=kmeans_feature,
                cluster_run_id=row["run_id"],
                label_kind=LABEL_KIND,
                max_frames=CFG.get("analysis_max_frames"),
                include_per_sequence=False,
            )
            kmeans_metrics.append({
                "k": row.get("k"),
                "run_id": row["run_id"],
                "ARI": metrics["metrics"]["ARI"],
                "AMI": metrics["metrics"]["AMI"],
                "purity": metrics["metrics"]["purity"],
                "hungarian_accuracy": metrics["metrics"]["hungarian_accuracy"],
            })
        if kmeans_metrics:
            display(pd.DataFrame(kmeans_metrics).sort_values(by="ARI", ascending=False))

    ward_metrics = []
    if 'ward_summary' in globals() and not ward_summary.empty:
        for _, row in ward_summary.iterrows():
            metrics = analysis.compute_cluster_label_agreement(
                dataset,
                cluster_feature=ward_assign_feature,
                cluster_run_id=row["run_id"],
                label_kind=LABEL_KIND,
                max_frames=CFG.get("analysis_max_frames"),
                include_per_sequence=False,
            )
            ward_metrics.append({
                "n_clusters": row.get("n_clusters"),
                "run_id": row["run_id"],
                "ARI": metrics["metrics"]["ARI"],
                "AMI": metrics["metrics"]["AMI"],
                "purity": metrics["metrics"]["purity"],
                "hungarian_accuracy": metrics["metrics"]["hungarian_accuracy"],
            })
        if ward_metrics:
            display(pd.DataFrame(ward_metrics).sort_values(by="ARI", ascending=False))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[20], line 7
#       5 if 'kmeans_summary' in globals() and not kmeans_summary.empty:
#       6     for _, row in kmeans_summary.iterrows():
# ----> 7         metrics = analysis.compute_cluster_label_agreement(
#       8             dataset,
#       9             cluster_feature=kmeans_feature,
#      10             cluster_run_id=row["run_id"],
#      11             label_kind=LABEL_KIND,
#      12             max_frames=CFG.get("analysis_max_frames"),
#      13             include_per_sequence=False,
#      14         )
#      15         kmeans_metrics.append({
#      16             "k": row.get("k"),
#      17             "run_id": row["run_id"],
#    (...)
#      21             "hungarian_accuracy": metrics["metrics"]["hungarian_accuracy"],
#      22         })
#      23     if kmeans_metrics:
#
# File ~/Documents/GitHub/EcodylicScience/behavior/analysis.py:135, in compute_cluster_label_agreement(ds, cluster_feature, cluster_run_id, label_kind, cluster_column, sequences, max_frames, rng_seed, include_per_sequence)
#     109 """
#     110 Align Ward/K-Means (or any per-frame clustering feature) with ground-truth labels
#     111 and report agreement metrics.
#    (...)
#     132     If True, returns per-sequence metrics (with confusion matrices stripped).
#     133 """
#     134 cluster_map, resolved_run_id, run_root = _load_feature_sequence_index(ds, cluster_feature, cluster_run_id)
# --> 135 label_map = _load_label_sequence_index(ds, label_kind)
#     136 if not cluster_map:
#     137     raise RuntimeError(f"No sequences found for feature '{cluster_feature}' (run_id={cluster_run_id}).")
#
# File ~/Documents/GitHub/EcodylicScience/behavior/analysis.py:295, in _load_label_sequence_index(ds, kind)
#     293 idx_path = labels_root / "index.csv"
#     294 if not idx_path.exists():
# --> 295     raise FileNotFoundError(f"Labels index missing: {idx_path}")
#     296 df = pd.read_csv(idx_path)
#     297 mapping: Dict[str, SequenceBundle] = {}
#
# FileNotFoundError: Labels index missing: /Volumes/JD-SSD/ESI-mice/dataset1/labels/behavior/index.csv

# %% [markdown]
# ## Visualization helper

# %%
viz_labels_feature = ward_assign_feature  # swap to k-means feature if desired
viz_labels_run = last_ward_assign_run

viz = features.VizGlobalColored(params={
    "coords": {
        "feature": tsne_feature,
        "run_id": tsne_run,
        "pattern": "global_tsne_coords_seq=*.npz",
        "load": {"kind": "npz", "key": "Y"},
    },
    "labels": {
        "feature": viz_labels_feature,
        "run_id": viz_labels_run,
        "pattern": "*.parquet",
        "load": {"kind": "parquet", "numeric_only": False, "columns": ["cluster"]},
    },
    "coord_key_regex": r"seq=(.+?)(?:_persp=.*)?$",
    "label_key_regex": None,
    "title": "Global t-SNE colored by clusters",
})

viz_run = dataset.run_feature(viz, input_kind="feature", input_feature=tsne_feature)
print("viz run:", viz_run)
# Out:
# [feature:viz-global-colored__from__global-tsne__from__social+ego@v1] completed run_id=0.1-8bc5d72ba4 -> /Volumes/JD-SSD/ESI-mice/dataset1/features/viz-global-colored__from__global-tsne__from__social+ego@v1/0.1-8bc5d72ba4
# viz run: 0.1-8bc5d72ba4

# %% [markdown]
# # ESI dataset -  use tsne embedding from CALMS

# %%
feat_tsne_map = features.GlobalTSNE(params={
    "inputset": "social+ego@v1",
    "map_existing_inputs": True,
    "reuse_embedding": {
        "feature": "calms-global-tsne",
        "run_id": None,  # latest CALMS run
        "pattern": "global_opentsne_embedding.joblib",
    },
    # optional if you want templates copied over:
    # "artifact": {
    #     "feature": "calms-global-tsne",
    #     "pattern": "global_templates_features.npz",
    #     "load": {"kind": "npz", "key": "templates"},
    # },
})
esi_tsne_run = dataset.run_feature(
    feat_tsne_map,
    input_kind="inputset",
    input_feature="social+ego@v1",
)
# Out:
# [feature:global-tsne__from__social+ego@v1] completed run_id=0.2-a613257177 -> /Volumes/JD-SSD/ESI-mice/dataset1/features/global-tsne__from__social+ego@v1/0.2-a613257177

# %%
## assign cluster labels
ward_assign = features.WardAssignClustering(params={
    "ward_model": {
        "feature": "global-ward__from__global-tsne",
        "run_id": None,
        "pattern": "model.joblib",
    },
    "artifact": {  # still uses the TSNE templates/scaler space
        "feature": "global-tsne",
        "run_id": None,
        "pattern": "global_templates_features.npz",
        "load": {"kind": "npz", "key": "templates"},
    },
    "scaler": {
        "feature": "global-tsne",
        "run_id": None,
        "pattern": "global_opentsne_embedding.joblib",
        "key": "scaler",
    },
    "inputset": "social+ego@v1",   # reuse the preset you saved earlier
    "n_clusters": 10,
    "recalc": False,
})

ward_assign_run = dataset.run_feature(
    ward_assign,
    input_kind="inputset",
    input_feature="social+ego@v1",   # tells the runner which inputset drives scope/streaming
)
print("ward-assign run:", ward_assign_run)
# Out:
# [feature:ward-assign__from__global-ward__from__global-tsne] completed run_id=0.1-2800a6d0c4 -> /Volumes/JD-SSD/ESI-mice/dataset1/features/ward-assign__from__global-ward__from__global-tsne/0.1-2800a6d0c4
# ward-assign run: 0.1-2800a6d0c4

# %%
esi_globaltsne = "0.2-419d3315f8"
esi_calms_globaltsne = '0.2-a613257177'
coords_run = esi_calms_globaltsne

viz = features.VizGlobalColored(params={
    "coords": {
        "feature": "global-tsne__from__social+ego@v1",
        "run_id": coords_run,
        "pattern": "global_tsne_coords_seq=*.npz",
        "load": {"kind": "npz", "key": "Y"},
    },
    "labels": {
        "feature": "ward-assign__from__global-ward__from__global-tsne",
        "run_id": None,
        "pattern": "*.parquet",
        "load": {"kind": "parquet", "numeric_only": False, "columns": ["cluster"]},
    },
    "coord_key_regex": r"seq=(.+)",
    "label_key_regex": r"seq=(.+)",
    "title": "Global t-SNE colored by Ward",
})

viz_run_id = dataset.run_feature(viz, input_kind="feature", input_feature="global-tsne")
print("viz run:", viz_run_id)
# Out:
# [feature:viz-global-colored__from__global-tsne] completed run_id=0.1-bf5d3f2654 -> /Volumes/JD-SSD/ESI-mice/dataset1/features/viz-global-colored__from__global-tsne/0.1-bf5d3f2654
# viz run: 0.1-bf5d3f2654

# %% [markdown]
# # Model Training

# %%
remote_cfg_03 = {
    "local_root": "/Volumes/JD-SSD/mice_data/calms21/dataset",
    "remote_root": "/home/jdavidson/mice_data/calms21/dataset",
    "root_map": {
        "/Volumes/JD-SSD/mice_data": "/home/jdavidson/mice_data"
    },
    "ssh_host": "jdavidson@100.77.35.28",
    "jupyter_url": "http://100.77.35.28:8888/lab?token=974853ff7c859db1b24198731bcb288c57bdbe9accbedcee",  # optional
    "python_cmd": "/home/jdavidson/miniforge3/envs/ecodylic/bin/python",
    "rsync_opts": ["--exclude", "media/", "--exclude", "*.mp4", "--exclude", "*.py", "--exclude", "*.ipynb", "--exclude", "features/ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1"],
    "rsync_progress": False
}

remote_cfg = remote_cfg_03

# %% [markdown]
# ## TemporalStacking of features for model input

# %%
stack_params = {
    "inputset": "social+ego",
    "half": 2,
    "skip": 1,
    "use_temporal_stack": True,
    "sigma_stack": 1,
    "add_pool": False,
    "pool_stats": ("mean",),
    "sigma_pool": 1,
    "stack_chunk_size": 1000,   # optional
}

# %%
importlib.reload(features)

# sync the package files needed
import subprocess
# cmd = "rsync * jdavidson@kn-cgpu03:/home/jdavidson/mice_data/calms21/dataset/."

cmd = "rsync -av \
    --exclude='*.pyc' --exclude='__pycache__' \
    /Users/jacob/Documents/GitHub/EcodylicScience/behavior \
    " + remote_cfg['ssh_host'] + ":/home/jdavidson/"
subprocess.run(cmd, shell=True, check=True)
# Out:
# Transfer starting: 510 files
# behavior/
# behavior/.DS_Store
# behavior/behavior-v3.ipynb
# behavior/.git/
# behavior/.git/.DS_Store
# behavior/src/
# behavior/src/.DS_Store
#
# sent 58955 bytes  received 6036 bytes  254766 bytes/sec
# total size is 53055427  speedup is 816.35
# CompletedProcess(args="rsync -av     --exclude='*.pyc' --exclude='__pycache__'     /Users/jacob/Documents/GitHub/EcodylicScience/behavior     jdavidson@100.77.35.28:/home/jdavidson/", returncode=0)

# %% [markdown]
# ### remote running

# %%
# Kick off a detached feature run
detached = True

job = dataset.run_feature_remote(
    "features.TemporalStackingFeature",
    params=stack_params,
    remote_cfg=remote_cfg,
    groups=GROUP_SCOPE,
    input_kind="inputset",
    input_feature="social+ego@v1",
    parallel_workers=10,  # only makes speed gains if the calculation is complicated; does not speed up write-limited things
    remote_only=False,
    detached=detached,
)
print("submitted job:", job["job_id"])

if detached:
    status = dataset.remote_job_status(remote_cfg, job["job_id"])
    print(status)  # includes status, run_id when finished, log path, etc.
# Out:
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# [remote-sync:to] running: rsync -az --delete --exclude .remote_jobs/** --exclude features/temporal-stack__from__social+ego@v1/0.1-5a2b368452/** --exclude features/temporal-stack__from__social+ego@v1/0.1-a04056b851/** --exclude features/temporal-stack__from__social+ego@v1/0.1-82afbc8a7e/** --exclude features/temporal-stack__from__social+ego@v1/0.1-3e9024a46d/** --exclude media/ --exclude *.mp4 --exclude *.py --exclude *.ipynb --exclude features/ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1 /Volumes/JD-SSD/mice_data/calms21/dataset/ jdavidson@100.77.35.28:/home/jdavidson/mice_data/calms21/dataset/
# [remote-run] executing on jdavidson@100.77.35.28
# submitted job: run_feature-20251117-080414-635124
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# {'job_type': 'run_feature', 'feature_class': 'features.TemporalStackingFeature', 'storage_feature': 'temporal-stack__from__social+ego@v1', 'remote_only': True, 'job_id': 'run_feature-20251117-080414-635124', 'job_kind': 'run_feature', 'status': 'running', 'submitted_at': '2025-11-17T07:04:14.635151+00:00', 'log_path': '/home/jdavidson/mice_data/calms21/dataset/.remote_jobs/logs/run_feature-20251117-080414-635124.log', 'script_path': '/home/jdavidson/mice_data/calms21/dataset/.remote_jobs/scripts/run_feature-20251117-080414-635124.py', 'pid': 1175232, 'started_at': '2025-11-17T07:04:14.673507+00:00', 'updated_at': '2025-11-17T07:04:14.673585+00:00'}

# %% [markdown]
# ### list all jobs

# %%
jobs = dataset.list_remote_jobs(remote_cfg, job_kind="run_feature")
for j in jobs:
    print(j["job_id"], j["status"])
# Out:
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# run_feature-20251114-153549-419284 failed
# run_feature-20251114-170525-192979 finished
# run_feature-20251117-080414-635124 finished

# %% [markdown]
# ### stop job

# %%
# later, to stop it
for j in jobs:
    if j['status']=='running':
        job_id = j["job_id"]
        stopped = dataset.remote_job_stop(remote_cfg, job_id)
        print(job_id, stopped["status"])  # "cancelled"
        
        # confirm status
        dataset.remote_job_status(remote_cfg, job_id)
# Out:
# [remote-run] executing on jdavidson@100.73.91.123
# [remote-run] executing on jdavidson@100.73.91.123
# [remote-run] executing on jdavidson@100.73.91.123
# run_feature-20251114-131813-161247 cancelled
# [remote-run] executing on jdavidson@100.73.91.123
# [remote-run] executing on jdavidson@100.73.91.123
# [remote-run] executing on jdavidson@100.73.91.123
# [remote-run] executing on jdavidson@100.73.91.123
# run_feature-20251114-131928-988632 cancelled
# [remote-run] executing on jdavidson@100.73.91.123

# %% [markdown]
# ### Local running

# %%
temporal_feat = features.TemporalStackingFeature(stack_params)

run_id = dataset.run_feature(
    temporal_feat,
    groups=GROUP_SCOPE,
    input_kind="inputset",
    input_feature="social+ego",
    parallel_workers=3, 
)
print("local run:", run_id)
# Out:
# [feature:temporal-stack__from__social+ego] completed run_id=0.1-fad89abffc -> /Volumes/JD-SSD/mice_data/calms21/dataset/features/temporal-stack__from__social+ego/0.1-fad89abffc
# local run: 0.1-fad89abffc

# %% [markdown]
# ## Set up model and fit - temporal stack input

# %%
import subprocess
cmd = "rsync * jdavidson@kn-cgpu03:/home/jdavidson/mice_data/calms21/dataset/."
subprocess.run(cmd, shell=True, check=True)

dataset.sync_to_remote(remote_cfg)
# Out:
# skipping directory __pycache__
# skipping directory dev-prev
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# [remote-sync:to] running: rsync -az --delete --exclude .remote_jobs/** --exclude features/temporal-stack__from__social+ego@v1/0.1-3e9024a46d/** --exclude features/temporal-stack__from__social+ego@v1/0.1-7ffa9af34f/** --exclude media/ --exclude *.mp4 --exclude *.py --exclude *.ipynb --exclude features/ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1 /Volumes/JD-SSD/mice_data/calms21/dataset/ jdavidson@100.77.35.28:/home/jdavidson/mice_data/calms21/dataset/
# cannot delete non-empty directory: .remote_jobs

# %%
### sync remote index files so can see them

# 1. Inspect available temporal-stack runs
feature_name = "temporal-stack__from__social+ego"
dataset.sync_from_remote(
    remote_cfg,
    include=[f"features/{feature_name}"],
    # include=[f"features/{feature_name}/index.csv"],
    # exclude=["*parquet"],   # everything else stays remote
)
# Out:
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# [remote-sync:from] running: rsync -az --delete --include features/temporal-stack__from__social+ego@v1 --exclude features/temporal-stack__from__social+ego@v1/0.1-5a2b368452/** --exclude features/temporal-stack__from__social+ego@v1/0.1-a04056b851/** --exclude features/temporal-stack__from__social+ego@v1/0.1-82afbc8a7e/** --exclude features/temporal-stack__from__social+ego@v1/0.1-3e9024a46d/** --exclude features/temporal-stack__from__social+ego@v1/0.1-7ffa9af34f/** --exclude media/ --exclude *.mp4 --exclude *.py --exclude *.ipynb --exclude features/ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1 jdavidson@100.77.35.28:/home/jdavidson/mice_data/calms21/dataset/ /Volumes/JD-SSD/mice_data/calms21/dataset/

# %%
feature_name = "temporal-stack__from__social+ego"
idx_path = dataset.get_root("features") / feature_name / "index.csv"
df_idx = pd.read_csv(idx_path)
df_idx = df_idx.sort_values("finished_at")
summary = (
    df_idx.groupby(["run_id"])
    .agg(n_rows=("sequence", "count"))
    .reset_index()
)
print(summary)  # each run_id + count of sequence files
# Out:
#            run_id  n_rows
# 0  0.1-fad89abffc      89

# %%
# pick the run_id you want (replace with one from the table)
stack_run_id = "0.1-fad89abffc"

# 2. Save an inputset pointing to that run
inputs = [
    {
        "feature": feature_name,
        "run_id": stack_run_id,
        "pattern": "*.parquet",
        "load": {
            "kind": "parquet",
            "drop_columns": ["frame", "group", "sequence"],
            "numeric_only": True,
        },
        "name": "temporal_stack",
    },
]
inputset_name = f"temporal-stack-{stack_run_id}"
features.save_inputset(dataset, inputset_name, inputs, overwrite=True)
print("Inputset saved:", inputset_name)

train_seqs = [s for s in dataset.list_sequences() if "task1/train" in s]
test_seqs = [s for s in dataset.list_sequences() if "task1/test" in s]
# train_seqs = train_seqs[0:10]
# test_seqs = test_seqs[0:2]

# 3. Build model config that uses the new inputset
behavior_cfg = {
    "inputset": inputset_name,
    "label_kind": "behavior",
    "train_sequences": train_seqs,
    "test_sequences": test_seqs,
    "random_state": 43,
    "classes": [0, 1, 2, 3],
    "label_map": {0: "attack", 1: "investigation", 2: "mount", 3: "other"},
    "standardize": True,
    "use_undersample": True,
    "undersample_ratio": 3.0,
    "use_smote": False,
    "xgb_params_preset": "xgb_v0",
    "use_external_memory": False  
}
cfg_path = dataset.get_root("models") / "configs" / f"temporal_stack_{stack_run_id}.json"
cfg_path.parent.mkdir(parents=True, exist_ok=True)
cfg_path.write_text(json.dumps(behavior_cfg, indent=2))
print("Config saved:", cfg_path)

# manual resync
dataset.sync_to_remote(remote_cfg)

# sync the package files needed
import subprocess
cmd = "rsync * jdavidson@kn-cgpu03:/home/jdavidson/mice_data/calms21/dataset/."
subprocess.run(cmd, shell=True, check=True)
remote_cfg["delete"] = False # so that the package files are not removed

# 4. Train remotely with the temporal-stack inputset
run = dataset.train_model_remote(
    model_class="models_behavior.BehaviorXGBoostModel",
    config=cfg_path,
    remote_cfg=remote_cfg,
    sync_before=False,
    sync_after=False,
    detached=False,          # optional: run in background
)
print("Remote training submitted:", run)
# Out:
# Inputset saved: temporal-stack-0.1-fad89abffc
# Config saved: /Volumes/JD-SSD/mice_data/calms21/dataset/models/configs/temporal_stack_0.1-fad89abffc.json
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# [remote-sync:to] running: rsync -az --delete --exclude .remote_jobs/** --exclude features/temporal-stack__from__social+ego@v1/0.1-3e9024a46d/** --exclude features/temporal-stack__from__social+ego@v1/0.1-7ffa9af34f/** --exclude media/ --exclude *.mp4 --exclude *.py --exclude *.ipynb --exclude features/ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1 /Volumes/JD-SSD/mice_data/calms21/dataset/ jdavidson@100.77.35.28:/home/jdavidson/mice_data/calms21/dataset/
# cannot delete non-empty directory: .remote_jobs
# skipping directory __pycache__
# skipping directory dev-prev
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# [model:behavior-xgb] completed run_id=0.1-04799ef479 -> /home/jdavidson/mice_data/calms21/dataset/models/behavior-xgb/0.1-04799ef479
# REMOTE_RUN_ID=0.1-04799ef479
#
# Remote training submitted: 0.1-04799ef479
# /home/jdavidson/miniforge3/envs/ecodylic/lib/python3.11/site-packages/xgboost/core.py:774: UserWarning: [07:10:06] WARNING: /workspace/src/common/error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)

# %%
# # single status
# print(dataset.remote_job_status(remote_cfg, job_id))

# list all training jobs
jobs = dataset.list_remote_jobs(remote_cfg, job_kind="train_model")
for j in jobs:
    print(j["job_id"], j["status"], 'run_id:', j['run_id'] if 'run_id' in j.keys() else None)

# # cancel if still running
# for j in jobs:
#     if j.get("status") == "running":
#         stopped = dataset.remote_job_stop(remote_cfg, j["job_id"])
#         print("stopped", j["job_id"], stopped.get("status"))
# Out:
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# train_model-20251114-172906-212627 failed run_id: None
# train_model-20251114-173150-096747 failed run_id: None
# train_model-20251117-082008-025308 failed run_id: None
# train_model-20251117-082204-564247 failed run_id: None
# train_model-20251119-163040-854323 failed run_id: None

# %%
dataset.sync_from_remote(remote_cfg)

run_id = run            # need to find a better way to retrieve this, I just looked in the directory
run_root = dataset.get_root("models") / "behavior-xgb" / run_id

# 1) Quick per-class metrics table
summary_df = pd.read_csv(run_root / "summary.csv")
display(summary_df.sort_values("behavior"))

# 2) Full reports + confusion matrices
with open(run_root / "reports.json") as f:
    reports = json.load(f)

conf_mats = {
    int(cls): np.array(payload["confusion_matrix"])
    for cls, payload in reports.items()
}

# for cls, cm in conf_mats.items():
#     print(f"\nBehavior {cls} confusion matrix (rows=true, cols=pred):")
#     display(pd.DataFrame(cm, index=["neg", "pos"], columns=["neg", "pos"]))

macro_f1 = np.mean([
    payload["report"][str(cls)]["f1-score"]
    for cls, payload in reports.items()
])
print(f"Macro F1: {macro_f1:.3f}")
# Out:
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# [remote-sync:from] running: rsync -az --exclude features/temporal-stack__from__social+ego@v1/0.1-3e9024a46d/** --exclude features/temporal-stack__from__social+ego@v1/0.1-7ffa9af34f/** --exclude media/ --exclude *.mp4 --exclude *.py --exclude *.ipynb --exclude features/ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1 jdavidson@100.77.35.28:/home/jdavidson/mice_data/calms21/dataset/ /Volumes/JD-SSD/mice_data/calms21/dataset/
#    behavior  precision    recall        f1   support  average_precision
# 0         0   0.746720  0.729929  0.738229   12630.0           0.783084
# 1         1   0.682338  0.665557  0.673843   61275.0           0.721143
# 2         2   0.926887  0.755118  0.832232   31848.0           0.920556
# 3         3   0.916371  0.911483  0.913920  156354.0           0.974722
# Macro F1: 0.790

# %% [markdown]
# ## set up model and fit - single frame input-based

# %%
import json
from pathlib import Path
import models_behavior
import importlib
importlib.reload(models_behavior)
 
behavior_cfg = {
    "inputset": "social+ego@v1",        # combines pair-wavelet social + ego
    # Optional: override/extend inputs inline
    # "inputs": [
    #     {"feature": "pair-wavelet__from__pair-posedistance-pca", "run_id": None,
    #      "pattern": "*.parquet",
    #      "load": {"kind": "parquet", "drop_columns": ["frame", "group", "sequence"], "numeric_only": True}},
    #     ...
    # ],
    "label_kind": "behavior",
    # Provide official splits or let train_fraction handle it
    "train_sequences": [(d) for d in  dataset.list_sequences() if 'task1/train' in d],
    "test_sequences":  [(d) for d in  dataset.list_sequences() if 'task1/test' in d],
    # "train_fraction": 0.8,             # used when explicit lists omitted
    "random_state": 42,
    "classes": [0, 1, 2, 3],
    "label_map": {0: "attack", 1: "investigation", 2: "mount", 3: "other"},
    "standardize": True,
    "use_undersample": True,
    "undersample_ratio": 3.0,
    "use_smote": False,
    "xgb_params_preset": "xgb_v0",     # or "xgb_v0"/"xgb_v2"; add "xgb_params" for overrides
    "use_external_memory": False 
}

cfg_path = dataset.get_root("models") / "configs" / "calms_behavior_xgb_inputset.json"
cfg_path.parent.mkdir(parents=True, exist_ok=True)
cfg_path.write_text(json.dumps(behavior_cfg, indent=2))
print("Config saved:", cfg_path)

model = models_behavior.BehaviorXGBoostModel()
run_id = dataset.train_model(model, cfg_path)
print("behavior-xgb run:", run_id)

# %% [markdown]
# ### remote training

# %%
# optional manual sync if you want to launch the job later
dataset.sync_to_remote(remote_cfg)

# sync the package files needed
import subprocess
cmd = "rsync * jdavidson@kn-cgpu03:/home/jdavidson/mice_data/calms21/dataset/."
subprocess.run(cmd, shell=True, check=True)

run_id = dataset.train_model_remote(
    model_class="models_behavior.BehaviorXGBoostModel",
    config=behavior_cfg,
    remote_cfg=remote_cfg,
    sync_before=False,
    sync_after=True,
)

print("remote run:", run_id)

# When coming back later just pull the artifacts:
dataset.sync_from_remote(remote_cfg)
# Out:
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# [remote-sync:to] running: rsync -az --delete --exclude .remote_jobs/** --exclude features/temporal-stack__from__social+ego@v1/0.1-5a2b368452/** --exclude features/temporal-stack__from__social+ego@v1/0.1-a04056b851/** --exclude media/ --exclude *.mp4 --exclude *.py --exclude *.ipynb --exclude features/ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1 /Volumes/JD-SSD/mice_data/calms21/dataset/ jdavidson@100.77.35.28:/home/jdavidson/mice_data/calms21/dataset/
# skipping directory __pycache__
# skipping directory dev-prev
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# [model:behavior-xgb] completed run_id=0.1-81e89c014b -> /home/jdavidson/mice_data/calms21/dataset/models/behavior-xgb/0.1-81e89c014b
# REMOTE_RUN_ID=0.1-81e89c014b
#
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# /home/jdavidson/miniforge3/envs/ecodylic/lib/python3.11/site-packages/xgboost/core.py:774: UserWarning: [15:31:18] WARNING: /workspace/src/common/error_msg.cc:62: Falling back to prediction using DMatrix due to mismatched devices. This might lead to higher memory usage and slower performance. XGBoost is running on: cuda:0, while the input data is on: cpu.
# Potential solutions:
# - Use a data structure that matches the device ordinal in the booster.
# - Set the device for booster before call to inplace_predict.
#
# This warning will only be shown once.
#
#   return func(**kwargs)
# [remote-sync:from] running: rsync -az --delete --exclude features/temporal-stack__from__social+ego@v1/0.1-5a2b368452/** --exclude features/temporal-stack__from__social+ego@v1/0.1-a04056b851/** --exclude media/ --exclude *.mp4 --exclude *.py --exclude *.ipynb --exclude features/ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1 jdavidson@100.77.35.28:/home/jdavidson/mice_data/calms21/dataset/ /Volumes/JD-SSD/mice_data/calms21/dataset/
# remote run: 0.1-81e89c014b
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# [remote-sync:from] running: rsync -az --delete --exclude features/temporal-stack__from__social+ego@v1/0.1-5a2b368452/** --exclude features/temporal-stack__from__social+ego@v1/0.1-a04056b851/** --exclude media/ --exclude *.mp4 --exclude *.py --exclude *.ipynb --exclude features/ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1 jdavidson@100.77.35.28:/home/jdavidson/mice_data/calms21/dataset/ /Volumes/JD-SSD/mice_data/calms21/dataset/

# %%
import json
import numpy as np
import pandas as pd
from pathlib import Path

run_id = "0.1-81e89c014b"            # <- whatever dataset.train_model_remote returned
run_root = dataset.get_root("models") / "behavior-xgb" / run_id

# 1) Quick per-class metrics table
summary_df = pd.read_csv(run_root / "summary.csv")
display(summary_df.sort_values("behavior"))

# 2) Full reports + confusion matrices
with open(run_root / "reports.json") as f:
    reports = json.load(f)

conf_mats = {
    int(cls): np.array(payload["confusion_matrix"])
    for cls, payload in reports.items()
}

# for cls, cm in conf_mats.items():
#     print(f"\nBehavior {cls} confusion matrix (rows=true, cols=pred):")
#     display(pd.DataFrame(cm, index=["neg", "pos"], columns=["neg", "pos"]))

macro_f1 = np.mean([
    payload["report"][str(cls)]["f1-score"]
    for cls, payload in reports.items()
])
print(f"Macro F1: {macro_f1:.3f}")
# Out:
#    behavior  precision    recall        f1   support  average_precision
# 0         0   0.748032  0.707284  0.727088   12630.0           0.776048
# 1         1   0.669328  0.659421  0.664337   61275.0           0.712217
# 2         2   0.924620  0.746797  0.826249   31848.0           0.917819
# 3         3   0.911416  0.910920  0.911168  156354.0           0.973463
# Behavior 0 confusion matrix (rows=true, cols=pred):
#         neg   pos
# neg  246468  3009
# pos    3697  8933
# Behavior 1 confusion matrix (rows=true, cols=pred):
#         neg    pos
# neg  180870  19962
# pos   20869  40406
# Behavior 2 confusion matrix (rows=true, cols=pred):
#         neg    pos
# neg  228320   1939
# pos    8064  23784
# Behavior 3 confusion matrix (rows=true, cols=pred):
#        neg     pos
# neg  91910   13843
# pos  13928  142426
# Macro F1: 0.782

# %%
print('Mean F1 excluding other:',np.mean(summary_df['f1'].values[0:3]))
# Out:
# Mean F1 excluding other: 0.7392248385085954

# %% [markdown]
# # Model prediction

# %%
import json, pathlib
run_id = "0.1-bd0052fc0b"

run_root = dataset.get_root("models") / "behavior-xgb" / run_id
cfg = json.loads((run_root / "config.json").read_text())
feature_name = cfg["inputset"]  # or "feature" if trained on a feature
feature_name
# Out:
# 'temporal-stack-0.1-82afbc8a7e'

# %%
importlib.reload(features)

cmd = "rsync * jdavidson@kn-cgpu03:/home/jdavidson/mice_data/calms21/dataset/."
subprocess.run(cmd, shell=True, check=True)

predict_feat = features.ModelPredictFeature({
    "model_class": "models_behavior.BehaviorXGBoostModel",
    "model_run_id": run_id,
})

## REMOTE RUN
remote_run = dataset.run_feature_remote(
    feature_class="features.ModelPredictFeature",
    params=predict_feat.params,
    remote_cfg=remote_cfg,
    groups=GROUP_SCOPE,
    input_kind="inputset",
    input_feature=feature_name,
    parallel_workers=2,
    sync_before=True,   # adjust as needed
    sync_after=True,
    remote_only=False,
)

## LOCAL RUN
# run_id = dataset.run_feature(
#     predict_feat,
#     input_kind="inputset",
#     input_feature=feature_name,   # same feature the model was trained on
#     groups=GROUP_SCOPE,
#     parallel_workers=2,
# )

# overlay:
# feature_runs = {"temporal-stack": None, "behavior-xgb-pred": run_id}
# viz.play_video(dataset, group, sequence, feature_runs, color_by="behavior-xgb-pred")
# Out:
# skipping directory __pycache__
# skipping directory dev-prev
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# [remote-sync:to] running: rsync -az --delete --exclude .remote_jobs/** --exclude features/temporal-stack__from__social+ego@v1/0.1-5a2b368452/** --exclude features/temporal-stack__from__social+ego@v1/0.1-a04056b851/** --exclude features/temporal-stack__from__social+ego@v1/0.1-82afbc8a7e/** --exclude features/temporal-stack__from__social+ego@v1/0.1-3e9024a46d/** --exclude features/temporal-stack__from__social+ego@v1/0.1-7ffa9af34f/** --exclude media/ --exclude *.mp4 --exclude *.py --exclude *.ipynb --exclude features/ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1 /Volumes/JD-SSD/mice_data/calms21/dataset/ jdavidson@100.77.35.28:/home/jdavidson/mice_data/calms21/dataset/
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# [feature:model-predict__from__temporal-stack-0.1-82afbc8a7e] completed run_id=0.1-bd1ea370f9 -> /home/jdavidson/mice_data/calms21/dataset/features/model-predict__from__temporal-stack-0.1-82afbc8a7e/0.1-bd1ea370f9
# REMOTE_FEATURE_RUN_ID=0.1-bd1ea370f9
# REMOTE_STORAGE_FEATURE=model-predict__from__temporal-stack-0.1-82afbc8a7e
#
# [remote-run] executing via Jupyter -> http://100.77.35.28:8888
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse042_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse051_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse050_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse069_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse049_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse043_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse037_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse022_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse056_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse013_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse015_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse061_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse062_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse047_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse011_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse071_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse057_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse052_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse014_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse031_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse054_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse002_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse033_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse079_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse005_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse029_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse074_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse027_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse028_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse046_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse001_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse039_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse021_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse087_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse020_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse078_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse035_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse010_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse023_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse055_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse024_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse012_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse068_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse072_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse048_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse044_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse025_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse007_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse084_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse063_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse018_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse053_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse041_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse073_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse032_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse083_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse030_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse045_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse008_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse067_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse085_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse089_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse066_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse088_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse058_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse059_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse077_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse017_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse009_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse081_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse038_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse004_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse082_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse076_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse034_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse003_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse036_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse065_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse086_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse006_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse064_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse019_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse075_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse016_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_test,task1/test/mouse080_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse060_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse026_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse040_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [feature:model-predict] transform failed for (calms21_task1_train,task1/train/mouse070_task1_annotator1): X has 49 features, but StandardScaler is expecting 3703 features as input.
# [remote-sync:from] running: rsync -az --delete --exclude features/temporal-stack__from__social+ego@v1/0.1-5a2b368452/** --exclude features/temporal-stack__from__social+ego@v1/0.1-a04056b851/** --exclude features/temporal-stack__from__social+ego@v1/0.1-82afbc8a7e/** --exclude features/temporal-stack__from__social+ego@v1/0.1-3e9024a46d/** --exclude features/temporal-stack__from__social+ego@v1/0.1-7ffa9af34f/** --exclude media/ --exclude *.mp4 --exclude *.py --exclude *.ipynb --exclude features/ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1 jdavidson@100.77.35.28:/home/jdavidson/mice_data/calms21/dataset/ /Volumes/JD-SSD/mice_data/calms21/dataset/

# %% [markdown]
# # Visualization

# %%
import visualization as viz
importlib.reload(viz)
# Out:
# <module 'visualization' from '/Users/jacob/Documents/GitHub/EcodylicScience/behavior/visualization.py'>

# %% [markdown]
# ## label loader

# %% [markdown]
# ### features

# %%
# map feature/model storage names to run_ids (None = latest finished run)
feature_runs = {
    "ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1": "0.1-1b442f7694",
}
g1, s1 = "calms21_task1_train", "task1/train/mouse001_task1_annotator1"

tracks_df, labels = viz.load_tracks_and_labels(dataset, group=g1, sequence=s1, feature_runs=feature_runs)

# inspect
print(tracks_df.head())
print(labels["per_id"].keys())      # features with per-id labels
print(labels["per_pair"].keys())    # features with per-pair labels
# Out:
#    frame      time  id  X#wcentroid  Y#wcentroid          VX          VY  \
# 0      0  0.000000   0   751.516347   223.200147  114.594203  102.276037
# 1      1  0.033333   0   755.336154   226.609349  108.039433   -0.776120
# 2      2  0.066667   0   758.718976   223.148406   34.177447 -114.062134
# 3      3  0.100000   0   757.614650   219.005206  -55.098999 -147.499908
# 4      4  0.133333   0   755.045709   213.315079 -104.686066 -119.485221
#
#         SPEED           AX           AY  ...  midline_y midline_length  \
# 0  153.597588  -196.643110 -3091.564693  ...        NaN            NaN
# 1  108.042221 -1206.251351 -3245.072564  ...        NaN            NaN
# 2  119.072534 -2447.076481 -2200.856820  ...        NaN            NaN
# 3  157.455144 -2082.952685   -81.346298  ...        NaN            NaN
# 4  158.858082  -800.787179   654.678167  ...        NaN            NaN
#
#   midline_segment_length  normalized_midline  ANGULAR_V#centroid  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
#
#    ANGULAR_A#centroid  BORDER_DISTANCE#pcentroid  MIDLINE_OFFSET  num_pixels  \
# 0                 NaN                        NaN             NaN         NaN
# 1                 NaN                        NaN             NaN         NaN
# 2                 NaN                        NaN             NaN         NaN
# 3                 NaN                        NaN             NaN         NaN
# 4                 NaN                        NaN             NaN         NaN
#
#    detection_p
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 53 columns]
# dict_keys(['ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1'])
# dict_keys([])

# %% [markdown]
# ### ground truth labels

# %%
g1, s1 = "calms21_task1_train", "task1/train/mouse001_task1_annotator1"
gt = viz.load_ground_truth_labels(dataset, label_kind="behavior", group=g1, sequence=s1)
display(gt.head())
# Out:
#    frame  label_id         label_name
# 0      0         3  other_interaction
# 1      1         1      investigation
# 2      2         1      investigation
# 3      3         1      investigation
# 4      4         1      investigation

# %% [markdown]
# ## overlay

# %%
importlib.reload(viz)
import cv2
import matplotlib.pyplot as plt
from PIL import Image

tracks_df, labels = viz.load_tracks_and_labels(dataset, g1, s1, feature_runs)
gt = viz.load_ground_truth_labels(dataset, "behavior", g1, s1)

overlay = viz.prepare_overlay(tracks_df, labels, gt_df=gt, kinds=("pose", "bbox"), color_by="ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1")

frame_idx = overlay["frames"][1000]
frame_overlay = overlay["per_frame"][frame_idx]

dummy = np.zeros((720, 1280, 3), dtype=np.uint8)   # replace with actual video frame
drawn = viz.draw_frame(dummy, frame_overlay, overlay["id_colors"])
display(Image.fromarray(cv2.cvtColor(drawn, cv2.COLOR_BGR2RGB)))
# Out:
# <PIL.Image.Image image mode=RGB size=1280x720>

# %%
### Custom handing per frame example

# tracks_df, lbls = viz.load_tracks_and_labels(dataset, g1, s1, feature_runs)
# gt = viz.load_ground_truth_labels(dataset, "behavior", g1, s1)
# overlay = viz.prepare_overlay(tracks_df, lbls, gt_df=gt)
# video_path = dataset.resolve_media_path(g1, s1)

# stream = viz.render_stream(video_path, overlay, start=0, end=600, downscale=0.5)
# for frame_idx, frame in stream:
#     # custom handling per frame
#     pass

# %%
import visualization as viz
importlib.reload(viz)

feature_runs = {
    "ward-assign__from__global-ward__from__global-tsne__from__social+ego@v1": "0.1-1b442f7694",
}
g1, s1 = "calms21_task1_train", "task1/train/mouse001_task1_annotator1"

# Interactive preview (press 'q' or Esc to exit)
viz.play_video(dataset, g1, s1, feature_runs, color_by=list(feature_runs.keys())[0], downscale=1)
# # color by ground truth:
# viz.play_video(dataset, g1, s1, feature_runs, color_by="gt")

# %%
# Offline render without GUI
viz.play_video(dataset, g1, s1, feature_runs, label_kind="behavior",
               start=0, end=100, downscale=0.75,
               show_window=False, output_path="outputs/mouse001_overlay.mp4", color_by="gt")
# Out:
# PosixPath('outputs/mouse001_overlay.mp4')

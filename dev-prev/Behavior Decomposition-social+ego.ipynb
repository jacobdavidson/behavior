# %%
import numpy as np
import pandas as pd
import glob

from sklearn.decomposition import IncrementalPCA
from pathlib import Path

import numpy as np
import pandas as pd
from pathlib import Path
from collections import defaultdict
from tqdm import tqdm

from sklearn.model_selection import GroupShuffleSplit
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler

import joblib
import re, os

from tqdm import tqdm
from joblib import Parallel, delayed
import concurrent.futures as cf
from time import perf_counter
from sklearn.preprocessing import StandardScaler

from concurrent.futures import ThreadPoolExecutor

import os, math, time, json
from pathlib import Path
import numpy as np
import pandas as pd
from sklearn.metrics import classification_report, confusion_matrix, average_precision_score, precision_recall_curve, f1_score
from sklearn.model_selection import train_test_split

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import autocast, GradScaler

# %%
import importlib
import calms_dataset as calms
import util
import models as mod
importlib.reload(mod)
importlib.reload(calms)
importlib.reload(util)
# import viz
# Out:
# <module 'util' from '/Users/jacob/Documents/GitHub/EcodylicScience/behavior/util.py'>

# %% [markdown]
# # Functions

# %% [markdown]
# # Data import

# %% [markdown]
# ### CALMS DATA

# %%
datadir = Path("/home/jdavidson/calms21/data")
base = "/home/jdavidson/calms21/"
files = sorted(datadir.glob("*npy"))
print(f"Found {len(files)} files")
# Out:
# Found 8 files

# %%
file = files[0]
file
# Out:
# PosixPath('/home/jdavidson/calms21/data/calms21_task1_train.npy')

# %%
df_trex = calms.calms21_to_trex_df(file)
df_trex.head()
# Out:
#    frame      time  id  X#wcentroid  Y#wcentroid          VX          VY  \
# 0      0  0.000000   0   751.516347   223.200147  114.594203  102.276037
# 1      1  0.033333   0   755.336154   226.609349  108.039433   -0.776120
# 2      2  0.066667   0   758.718976   223.148406   34.177447 -114.062134
# 3      3  0.100000   0   757.614650   219.005206  -55.098999 -147.499908
# 4      4  0.133333   0   755.045709   213.315079 -104.686066 -119.485221
#
#         SPEED           AX           AY  ...  midline_y midline_length  \
# 0  153.597588  -196.643110 -3091.564693  ...        NaN            NaN
# 1  108.042221 -1206.251351 -3245.072564  ...        NaN            NaN
# 2  119.072534 -2447.076481 -2200.856820  ...        NaN            NaN
# 3  157.455144 -2082.952685   -81.346298  ...        NaN            NaN
# 4  158.858082  -800.787179   654.678167  ...        NaN            NaN
#
#   midline_segment_length  normalized_midline  ANGULAR_V#centroid  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3                    NaN                 NaN                 NaN
# 4                    NaN                 NaN                 NaN
#
#    ANGULAR_A#centroid  BORDER_DISTANCE#pcentroid  MIDLINE_OFFSET  num_pixels  \
# 0                 NaN                        NaN             NaN         NaN
# 1                 NaN                        NaN             NaN         NaN
# 2                 NaN                        NaN             NaN         NaN
# 3                 NaN                        NaN             NaN         NaN
# 4                 NaN                        NaN             NaN         NaN
#
#    detection_p
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
#
# [5 rows x 46 columns]

# %%
# only use a single video
df_trex['sequence'].unique()
# Out:
# array(['task1/train/mouse001_task1_annotator1',
#        'task1/train/mouse002_task1_annotator1',
#        'task1/train/mouse003_task1_annotator1',
#        'task1/train/mouse004_task1_annotator1',
#        'task1/train/mouse005_task1_annotator1',
#        'task1/train/mouse006_task1_annotator1',
#        'task1/train/mouse007_task1_annotator1',
#        'task1/train/mouse008_task1_annotator1',
#        'task1/train/mouse009_task1_annotator1',
#        'task1/train/mouse010_task1_annotator1',
#        'task1/train/mouse011_task1_annotator1',
#        'task1/train/mouse012_task1_annotator1',
#        'task1/train/mouse013_task1_annotator1',
#        'task1/train/mouse014_task1_annotator1',
#        'task1/train/mouse015_task1_annotator1',
#        'task1/train/mouse016_task1_annotator1',
#        'task1/train/mouse017_task1_annotator1',
#        'task1/train/mouse018_task1_annotator1',
#        'task1/train/mouse019_task1_annotator1',
#        'task1/train/mouse020_task1_annotator1',
#        'task1/train/mouse021_task1_annotator1',
#        'task1/train/mouse022_task1_annotator1',
#        'task1/train/mouse023_task1_annotator1',
#        'task1/train/mouse024_task1_annotator1',
#        'task1/train/mouse025_task1_annotator1',
#        'task1/train/mouse026_task1_annotator1',
#        'task1/train/mouse027_task1_annotator1',
#        'task1/train/mouse028_task1_annotator1',
#        'task1/train/mouse029_task1_annotator1',
#        'task1/train/mouse030_task1_annotator1',
#        'task1/train/mouse031_task1_annotator1',
#        'task1/train/mouse032_task1_annotator1',
#        'task1/train/mouse033_task1_annotator1',
#        'task1/train/mouse034_task1_annotator1',
#        'task1/train/mouse035_task1_annotator1',
#        'task1/train/mouse036_task1_annotator1',
#        'task1/train/mouse037_task1_annotator1',
#        'task1/train/mouse038_task1_annotator1',
#        'task1/train/mouse039_task1_annotator1',
#        'task1/train/mouse040_task1_annotator1',
#        'task1/train/mouse041_task1_annotator1',
#        'task1/train/mouse042_task1_annotator1',
#        'task1/train/mouse043_task1_annotator1',
#        'task1/train/mouse044_task1_annotator1',
#        'task1/train/mouse045_task1_annotator1',
#        'task1/train/mouse046_task1_annotator1',
#        'task1/train/mouse047_task1_annotator1',
#        'task1/train/mouse048_task1_annotator1',
#        'task1/train/mouse049_task1_annotator1',
#        'task1/train/mouse050_task1_annotator1',
#        'task1/train/mouse051_task1_annotator1',
#        'task1/train/mouse052_task1_annotator1',
#        'task1/train/mouse053_task1_annotator1',
#        'task1/train/mouse054_task1_annotator1',
#        'task1/train/mouse055_task1_annotator1',
#        'task1/train/mouse056_task1_annotator1',
#        'task1/train/mouse057_task1_annotator1',
#        'task1/train/mouse058_task1_annotator1',
#        'task1/train/mouse059_task1_annotator1',
#        'task1/train/mouse060_task1_annotator1',
#        'task1/train/mouse061_task1_annotator1',
#        'task1/train/mouse062_task1_annotator1',
#        'task1/train/mouse063_task1_annotator1',
#        'task1/train/mouse064_task1_annotator1',
#        'task1/train/mouse065_task1_annotator1',
#        'task1/train/mouse066_task1_annotator1',
#        'task1/train/mouse067_task1_annotator1',
#        'task1/train/mouse068_task1_annotator1',
#        'task1/train/mouse069_task1_annotator1',
#        'task1/train/mouse070_task1_annotator1'], dtype=object)

# %%
# df = df_trex[df_trex['sequence']=='task1/test/mouse071_task1_annotator1']
cm_per_pixel = 1

# %%
df = df_trex

# %% [markdown]
# ## ESI data

# %%
datadir = Path("/Volumes/JD-SSD/ESI-mice/data/")
base = "/Volumes/JD-SSD/ESI-mice/"
files = sorted(datadir.glob("*npz"))
print(f"Found {len(files)} files")
# Out:
# Found 4 files

# %%
# ----------------------------
# Combine all
# ----------------------------
dfs = []
for f in files:
    print("Loading", f.name)
    try:
        dfs.append(util.load_npz_to_df(f))
    except Exception as e:
        print(f"⚠️  Skipping {f.name} due to error: {e}")

df = pd.concat(dfs, ignore_index=True)
print(f"Combined shape: {df.shape}, {df['id'].nunique()} IDs")

# get constant values
data = np.load(files[0], allow_pickle=True)

cm_per_pixel = data['cm_per_pixel'][0]
video_size = data['video_size']
frame_rate = data['frame_rate'][0]
# Out:
# Loading concat_2024-11-11_id0.npz
# Loading concat_2024-11-11_id1.npz
# Loading concat_2024-11-11_id2.npz
# Loading concat_2024-11-11_id3.npz
# Combined shape: (86635, 43), 4 IDs

# %%
df
# Out:
#           ANGLE  ANGULAR_A#centroid  ANGULAR_V#centroid          AX  \
# 0      2.484261            0.000000            0.000000    0.000000
# 1      2.539648            0.000000            0.000000 -213.288223
# 2      2.568560            0.000000            0.000000   82.335327
# 3      2.533308            0.000000            0.000000   -4.889465
# 4      2.584643          579.182861           18.248541 -218.487366
# ...         ...                 ...                 ...         ...
# 86630 -0.387860          331.733459           12.345165   18.905931
# 86631       inf                 inf                 inf         inf
# 86632  0.304110           76.627808            5.817895  162.744202
# 86633  0.733470         -174.315720            0.007371 -677.256042
# 86634 -0.415556           -0.442254           -0.007371   -3.953948
#
#                 AY  BORDER_DISTANCE#pcentroid  MIDLINE_OFFSET      SPEED  \
# 0         0.000000                  44.426197       -0.080008   0.000000
# 1        28.369490                  44.311649       -0.089096   7.172223
# 2        67.904068                  44.217575       -0.068876   5.417796
# 3        32.919144                  44.105537       -0.019073   6.248902
# 4       -87.554840                  43.749397       -0.022627  11.892261
# ...            ...                        ...             ...        ...
# 86630    46.453991                  41.752728       -0.085200   1.989221
# 86631          inf                        inf             inf        inf
# 86632   374.228424                  42.553314       -0.223197  29.172840
# 86633    16.000341                  42.637295       -0.350005  29.614714
# 86634 -3309.926270                  41.736694       -0.076699  83.698242
#
#        SPEED#pcentroid  SPEED#wcentroid  ...  poseY1  poseY2  poseY3  poseY4  \
# 0             0.000000         0.000000  ...   351.0   306.0   239.0   353.0
# 1             5.162939         3.123934  ...   356.0   310.0   235.0   353.0
# 2             5.141601         5.689838  ...   361.0   318.0   239.0   357.0
# 3             4.118808        11.827248  ...   361.0   322.0   252.0   360.0
# 4            13.467146        10.831641  ...   367.0   334.0   266.0   362.0
# ...                ...              ...  ...     ...     ...     ...     ...
# 86630         0.619597         0.890100  ...   296.0   329.0   421.0   305.0
# 86631              inf              inf  ...     inf     inf     inf     inf
# 86632        14.856554        10.369840  ...   313.0   330.0   419.0   342.0
# 86633        11.890886         6.963426  ...   322.0   331.0   414.0   362.0
# 86634        39.439835        13.340050  ...   295.0   331.0   422.0   304.0
#
#        poseY5  poseY6        time    timestamp  visual_identification_p  id
# 0       402.0   275.0  177.066666  177066672.0                      inf   0
# 1       404.0   277.0  177.100006  177100000.0                      inf   0
# 2       408.0   284.0  177.133331  177133328.0                      inf   0
# 3       409.0   290.0  177.166672  177166672.0                      inf   0
# 4       414.0   301.0  177.199997  177200000.0                      inf   0
# ...       ...     ...         ...          ...                      ...  ..
# 86630   266.0   372.0  899.733337  899733312.0                      inf   3
# 86631     inf     inf  899.766663  899766656.0                      inf   3
# 86632   298.0   366.0  899.799988  899800000.0                      inf   3
# 86633   323.0   361.0  899.833313  899833344.0                      inf   3
# 86634   265.0   364.0  899.866638  899866688.0                      inf   3
#
# [86635 rows x 43 columns]

# %% [markdown]
# # behavioral decomposition

# %%
# === Pair-level Klibaite-style social decomposition (IncrementalPCA with 6 comps) ===
import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.decomposition import IncrementalPCA

# -----------------------------
# 0) Assumes you already have df with pose & tracking
# ----------------------------- 
# df = pd.read_parquet("your_pose_dataframe.parquet")

# -----------------------------
# 1) Config
# -----------------------------
POSE_N = 7
POSE_X_COLS = [f"poseX{i}" for i in range(POSE_N)]
POSE_Y_COLS = [f"poseY{i}" for i in range(POSE_N)]
POSE_COLS = POSE_X_COLS + POSE_Y_COLS

ORDER_COL = "frame" if "frame" in df.columns else ("time" if "time" in df.columns else None)
ID_COL    = "id" if "id" in df.columns else None
SEQ_COL   = "sequence" if "sequence" in df.columns else None

# PCA per paper: 6 components for shared postural representation
N_COMPONENTS = 6
BATCH_SIZE   = 5000

# Cleaning/interp parameters (per individual)
LINEAR_INTERP_LIMIT    = 10
EDGE_FILL_LIMIT        = 3
MAX_MISSING_FRACTION   = 0.1

# Pair feature options
INCLUDE_INTRA_A = True   # lower-tri distances within animal A
INCLUDE_INTRA_B = True   # lower-tri distances within animal B
INCLUDE_INTER   = True   # all A×B cross distances
DUPLICATE_PERSPECTIVE = True  # add (B,A) order as second sample per frame

OUT_DIR = Path(base + "socialmapper_outputs")
OUT_DIR.mkdir(exist_ok=True, parents=True)

# -----------------------------
# 2) Sanity checks
# -----------------------------
need = (POSE_COLS + ([ORDER_COL] if ORDER_COL else []) + ([ID_COL] if ID_COL else []))
missing = [c for c in need if c not in df.columns]
if missing:
    raise ValueError(f"Missing expected columns: {missing}")
if ORDER_COL is None:
    raise ValueError("Need either 'frame' or 'time' column to order frames.")
if ID_COL is None:
    df = df.copy()
    df["id"] = 0
    ID_COL = "id"
if SEQ_COL is None:
    df = df.copy()
    df["sequence"] = "seq0"
    SEQ_COL = "sequence"

# Keep only needed columns
keep_cols = [SEQ_COL, ID_COL, ORDER_COL] + POSE_COLS
df_small = df[keep_cols].copy()
df_small[ORDER_COL] = df_small[ORDER_COL].astype(int, errors="ignore")
df_small[POSE_COLS] = df_small[POSE_COLS].replace([np.inf, -np.inf], np.nan)

# -----------------------------
# 3) Clean/interpolate per individual
# -----------------------------

df_small = (
    df_small
    .groupby([SEQ_COL, ID_COL], group_keys=False)
    .apply(util.clean_one_group, include_groups=True)
)

# Final assert: no NaNs left in pose cols
if df_small[POSE_COLS].isna().any().any():
    raise ValueError("NaNs remain after cleaning pose columns.")

# -----------------------------
# 4) Build dyad pairs per sequence by inner-joining on frame
#    (assumes two animals per sequence; if more, pairs the first two by default)
# -----------------------------
pair_index = []   # list of (sequence, idA, idB)
pairs_per_seq = {}  # seq -> (idA, idB)

for seq, gseq in df_small.groupby(SEQ_COL):
    ids = sorted(gseq[ID_COL].unique())
    if len(ids) < 2:
        continue
    idA, idB = ids[:2]
    pairs_per_seq[seq] = (idA, idB)
    pair_index.append((seq, idA, idB))

if not pair_index:
    raise ValueError("No sequences with at least two IDs found to form dyads.")

# Precompute lower-tri indices for intra distances
tri_i, tri_j = np.tril_indices(POSE_N, k=-1)
n_intra = len(tri_i)
n_cross = POSE_N * POSE_N

# Determine feature length
feat_len = 0
if INCLUDE_INTRA_A: feat_len += n_intra
if INCLUDE_INTRA_B: feat_len += n_intra
if INCLUDE_INTER:   feat_len += n_cross

# -----------------------------
# 6) Fit global IncrementalPCA (6 comps)
# -----------------------------
ipca = IncrementalPCA(n_components=min(N_COMPONENTS, feat_len))

# partial_fit streaming
for Xb, _, _, _ in util.dyad_row_generator(df_small, BATCH_SIZE):
    if not np.isfinite(Xb).all():
        i_bad = np.where(~np.isfinite(Xb))
        raise ValueError(f"Non-finite values in batch at indices {i_bad}")
    ipca.partial_fit(Xb)

print(f"[IPCA] Fitted on feature length {feat_len} -> {ipca.n_components_} comps")

# -----------------------------
# 7) Transform & save per sequence (keeping perspective)
# -----------------------------
# We’ll collect per (sequence, perspective) projections aligned to frame order
per_seq_persp = {}  # (seq, persp) -> dict(frames, Z_rows_list)

for Xb, seqs, frames, persp in dyad_row_generator(df_small, BATCH_SIZE):
    Zb = ipca.transform(Xb)  # (B, n_components)
    for p in (0, 1) if DUPLICATE_PERSPECTIVE else (0,):
        mask = (persp == p)
        if not np.any(mask):
            continue
        Zp = Zb[mask]
        seq_list = [s for s, m in zip(seqs, mask) if m]
        frames_p = frames[mask]
        for s in np.unique(seq_list):
            m2 = np.array([ss == s for ss in seq_list], dtype=bool)
            key = (s, p)
            if key not in per_seq_persp:
                per_seq_persp[key] = {"frames": [], "Z": []}
            per_seq_persp[key]["frames"].append(frames_p[m2])
            per_seq_persp[key]["Z"].append(Zp[m2])

# --- Save one file per (sequence, perspective) ---
for (seq, p), rec in per_seq_persp.items():
    frames_all = np.concatenate(rec["frames"])
    Z_all = np.vstack(rec["Z"])              # (n_frames_seq_p, n_components)
    sort_idx = np.argsort(frames_all)
    Z_sorted = Z_all[sort_idx].T             # (n_components, n_frames_sorted)

    # sanitize sequence name for filesystem
    safe_seq = str(seq).replace("/", "-").replace("\\", "-")

    out_path = OUT_DIR / f"social_projections_seq={safe_seq}_persp={p}.npz"
    np.savez_compressed(
        out_path,
        projections=Z_sorted,                # (6, n_frames)
        components=ipca.components_,         # (6, feat_len)
        mean_=ipca.mean_,                    # (feat_len,)
        tri_i=tri_i, tri_j=tri_j,            # intra mapping indices
        pose_points=POSE_N,
        include_intra_A=INCLUDE_INTRA_A,
        include_intra_B=INCLUDE_INTRA_B,
        include_inter=INCLUDE_INTER,
        duplicate_perspective=DUPLICATE_PERSPECTIVE,
        feature_len=feat_len,
        order_col=ORDER_COL,
        sequence=seq,
        perspective=p,                       # 0: A->B, 1: B->A
    )
    print(f"[SAVE] {out_path}  (frames={Z_sorted.shape[1]})")

print("Done: pair-level features + global 6D IPCA saved per sequence (and perspective).")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 73
#      64 df_small[POSE_COLS] = df_small[POSE_COLS].replace([np.inf, -np.inf], np.nan)
#      66 # -----------------------------
#      67 # 3) Clean/interpolate per individual
#      68 # -----------------------------
#      70 df_small = (
#      71     df_small
#      72     .groupby([SEQ_COL, ID_COL], group_keys=False)
# ---> 73     .apply(util.clean_one_group, include_groups=True)
#      74 )
#      76 # Final assert: no NaNs left in pose cols
#      77 if df_small[POSE_COLS].isna().any().any():
#
# File ~/miniforge3/envs/beesbook/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1826, in GroupBy.apply(self, func, include_groups, *args, **kwargs)
#    1824 with option_context("mode.chained_assignment", None):
#    1825     try:
# -> 1826         result = self._python_apply_general(f, self._selected_obj)
#    1827         if (
#    1828             not isinstance(self.obj, Series)
#    1829             and self._selection is None
#    1830             and self._selected_obj.shape != self._obj_with_exclusions.shape
#    1831         ):
#    1832             warnings.warn(
#    1833                 message=_apply_groupings_depr.format(
#    1834                     type(self).__name__, "apply"
#    (...)
#    1837                 stacklevel=find_stack_level(),
#    1838             )
#
# File ~/miniforge3/envs/beesbook/lib/python3.12/site-packages/pandas/core/groupby/groupby.py:1887, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1852 @final
#    1853 def _python_apply_general(
#    1854     self,
#    (...)
#    1859     is_agg: bool = False,
#    1860 ) -> NDFrameT:
#    1861     """
#    1862     Apply function f in python space
#    1863
#    (...)
#    1885         data after applying f
#    1886     """
# -> 1887     values, mutated = self._grouper.apply_groupwise(f, data, self.axis)
#    1888     if not_indexed_same is None:
#    1889         not_indexed_same = mutated
#
# File ~/miniforge3/envs/beesbook/lib/python3.12/site-packages/pandas/core/groupby/ops.py:928, in BaseGrouper.apply_groupwise(self, f, data, axis)
#     926 # group might be modified
#     927 group_axes = group.axes
# --> 928 res = f(group)
#     929 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     930     mutated = True
#
# File ~/Documents/GitHub/EcodylicScience/behavior/util.py:163, in clean_one_group(g)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# NameError: name 'ORDER_COL' is not defined

# %%
# --------------------------------------
# 8) (Optional) quick sanity check
# --------------------------------------
import numpy as np
from pathlib import Path

# Find one saved projection file
npz_files = list(OUT_DIR.glob("social_projections_seq=*persp=*.npz"))
if not npz_files:
    raise FileNotFoundError("No social_projections_*.npz files found in output directory.")

test_file = npz_files[0]
data = np.load(test_file)

print(f"\n[CHECK] Loaded: {test_file.name}")
print(f"  projections shape : {data['projections'].shape}")
print(f"  components shape  : {data['components'].shape}")
print(f"  mean_ shape       : {data['mean_'].shape}")
print(f"  pose_points       : {data['pose_points']}")
print(f"  perspective       : {data['perspective']}")
print(f"  feature length    : {data['feature_len']}")
print(f"  Expected projection shape: ({min(N_COMPONENTS, data['components'].shape[0])}, n_frames)")

n_comp, n_frames = data["projections"].shape
assert n_comp == min(N_COMPONENTS, data["components"].shape[0]), \
    f"Unexpected n_components: got {n_comp}"
print("✅ Sanity check passed — projection dimensions match expected PCA config.")

# %% [markdown]
# ## Egocentric features

# %%
# ============================================================
# STEP 1.5 — Egocentric + kinematic features per sequence
#   Saves: ego_kinematics_seq=<safe_seq>_persp=<0|1>.npz
#   Shape saved: ego (n_feats, n_frames)  and frames (n_frames,)
# ============================================================
import numpy as np
from pathlib import Path

EGO_OUT_DIR = OUT_DIR  # reuse your output dir
EGO_OUT_DIR.mkdir(parents=True, exist_ok=True)

# --- CONFIG: which keypoints define heading / center ---
# Adjust these indices to your skeleton if needed
# Default: heading = neck - tail_base, center = mean of all points
NECK_IDX      = 3         # e.g., neck
TAIL_BASE_IDX = 6         # e.g., tail base
CENTER_MODE   = "mean"    # "mean" or an integer index of a single point
FPS_DEFAULT   = 30.0

# Optional smoothing of positions before velocity (frames)
SMOOTH_WIN = 0            # 0 = no smoothing; else box filter window size (odd)



# --- iterate sequences, build joined tables once (reuse from STEP 1) ---
for seq, (idA, idB) in pairs_per_seq.items():
    gA = df_small[(df_small[SEQ_COL] == seq) & (df_small[ID_COL] == idA)][[ORDER_COL] + POSE_COLS]
    gB = df_small[(df_small[SEQ_COL] == seq) & (df_small[ID_COL] == idB)][[ORDER_COL] + POSE_COLS]
    if gA.empty or gB.empty:
        continue

    gA = gA.rename(columns={ORDER_COL: "frame"})
    gB = gB.rename(columns={ORDER_COL: "frame"})
    j = gA.merge(gB, on="frame", suffixes=("_A", "_B"))
    if j.empty:
        continue

    # try to recover FPS if present in your earlier saved artifacts, else default
    fps = FPS_DEFAULT

    frames, AtoB, BtoA, feat_names = util._build_ego_block_for_joined(j, fps)

    # sanitized seq name for file
    safe_seq = str(seq).replace("/", "-").replace("\\", "-")

    # save both perspectives
    for p, arr in [(0, AtoB), (1, BtoA)]:
        out_path = EGO_OUT_DIR / f"ego_kinematics_seq={safe_seq}_persp={p}.npz"
        np.savez_compressed(
            out_path,
            ego=arr,                   # (n_feats, n_frames)
            frames=frames,             # (n_frames,)
            fps=fps,
            feature_names=np.array(feat_names, dtype=object),
            pose_points=POSE_N,
            neck_idx=NECK_IDX,
            tail_base_idx=TAIL_BASE_IDX,
            center_mode=np.array([CENTER_MODE] if isinstance(CENTER_MODE, str) else [int(CENTER_MODE)], dtype=object),
            sequence=seq,
            perspective=p,
        )
        print(f"[EGO SAVE] {out_path.name}  -> {arr.shape} = (n_feats, n_frames)")

print("Done: egocentric + kinematic features saved for all sequences (both perspectives).")

# %% [markdown]
# # Wavelet decomposition

# %%
# Wavelet spectrogram for pair-level (social) projections with slower band (0.2–5 Hz)
# Requires: numpy, pywt (PyWavelets)

import numpy as np
import pywt
from pathlib import Path
import re

# -----------------------
# Config
# -----------------------
IN_DIR  = Path(base + "socialmapper_outputs")
PATTERN = "social_projections_seq=*persp=*.npz"   # what we saved earlier
FPS     = 30.0                                    # set correctly for your videos (CalMS21 uses 30 fps)
OVERWRITE = True                                  # skip if output exists

# Frequency band per paper (slower joint dynamics): ~0.2–5 Hz, dyadically spaced
f_min, f_max, n_freq = 0.2, 5.0, 25
frequencies = 2 ** np.linspace(np.log2(f_min), np.log2(f_max), n_freq)

# Complex Morlet wavelet; you can tweak parameters if desired
wavelet = pywt.ContinuousWavelet("cmor1.5-1.0")
central_f = pywt.central_frequency(wavelet)           # central frequency of the wavelet

# PyWavelets relation: freq = sampling_freq / (scale * central_f)  =>  scale = sampling_freq / (freq * central_f)
sampling_frequency = FPS
scales = sampling_frequency / (frequencies * central_f)

# -----------------------
# Process all pair-level projection files
# -----------------------
files = sorted(IN_DIR.glob(PATTERN))
if not files:
    raise FileNotFoundError(f"No projection files matching {PATTERN} in {IN_DIR}")

print(f"Found {len(files)} social projection files.")

for fpath in files:
    # Parse seq & perspective for output naming (we saved raw 'sequence' inside too)
    fname = fpath.stem  # e.g., "social_projections_seq=task1-test-mouse071_task1_annotator1_persp=0"
    m_seq = re.search(r"seq=(.+)_persp=", fname)
    m_p   = re.search(r"persp=(\d+)", fname)
    safe_seq = m_seq.group(1) if m_seq else "unknownseq"
    persp    = int(m_p.group(1)) if m_p else 0

    out_path = IN_DIR / f"wavelet_social_seq={safe_seq}_persp={persp}.npz"
    if out_path.exists() and not OVERWRITE:
        print(f"[SKIP] {out_path.name} exists; set OVERWRITE=True to recompute.")
        continue

    npz = np.load(fpath)
    Z = npz["projections"]               # (n_components, n_frames) — typically 6 x T
    n_components, n_frames = Z.shape

    print(f"[{fpath.name}] components={n_components}, frames={n_frames} -> computing wavelets...")

    # Compute CWT power per component
    power_stack = np.empty((n_components, n_freq, n_frames), dtype=np.float32)
    for k in range(n_components):
        coeffs, _ = pywt.cwt(Z[k], scales, wavelet, sampling_period=1.0 / sampling_frequency)
        power_stack[k] = (np.abs(coeffs) ** 2).astype(np.float32)  # (n_freq, n_frames)

    # Log + clamp at -3
    eps = np.finfo(np.float32).tiny
    log_power = np.log(power_stack + eps)
    log_power_clamped = np.maximum(log_power, -3.0)

    # Flatten to (n_components * n_freq, n_frames)
    spectrogram_flat = log_power_clamped.reshape(n_components * n_freq, n_frames)

    # Save
    np.savez_compressed(
        out_path,
        spectrogram=spectrogram_flat,        # (n_components*n_freq, n_frames)
        log_power_clamped=log_power_clamped, # (n_components, n_freq, n_frames)
        frequencies=frequencies,             # Hz
        scales=scales,
        fps=FPS,
        wavelet=str(wavelet),
        sequence=npz.get("sequence", safe_seq),
        perspective=npz.get("perspective", persp),
        n_components=n_components,
    )
    print(f"[SAVE] {out_path.name}  -> shape {spectrogram_flat.shape} = ({n_components}×{n_freq}) × {n_frames}")

print("All pair-level wavelet spectrograms done.")
# Out:
# Found 430 social projection files.
# [social_projections_seq=task1-test-mouse071_task1_annotator1_persp=0.npz] components=6, frames=23810 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse071_task1_annotator1_persp=0.npz  -> shape (150, 23810) = (6×25) × 23810
# [social_projections_seq=task1-test-mouse071_task1_annotator1_persp=1.npz] components=6, frames=23810 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse071_task1_annotator1_persp=1.npz  -> shape (150, 23810) = (6×25) × 23810
# [social_projections_seq=task1-test-mouse072_task1_annotator1_persp=0.npz] components=6, frames=18164 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse072_task1_annotator1_persp=0.npz  -> shape (150, 18164) = (6×25) × 18164
# [social_projections_seq=task1-test-mouse072_task1_annotator1_persp=1.npz] components=6, frames=18164 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse072_task1_annotator1_persp=1.npz  -> shape (150, 18164) = (6×25) × 18164
# [social_projections_seq=task1-test-mouse073_task1_annotator1_persp=0.npz] components=6, frames=19156 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse073_task1_annotator1_persp=0.npz  -> shape (150, 19156) = (6×25) × 19156
# [social_projections_seq=task1-test-mouse073_task1_annotator1_persp=1.npz] components=6, frames=19156 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse073_task1_annotator1_persp=1.npz  -> shape (150, 19156) = (6×25) × 19156
# [social_projections_seq=task1-test-mouse074_task1_annotator1_persp=0.npz] components=6, frames=18825 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse074_task1_annotator1_persp=0.npz  -> shape (150, 18825) = (6×25) × 18825
# [social_projections_seq=task1-test-mouse074_task1_annotator1_persp=1.npz] components=6, frames=18825 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse074_task1_annotator1_persp=1.npz  -> shape (150, 18825) = (6×25) × 18825
# [social_projections_seq=task1-test-mouse075_task1_annotator1_persp=0.npz] components=6, frames=18015 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse075_task1_annotator1_persp=0.npz  -> shape (150, 18015) = (6×25) × 18015
# [social_projections_seq=task1-test-mouse075_task1_annotator1_persp=1.npz] components=6, frames=18015 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse075_task1_annotator1_persp=1.npz  -> shape (150, 18015) = (6×25) × 18015
# [social_projections_seq=task1-test-mouse076_task1_annotator1_persp=0.npz] components=6, frames=19710 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse076_task1_annotator1_persp=0.npz  -> shape (150, 19710) = (6×25) × 19710
# [social_projections_seq=task1-test-mouse076_task1_annotator1_persp=1.npz] components=6, frames=19710 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse076_task1_annotator1_persp=1.npz  -> shape (150, 19710) = (6×25) × 19710
# [social_projections_seq=task1-test-mouse077_task1_annotator1_persp=0.npz] components=6, frames=18907 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse077_task1_annotator1_persp=0.npz  -> shape (150, 18907) = (6×25) × 18907
# [social_projections_seq=task1-test-mouse077_task1_annotator1_persp=1.npz] components=6, frames=18907 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse077_task1_annotator1_persp=1.npz  -> shape (150, 18907) = (6×25) × 18907
# [social_projections_seq=task1-test-mouse078_task1_annotator1_persp=0.npz] components=6, frames=19473 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse078_task1_annotator1_persp=0.npz  -> shape (150, 19473) = (6×25) × 19473
# [social_projections_seq=task1-test-mouse078_task1_annotator1_persp=1.npz] components=6, frames=19473 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse078_task1_annotator1_persp=1.npz  -> shape (150, 19473) = (6×25) × 19473
# [social_projections_seq=task1-test-mouse079_task1_annotator1_persp=0.npz] components=6, frames=17483 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse079_task1_annotator1_persp=0.npz  -> shape (150, 17483) = (6×25) × 17483
# [social_projections_seq=task1-test-mouse079_task1_annotator1_persp=1.npz] components=6, frames=17483 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse079_task1_annotator1_persp=1.npz  -> shape (150, 17483) = (6×25) × 17483
# [social_projections_seq=task1-test-mouse080_task1_annotator1_persp=0.npz] components=6, frames=6179 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse080_task1_annotator1_persp=0.npz  -> shape (150, 6179) = (6×25) × 6179
# [social_projections_seq=task1-test-mouse080_task1_annotator1_persp=1.npz] components=6, frames=6179 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse080_task1_annotator1_persp=1.npz  -> shape (150, 6179) = (6×25) × 6179
# [social_projections_seq=task1-test-mouse081_task1_annotator1_persp=0.npz] components=6, frames=4932 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse081_task1_annotator1_persp=0.npz  -> shape (150, 4932) = (6×25) × 4932
# [social_projections_seq=task1-test-mouse081_task1_annotator1_persp=1.npz] components=6, frames=4932 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse081_task1_annotator1_persp=1.npz  -> shape (150, 4932) = (6×25) × 4932
# [social_projections_seq=task1-test-mouse082_task1_annotator1_persp=0.npz] components=6, frames=7115 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse082_task1_annotator1_persp=0.npz  -> shape (150, 7115) = (6×25) × 7115
# [social_projections_seq=task1-test-mouse082_task1_annotator1_persp=1.npz] components=6, frames=7115 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse082_task1_annotator1_persp=1.npz  -> shape (150, 7115) = (6×25) × 7115
# [social_projections_seq=task1-test-mouse083_task1_annotator1_persp=0.npz] components=6, frames=4881 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse083_task1_annotator1_persp=0.npz  -> shape (150, 4881) = (6×25) × 4881
# [social_projections_seq=task1-test-mouse083_task1_annotator1_persp=1.npz] components=6, frames=4881 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse083_task1_annotator1_persp=1.npz  -> shape (150, 4881) = (6×25) × 4881
# [social_projections_seq=task1-test-mouse084_task1_annotator1_persp=0.npz] components=6, frames=5626 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse084_task1_annotator1_persp=0.npz  -> shape (150, 5626) = (6×25) × 5626
# [social_projections_seq=task1-test-mouse084_task1_annotator1_persp=1.npz] components=6, frames=5626 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse084_task1_annotator1_persp=1.npz  -> shape (150, 5626) = (6×25) × 5626
# [social_projections_seq=task1-test-mouse085_task1_annotator1_persp=0.npz] components=6, frames=19200 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse085_task1_annotator1_persp=0.npz  -> shape (150, 19200) = (6×25) × 19200
# [social_projections_seq=task1-test-mouse085_task1_annotator1_persp=1.npz] components=6, frames=19200 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse085_task1_annotator1_persp=1.npz  -> shape (150, 19200) = (6×25) × 19200
# [social_projections_seq=task1-test-mouse086_task1_annotator1_persp=0.npz] components=6, frames=8617 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse086_task1_annotator1_persp=0.npz  -> shape (150, 8617) = (6×25) × 8617
# [social_projections_seq=task1-test-mouse086_task1_annotator1_persp=1.npz] components=6, frames=8617 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse086_task1_annotator1_persp=1.npz  -> shape (150, 8617) = (6×25) × 8617
# [social_projections_seq=task1-test-mouse087_task1_annotator1_persp=0.npz] components=6, frames=11915 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse087_task1_annotator1_persp=0.npz  -> shape (150, 11915) = (6×25) × 11915
# [social_projections_seq=task1-test-mouse087_task1_annotator1_persp=1.npz] components=6, frames=11915 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse087_task1_annotator1_persp=1.npz  -> shape (150, 11915) = (6×25) × 11915
# [social_projections_seq=task1-test-mouse088_task1_annotator1_persp=0.npz] components=6, frames=8825 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse088_task1_annotator1_persp=0.npz  -> shape (150, 8825) = (6×25) × 8825
# [social_projections_seq=task1-test-mouse088_task1_annotator1_persp=1.npz] components=6, frames=8825 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse088_task1_annotator1_persp=1.npz  -> shape (150, 8825) = (6×25) × 8825
# [social_projections_seq=task1-test-mouse089_task1_annotator1_persp=0.npz] components=6, frames=11274 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse089_task1_annotator1_persp=0.npz  -> shape (150, 11274) = (6×25) × 11274
# [social_projections_seq=task1-test-mouse089_task1_annotator1_persp=1.npz] components=6, frames=11274 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-test-mouse089_task1_annotator1_persp=1.npz  -> shape (150, 11274) = (6×25) × 11274
# [social_projections_seq=task1-train-mouse001_task1_annotator1_persp=0.npz] components=6, frames=21364 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse001_task1_annotator1_persp=0.npz  -> shape (150, 21364) = (6×25) × 21364
# [social_projections_seq=task1-train-mouse001_task1_annotator1_persp=1.npz] components=6, frames=21364 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse001_task1_annotator1_persp=1.npz  -> shape (150, 21364) = (6×25) × 21364
# [social_projections_seq=task1-train-mouse002_task1_annotator1_persp=0.npz] components=6, frames=19343 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse002_task1_annotator1_persp=0.npz  -> shape (150, 19343) = (6×25) × 19343
# [social_projections_seq=task1-train-mouse002_task1_annotator1_persp=1.npz] components=6, frames=19343 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse002_task1_annotator1_persp=1.npz  -> shape (150, 19343) = (6×25) × 19343
# [social_projections_seq=task1-train-mouse003_task1_annotator1_persp=0.npz] components=6, frames=13222 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse003_task1_annotator1_persp=0.npz  -> shape (150, 13222) = (6×25) × 13222
# [social_projections_seq=task1-train-mouse003_task1_annotator1_persp=1.npz] components=6, frames=13222 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse003_task1_annotator1_persp=1.npz  -> shape (150, 13222) = (6×25) × 13222
# [social_projections_seq=task1-train-mouse004_task1_annotator1_persp=0.npz] components=6, frames=7433 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse004_task1_annotator1_persp=0.npz  -> shape (150, 7433) = (6×25) × 7433
# [social_projections_seq=task1-train-mouse004_task1_annotator1_persp=1.npz] components=6, frames=7433 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse004_task1_annotator1_persp=1.npz  -> shape (150, 7433) = (6×25) × 7433
# [social_projections_seq=task1-train-mouse005_task1_annotator1_persp=0.npz] components=6, frames=5641 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse005_task1_annotator1_persp=0.npz  -> shape (150, 5641) = (6×25) × 5641
# [social_projections_seq=task1-train-mouse005_task1_annotator1_persp=1.npz] components=6, frames=5641 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse005_task1_annotator1_persp=1.npz  -> shape (150, 5641) = (6×25) × 5641
# [social_projections_seq=task1-train-mouse006_task1_annotator1_persp=0.npz] components=6, frames=3029 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse006_task1_annotator1_persp=0.npz  -> shape (150, 3029) = (6×25) × 3029
# [social_projections_seq=task1-train-mouse006_task1_annotator1_persp=1.npz] components=6, frames=3029 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse006_task1_annotator1_persp=1.npz  -> shape (150, 3029) = (6×25) × 3029
# [social_projections_seq=task1-train-mouse007_task1_annotator1_persp=0.npz] components=6, frames=10025 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse007_task1_annotator1_persp=0.npz  -> shape (150, 10025) = (6×25) × 10025
# [social_projections_seq=task1-train-mouse007_task1_annotator1_persp=1.npz] components=6, frames=10025 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse007_task1_annotator1_persp=1.npz  -> shape (150, 10025) = (6×25) × 10025
# [social_projections_seq=task1-train-mouse008_task1_annotator1_persp=0.npz] components=6, frames=11407 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse008_task1_annotator1_persp=0.npz  -> shape (150, 11407) = (6×25) × 11407
# [social_projections_seq=task1-train-mouse008_task1_annotator1_persp=1.npz] components=6, frames=11407 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse008_task1_annotator1_persp=1.npz  -> shape (150, 11407) = (6×25) × 11407
# [social_projections_seq=task1-train-mouse009_task1_annotator1_persp=0.npz] components=6, frames=8332 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse009_task1_annotator1_persp=0.npz  -> shape (150, 8332) = (6×25) × 8332
# [social_projections_seq=task1-train-mouse009_task1_annotator1_persp=1.npz] components=6, frames=8332 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse009_task1_annotator1_persp=1.npz  -> shape (150, 8332) = (6×25) × 8332
# [social_projections_seq=task1-train-mouse010_task1_annotator1_persp=0.npz] components=6, frames=8666 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse010_task1_annotator1_persp=0.npz  -> shape (150, 8666) = (6×25) × 8666
# [social_projections_seq=task1-train-mouse010_task1_annotator1_persp=1.npz] components=6, frames=8666 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse010_task1_annotator1_persp=1.npz  -> shape (150, 8666) = (6×25) × 8666
# [social_projections_seq=task1-train-mouse011_task1_annotator1_persp=0.npz] components=6, frames=4260 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse011_task1_annotator1_persp=0.npz  -> shape (150, 4260) = (6×25) × 4260
# [social_projections_seq=task1-train-mouse011_task1_annotator1_persp=1.npz] components=6, frames=4260 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse011_task1_annotator1_persp=1.npz  -> shape (150, 4260) = (6×25) × 4260
# [social_projections_seq=task1-train-mouse012_task1_annotator1_persp=0.npz] components=6, frames=7190 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse012_task1_annotator1_persp=0.npz  -> shape (150, 7190) = (6×25) × 7190
# [social_projections_seq=task1-train-mouse012_task1_annotator1_persp=1.npz] components=6, frames=7190 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse012_task1_annotator1_persp=1.npz  -> shape (150, 7190) = (6×25) × 7190
# [social_projections_seq=task1-train-mouse013_task1_annotator1_persp=0.npz] components=6, frames=2263 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse013_task1_annotator1_persp=0.npz  -> shape (150, 2263) = (6×25) × 2263
# [social_projections_seq=task1-train-mouse013_task1_annotator1_persp=1.npz] components=6, frames=2263 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse013_task1_annotator1_persp=1.npz  -> shape (150, 2263) = (6×25) × 2263
# [social_projections_seq=task1-train-mouse014_task1_annotator1_persp=0.npz] components=6, frames=8994 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse014_task1_annotator1_persp=0.npz  -> shape (150, 8994) = (6×25) × 8994
# [social_projections_seq=task1-train-mouse014_task1_annotator1_persp=1.npz] components=6, frames=8994 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse014_task1_annotator1_persp=1.npz  -> shape (150, 8994) = (6×25) × 8994
# [social_projections_seq=task1-train-mouse015_task1_annotator1_persp=0.npz] components=6, frames=7406 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse015_task1_annotator1_persp=0.npz  -> shape (150, 7406) = (6×25) × 7406
# [social_projections_seq=task1-train-mouse015_task1_annotator1_persp=1.npz] components=6, frames=7406 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse015_task1_annotator1_persp=1.npz  -> shape (150, 7406) = (6×25) × 7406
# [social_projections_seq=task1-train-mouse016_task1_annotator1_persp=0.npz] components=6, frames=3692 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse016_task1_annotator1_persp=0.npz  -> shape (150, 3692) = (6×25) × 3692
# [social_projections_seq=task1-train-mouse016_task1_annotator1_persp=1.npz] components=6, frames=3692 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse016_task1_annotator1_persp=1.npz  -> shape (150, 3692) = (6×25) × 3692
# [social_projections_seq=task1-train-mouse017_task1_annotator1_persp=0.npz] components=6, frames=6200 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse017_task1_annotator1_persp=0.npz  -> shape (150, 6200) = (6×25) × 6200
# [social_projections_seq=task1-train-mouse017_task1_annotator1_persp=1.npz] components=6, frames=6200 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse017_task1_annotator1_persp=1.npz  -> shape (150, 6200) = (6×25) × 6200
# [social_projections_seq=task1-train-mouse018_task1_annotator1_persp=0.npz] components=6, frames=6127 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse018_task1_annotator1_persp=0.npz  -> shape (150, 6127) = (6×25) × 6127
# [social_projections_seq=task1-train-mouse018_task1_annotator1_persp=1.npz] components=6, frames=6127 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse018_task1_annotator1_persp=1.npz  -> shape (150, 6127) = (6×25) × 6127
# [social_projections_seq=task1-train-mouse019_task1_annotator1_persp=0.npz] components=6, frames=4461 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse019_task1_annotator1_persp=0.npz  -> shape (150, 4461) = (6×25) × 4461
# [social_projections_seq=task1-train-mouse019_task1_annotator1_persp=1.npz] components=6, frames=4461 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse019_task1_annotator1_persp=1.npz  -> shape (150, 4461) = (6×25) × 4461
# [social_projections_seq=task1-train-mouse020_task1_annotator1_persp=0.npz] components=6, frames=3714 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse020_task1_annotator1_persp=0.npz  -> shape (150, 3714) = (6×25) × 3714
# [social_projections_seq=task1-train-mouse020_task1_annotator1_persp=1.npz] components=6, frames=3714 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse020_task1_annotator1_persp=1.npz  -> shape (150, 3714) = (6×25) × 3714
# [social_projections_seq=task1-train-mouse021_task1_annotator1_persp=0.npz] components=6, frames=11322 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse021_task1_annotator1_persp=0.npz  -> shape (150, 11322) = (6×25) × 11322
# [social_projections_seq=task1-train-mouse021_task1_annotator1_persp=1.npz] components=6, frames=11322 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse021_task1_annotator1_persp=1.npz  -> shape (150, 11322) = (6×25) × 11322
# [social_projections_seq=task1-train-mouse022_task1_annotator1_persp=0.npz] components=6, frames=9792 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse022_task1_annotator1_persp=0.npz  -> shape (150, 9792) = (6×25) × 9792
# [social_projections_seq=task1-train-mouse022_task1_annotator1_persp=1.npz] components=6, frames=9792 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse022_task1_annotator1_persp=1.npz  -> shape (150, 9792) = (6×25) × 9792
# [social_projections_seq=task1-train-mouse023_task1_annotator1_persp=0.npz] components=6, frames=1838 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse023_task1_annotator1_persp=0.npz  -> shape (150, 1838) = (6×25) × 1838
# [social_projections_seq=task1-train-mouse023_task1_annotator1_persp=1.npz] components=6, frames=1838 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse023_task1_annotator1_persp=1.npz  -> shape (150, 1838) = (6×25) × 1838
# [social_projections_seq=task1-train-mouse024_task1_annotator1_persp=0.npz] components=6, frames=8899 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse024_task1_annotator1_persp=0.npz  -> shape (150, 8899) = (6×25) × 8899
# [social_projections_seq=task1-train-mouse024_task1_annotator1_persp=1.npz] components=6, frames=8899 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse024_task1_annotator1_persp=1.npz  -> shape (150, 8899) = (6×25) × 8899
# [social_projections_seq=task1-train-mouse025_task1_annotator1_persp=0.npz] components=6, frames=3770 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse025_task1_annotator1_persp=0.npz  -> shape (150, 3770) = (6×25) × 3770
# [social_projections_seq=task1-train-mouse025_task1_annotator1_persp=1.npz] components=6, frames=3770 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse025_task1_annotator1_persp=1.npz  -> shape (150, 3770) = (6×25) × 3770
# [social_projections_seq=task1-train-mouse026_task1_annotator1_persp=0.npz] components=6, frames=3632 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse026_task1_annotator1_persp=0.npz  -> shape (150, 3632) = (6×25) × 3632
# [social_projections_seq=task1-train-mouse026_task1_annotator1_persp=1.npz] components=6, frames=3632 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse026_task1_annotator1_persp=1.npz  -> shape (150, 3632) = (6×25) × 3632
# [social_projections_seq=task1-train-mouse027_task1_annotator1_persp=0.npz] components=6, frames=1987 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse027_task1_annotator1_persp=0.npz  -> shape (150, 1987) = (6×25) × 1987
# [social_projections_seq=task1-train-mouse027_task1_annotator1_persp=1.npz] components=6, frames=1987 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse027_task1_annotator1_persp=1.npz  -> shape (150, 1987) = (6×25) × 1987
# [social_projections_seq=task1-train-mouse028_task1_annotator1_persp=0.npz] components=6, frames=1036 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse028_task1_annotator1_persp=0.npz  -> shape (150, 1036) = (6×25) × 1036
# [social_projections_seq=task1-train-mouse028_task1_annotator1_persp=1.npz] components=6, frames=1036 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse028_task1_annotator1_persp=1.npz  -> shape (150, 1036) = (6×25) × 1036
# [social_projections_seq=task1-train-mouse029_task1_annotator1_persp=0.npz] components=6, frames=3041 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse029_task1_annotator1_persp=0.npz  -> shape (150, 3041) = (6×25) × 3041
# [social_projections_seq=task1-train-mouse029_task1_annotator1_persp=1.npz] components=6, frames=3041 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse029_task1_annotator1_persp=1.npz  -> shape (150, 3041) = (6×25) × 3041
# [social_projections_seq=task1-train-mouse030_task1_annotator1_persp=0.npz] components=6, frames=1607 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse030_task1_annotator1_persp=0.npz  -> shape (150, 1607) = (6×25) × 1607
# [social_projections_seq=task1-train-mouse030_task1_annotator1_persp=1.npz] components=6, frames=1607 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse030_task1_annotator1_persp=1.npz  -> shape (150, 1607) = (6×25) × 1607
# [social_projections_seq=task1-train-mouse031_task1_annotator1_persp=0.npz] components=6, frames=5096 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse031_task1_annotator1_persp=0.npz  -> shape (150, 5096) = (6×25) × 5096
# [social_projections_seq=task1-train-mouse031_task1_annotator1_persp=1.npz] components=6, frames=5096 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse031_task1_annotator1_persp=1.npz  -> shape (150, 5096) = (6×25) × 5096
# [social_projections_seq=task1-train-mouse032_task1_annotator1_persp=0.npz] components=6, frames=5763 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse032_task1_annotator1_persp=0.npz  -> shape (150, 5763) = (6×25) × 5763
# [social_projections_seq=task1-train-mouse032_task1_annotator1_persp=1.npz] components=6, frames=5763 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse032_task1_annotator1_persp=1.npz  -> shape (150, 5763) = (6×25) × 5763
# [social_projections_seq=task1-train-mouse033_task1_annotator1_persp=0.npz] components=6, frames=2497 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse033_task1_annotator1_persp=0.npz  -> shape (150, 2497) = (6×25) × 2497
# [social_projections_seq=task1-train-mouse033_task1_annotator1_persp=1.npz] components=6, frames=2497 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse033_task1_annotator1_persp=1.npz  -> shape (150, 2497) = (6×25) × 2497
# [social_projections_seq=task1-train-mouse034_task1_annotator1_persp=0.npz] components=6, frames=1062 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse034_task1_annotator1_persp=0.npz  -> shape (150, 1062) = (6×25) × 1062
# [social_projections_seq=task1-train-mouse034_task1_annotator1_persp=1.npz] components=6, frames=1062 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse034_task1_annotator1_persp=1.npz  -> shape (150, 1062) = (6×25) × 1062
# [social_projections_seq=task1-train-mouse035_task1_annotator1_persp=0.npz] components=6, frames=4879 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse035_task1_annotator1_persp=0.npz  -> shape (150, 4879) = (6×25) × 4879
# [social_projections_seq=task1-train-mouse035_task1_annotator1_persp=1.npz] components=6, frames=4879 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse035_task1_annotator1_persp=1.npz  -> shape (150, 4879) = (6×25) × 4879
# [social_projections_seq=task1-train-mouse036_task1_annotator1_persp=0.npz] components=6, frames=96 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse036_task1_annotator1_persp=0.npz  -> shape (150, 96) = (6×25) × 96
# [social_projections_seq=task1-train-mouse036_task1_annotator1_persp=1.npz] components=6, frames=96 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse036_task1_annotator1_persp=1.npz  -> shape (150, 96) = (6×25) × 96
# [social_projections_seq=task1-train-mouse037_task1_annotator1_persp=0.npz] components=6, frames=5133 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse037_task1_annotator1_persp=0.npz  -> shape (150, 5133) = (6×25) × 5133
# [social_projections_seq=task1-train-mouse037_task1_annotator1_persp=1.npz] components=6, frames=5133 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse037_task1_annotator1_persp=1.npz  -> shape (150, 5133) = (6×25) × 5133
# [social_projections_seq=task1-train-mouse038_task1_annotator1_persp=0.npz] components=6, frames=2796 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse038_task1_annotator1_persp=0.npz  -> shape (150, 2796) = (6×25) × 2796
# [social_projections_seq=task1-train-mouse038_task1_annotator1_persp=1.npz] components=6, frames=2796 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse038_task1_annotator1_persp=1.npz  -> shape (150, 2796) = (6×25) × 2796
# [social_projections_seq=task1-train-mouse039_task1_annotator1_persp=0.npz] components=6, frames=3188 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse039_task1_annotator1_persp=0.npz  -> shape (150, 3188) = (6×25) × 3188
# [social_projections_seq=task1-train-mouse039_task1_annotator1_persp=1.npz] components=6, frames=3188 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse039_task1_annotator1_persp=1.npz  -> shape (150, 3188) = (6×25) × 3188
# [social_projections_seq=task1-train-mouse040_task1_annotator1_persp=0.npz] components=6, frames=2643 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse040_task1_annotator1_persp=0.npz  -> shape (150, 2643) = (6×25) × 2643
# [social_projections_seq=task1-train-mouse040_task1_annotator1_persp=1.npz] components=6, frames=2643 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse040_task1_annotator1_persp=1.npz  -> shape (150, 2643) = (6×25) × 2643
# [social_projections_seq=task1-train-mouse041_task1_annotator1_persp=0.npz] components=6, frames=1440 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse041_task1_annotator1_persp=0.npz  -> shape (150, 1440) = (6×25) × 1440
# [social_projections_seq=task1-train-mouse041_task1_annotator1_persp=1.npz] components=6, frames=1440 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse041_task1_annotator1_persp=1.npz  -> shape (150, 1440) = (6×25) × 1440
# [social_projections_seq=task1-train-mouse042_task1_annotator1_persp=0.npz] components=6, frames=3351 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse042_task1_annotator1_persp=0.npz  -> shape (150, 3351) = (6×25) × 3351
# [social_projections_seq=task1-train-mouse042_task1_annotator1_persp=1.npz] components=6, frames=3351 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse042_task1_annotator1_persp=1.npz  -> shape (150, 3351) = (6×25) × 3351
# [social_projections_seq=task1-train-mouse043_task1_annotator1_persp=0.npz] components=6, frames=974 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse043_task1_annotator1_persp=0.npz  -> shape (150, 974) = (6×25) × 974
# [social_projections_seq=task1-train-mouse043_task1_annotator1_persp=1.npz] components=6, frames=974 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse043_task1_annotator1_persp=1.npz  -> shape (150, 974) = (6×25) × 974
# [social_projections_seq=task1-train-mouse044_task1_annotator1_persp=0.npz] components=6, frames=3394 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse044_task1_annotator1_persp=0.npz  -> shape (150, 3394) = (6×25) × 3394
# [social_projections_seq=task1-train-mouse044_task1_annotator1_persp=1.npz] components=6, frames=3394 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse044_task1_annotator1_persp=1.npz  -> shape (150, 3394) = (6×25) × 3394
# [social_projections_seq=task1-train-mouse045_task1_annotator1_persp=0.npz] components=6, frames=2713 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse045_task1_annotator1_persp=0.npz  -> shape (150, 2713) = (6×25) × 2713
# [social_projections_seq=task1-train-mouse045_task1_annotator1_persp=1.npz] components=6, frames=2713 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse045_task1_annotator1_persp=1.npz  -> shape (150, 2713) = (6×25) × 2713
# [social_projections_seq=task1-train-mouse046_task1_annotator1_persp=0.npz] components=6, frames=5065 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse046_task1_annotator1_persp=0.npz  -> shape (150, 5065) = (6×25) × 5065
# [social_projections_seq=task1-train-mouse046_task1_annotator1_persp=1.npz] components=6, frames=5065 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse046_task1_annotator1_persp=1.npz  -> shape (150, 5065) = (6×25) × 5065
# [social_projections_seq=task1-train-mouse047_task1_annotator1_persp=0.npz] components=6, frames=2751 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse047_task1_annotator1_persp=0.npz  -> shape (150, 2751) = (6×25) × 2751
# [social_projections_seq=task1-train-mouse047_task1_annotator1_persp=1.npz] components=6, frames=2751 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse047_task1_annotator1_persp=1.npz  -> shape (150, 2751) = (6×25) × 2751
# [social_projections_seq=task1-train-mouse048_task1_annotator1_persp=0.npz] components=6, frames=1213 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse048_task1_annotator1_persp=0.npz  -> shape (150, 1213) = (6×25) × 1213
# [social_projections_seq=task1-train-mouse048_task1_annotator1_persp=1.npz] components=6, frames=1213 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse048_task1_annotator1_persp=1.npz  -> shape (150, 1213) = (6×25) × 1213
# [social_projections_seq=task1-train-mouse049_task1_annotator1_persp=0.npz] components=6, frames=2885 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse049_task1_annotator1_persp=0.npz  -> shape (150, 2885) = (6×25) × 2885
# [social_projections_seq=task1-train-mouse049_task1_annotator1_persp=1.npz] components=6, frames=2885 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse049_task1_annotator1_persp=1.npz  -> shape (150, 2885) = (6×25) × 2885
# [social_projections_seq=task1-train-mouse050_task1_annotator1_persp=0.npz] components=6, frames=1283 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse050_task1_annotator1_persp=0.npz  -> shape (150, 1283) = (6×25) × 1283
# [social_projections_seq=task1-train-mouse050_task1_annotator1_persp=1.npz] components=6, frames=1283 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse050_task1_annotator1_persp=1.npz  -> shape (150, 1283) = (6×25) × 1283
# [social_projections_seq=task1-train-mouse051_task1_annotator1_persp=0.npz] components=6, frames=17326 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse051_task1_annotator1_persp=0.npz  -> shape (150, 17326) = (6×25) × 17326
# [social_projections_seq=task1-train-mouse051_task1_annotator1_persp=1.npz] components=6, frames=17326 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse051_task1_annotator1_persp=1.npz  -> shape (150, 17326) = (6×25) × 17326
# [social_projections_seq=task1-train-mouse052_task1_annotator1_persp=0.npz] components=6, frames=17946 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse052_task1_annotator1_persp=0.npz  -> shape (150, 17946) = (6×25) × 17946
# [social_projections_seq=task1-train-mouse052_task1_annotator1_persp=1.npz] components=6, frames=17946 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse052_task1_annotator1_persp=1.npz  -> shape (150, 17946) = (6×25) × 17946
# [social_projections_seq=task1-train-mouse053_task1_annotator1_persp=0.npz] components=6, frames=17472 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse053_task1_annotator1_persp=0.npz  -> shape (150, 17472) = (6×25) × 17472
# [social_projections_seq=task1-train-mouse053_task1_annotator1_persp=1.npz] components=6, frames=17472 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse053_task1_annotator1_persp=1.npz  -> shape (150, 17472) = (6×25) × 17472
# [social_projections_seq=task1-train-mouse054_task1_annotator1_persp=0.npz] components=6, frames=17319 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse054_task1_annotator1_persp=0.npz  -> shape (150, 17319) = (6×25) × 17319
# [social_projections_seq=task1-train-mouse054_task1_annotator1_persp=1.npz] components=6, frames=17319 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse054_task1_annotator1_persp=1.npz  -> shape (150, 17319) = (6×25) × 17319
# [social_projections_seq=task1-train-mouse055_task1_annotator1_persp=0.npz] components=6, frames=17637 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse055_task1_annotator1_persp=0.npz  -> shape (150, 17637) = (6×25) × 17637
# [social_projections_seq=task1-train-mouse055_task1_annotator1_persp=1.npz] components=6, frames=17637 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse055_task1_annotator1_persp=1.npz  -> shape (150, 17637) = (6×25) × 17637
# [social_projections_seq=task1-train-mouse056_task1_annotator1_persp=0.npz] components=6, frames=16420 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse056_task1_annotator1_persp=0.npz  -> shape (150, 16420) = (6×25) × 16420
# [social_projections_seq=task1-train-mouse056_task1_annotator1_persp=1.npz] components=6, frames=16420 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse056_task1_annotator1_persp=1.npz  -> shape (150, 16420) = (6×25) × 16420
# [social_projections_seq=task1-train-mouse057_task1_annotator1_persp=0.npz] components=6, frames=18617 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse057_task1_annotator1_persp=0.npz  -> shape (150, 18617) = (6×25) × 18617
# [social_projections_seq=task1-train-mouse057_task1_annotator1_persp=1.npz] components=6, frames=18617 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse057_task1_annotator1_persp=1.npz  -> shape (150, 18617) = (6×25) × 18617
# [social_projections_seq=task1-train-mouse058_task1_annotator1_persp=0.npz] components=6, frames=18423 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse058_task1_annotator1_persp=0.npz  -> shape (150, 18423) = (6×25) × 18423
# [social_projections_seq=task1-train-mouse058_task1_annotator1_persp=1.npz] components=6, frames=18423 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse058_task1_annotator1_persp=1.npz  -> shape (150, 18423) = (6×25) × 18423
# [social_projections_seq=task1-train-mouse059_task1_annotator1_persp=0.npz] components=6, frames=5495 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse059_task1_annotator1_persp=0.npz  -> shape (150, 5495) = (6×25) × 5495
# [social_projections_seq=task1-train-mouse059_task1_annotator1_persp=1.npz] components=6, frames=5495 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse059_task1_annotator1_persp=1.npz  -> shape (150, 5495) = (6×25) × 5495
# [social_projections_seq=task1-train-mouse060_task1_annotator1_persp=0.npz] components=6, frames=4755 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse060_task1_annotator1_persp=0.npz  -> shape (150, 4755) = (6×25) × 4755
# [social_projections_seq=task1-train-mouse060_task1_annotator1_persp=1.npz] components=6, frames=4755 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse060_task1_annotator1_persp=1.npz  -> shape (150, 4755) = (6×25) × 4755
# [social_projections_seq=task1-train-mouse061_task1_annotator1_persp=0.npz] components=6, frames=3996 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse061_task1_annotator1_persp=0.npz  -> shape (150, 3996) = (6×25) × 3996
# [social_projections_seq=task1-train-mouse061_task1_annotator1_persp=1.npz] components=6, frames=3996 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse061_task1_annotator1_persp=1.npz  -> shape (150, 3996) = (6×25) × 3996
# [social_projections_seq=task1-train-mouse062_task1_annotator1_persp=0.npz] components=6, frames=7754 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse062_task1_annotator1_persp=0.npz  -> shape (150, 7754) = (6×25) × 7754
# [social_projections_seq=task1-train-mouse062_task1_annotator1_persp=1.npz] components=6, frames=7754 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse062_task1_annotator1_persp=1.npz  -> shape (150, 7754) = (6×25) × 7754
# [social_projections_seq=task1-train-mouse063_task1_annotator1_persp=0.npz] components=6, frames=13170 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse063_task1_annotator1_persp=0.npz  -> shape (150, 13170) = (6×25) × 13170
# [social_projections_seq=task1-train-mouse063_task1_annotator1_persp=1.npz] components=6, frames=13170 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse063_task1_annotator1_persp=1.npz  -> shape (150, 13170) = (6×25) × 13170
# [social_projections_seq=task1-train-mouse064_task1_annotator1_persp=0.npz] components=6, frames=7150 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse064_task1_annotator1_persp=0.npz  -> shape (150, 7150) = (6×25) × 7150
# [social_projections_seq=task1-train-mouse064_task1_annotator1_persp=1.npz] components=6, frames=7150 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse064_task1_annotator1_persp=1.npz  -> shape (150, 7150) = (6×25) × 7150
# [social_projections_seq=task1-train-mouse065_task1_annotator1_persp=0.npz] components=6, frames=8103 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse065_task1_annotator1_persp=0.npz  -> shape (150, 8103) = (6×25) × 8103
# [social_projections_seq=task1-train-mouse065_task1_annotator1_persp=1.npz] components=6, frames=8103 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse065_task1_annotator1_persp=1.npz  -> shape (150, 8103) = (6×25) × 8103
# [social_projections_seq=task1-train-mouse066_task1_annotator1_persp=0.npz] components=6, frames=7410 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse066_task1_annotator1_persp=0.npz  -> shape (150, 7410) = (6×25) × 7410
# [social_projections_seq=task1-train-mouse066_task1_annotator1_persp=1.npz] components=6, frames=7410 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse066_task1_annotator1_persp=1.npz  -> shape (150, 7410) = (6×25) × 7410
# [social_projections_seq=task1-train-mouse067_task1_annotator1_persp=0.npz] components=6, frames=7024 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse067_task1_annotator1_persp=0.npz  -> shape (150, 7024) = (6×25) × 7024
# [social_projections_seq=task1-train-mouse067_task1_annotator1_persp=1.npz] components=6, frames=7024 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse067_task1_annotator1_persp=1.npz  -> shape (150, 7024) = (6×25) × 7024
# [social_projections_seq=task1-train-mouse068_task1_annotator1_persp=0.npz] components=6, frames=9838 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse068_task1_annotator1_persp=0.npz  -> shape (150, 9838) = (6×25) × 9838
# [social_projections_seq=task1-train-mouse068_task1_annotator1_persp=1.npz] components=6, frames=9838 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse068_task1_annotator1_persp=1.npz  -> shape (150, 9838) = (6×25) × 9838
# [social_projections_seq=task1-train-mouse069_task1_annotator1_persp=0.npz] components=6, frames=11431 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse069_task1_annotator1_persp=0.npz  -> shape (150, 11431) = (6×25) × 11431
# [social_projections_seq=task1-train-mouse069_task1_annotator1_persp=1.npz] components=6, frames=11431 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse069_task1_annotator1_persp=1.npz  -> shape (150, 11431) = (6×25) × 11431
# [social_projections_seq=task1-train-mouse070_task1_annotator1_persp=0.npz] components=6, frames=12537 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse070_task1_annotator1_persp=0.npz  -> shape (150, 12537) = (6×25) × 12537
# [social_projections_seq=task1-train-mouse070_task1_annotator1_persp=1.npz] components=6, frames=12537 -> computing wavelets...
# [SAVE] wavelet_social_seq=task1-train-mouse070_task1_annotator1_persp=1.npz  -> shape (150, 12537) = (6×25) × 12537
# [social_projections_seq=task3-approach-test-mouse004_task3_approach_persp=0.npz] components=6, frames=7433 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse004_task3_approach_persp=0.npz  -> shape (150, 7433) = (6×25) × 7433
# [social_projections_seq=task3-approach-test-mouse004_task3_approach_persp=1.npz] components=6, frames=7433 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse004_task3_approach_persp=1.npz  -> shape (150, 7433) = (6×25) × 7433
# [social_projections_seq=task3-approach-test-mouse005_task3_approach_persp=0.npz] components=6, frames=5641 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse005_task3_approach_persp=0.npz  -> shape (150, 5641) = (6×25) × 5641
# [social_projections_seq=task3-approach-test-mouse005_task3_approach_persp=1.npz] components=6, frames=5641 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse005_task3_approach_persp=1.npz  -> shape (150, 5641) = (6×25) × 5641
# [social_projections_seq=task3-approach-test-mouse006_task3_approach_persp=0.npz] components=6, frames=3029 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse006_task3_approach_persp=0.npz  -> shape (150, 3029) = (6×25) × 3029
# [social_projections_seq=task3-approach-test-mouse006_task3_approach_persp=1.npz] components=6, frames=3029 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse006_task3_approach_persp=1.npz  -> shape (150, 3029) = (6×25) × 3029
# [social_projections_seq=task3-approach-test-mouse007_task3_approach_persp=0.npz] components=6, frames=10025 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse007_task3_approach_persp=0.npz  -> shape (150, 10025) = (6×25) × 10025
# [social_projections_seq=task3-approach-test-mouse007_task3_approach_persp=1.npz] components=6, frames=10025 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse007_task3_approach_persp=1.npz  -> shape (150, 10025) = (6×25) × 10025
# [social_projections_seq=task3-approach-test-mouse008_task3_approach_persp=0.npz] components=6, frames=11407 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse008_task3_approach_persp=0.npz  -> shape (150, 11407) = (6×25) × 11407
# [social_projections_seq=task3-approach-test-mouse008_task3_approach_persp=1.npz] components=6, frames=11407 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse008_task3_approach_persp=1.npz  -> shape (150, 11407) = (6×25) × 11407
# [social_projections_seq=task3-approach-test-mouse009_task3_approach_persp=0.npz] components=6, frames=8332 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse009_task3_approach_persp=0.npz  -> shape (150, 8332) = (6×25) × 8332
# [social_projections_seq=task3-approach-test-mouse009_task3_approach_persp=1.npz] components=6, frames=8332 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse009_task3_approach_persp=1.npz  -> shape (150, 8332) = (6×25) × 8332
# [social_projections_seq=task3-approach-test-mouse010_task3_approach_persp=0.npz] components=6, frames=8666 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse010_task3_approach_persp=0.npz  -> shape (150, 8666) = (6×25) × 8666
# [social_projections_seq=task3-approach-test-mouse010_task3_approach_persp=1.npz] components=6, frames=8666 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse010_task3_approach_persp=1.npz  -> shape (150, 8666) = (6×25) × 8666
# [social_projections_seq=task3-approach-test-mouse011_task3_approach_persp=0.npz] components=6, frames=3692 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse011_task3_approach_persp=0.npz  -> shape (150, 3692) = (6×25) × 3692
# [social_projections_seq=task3-approach-test-mouse011_task3_approach_persp=1.npz] components=6, frames=3692 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse011_task3_approach_persp=1.npz  -> shape (150, 3692) = (6×25) × 3692
# [social_projections_seq=task3-approach-test-mouse012_task3_approach_persp=0.npz] components=6, frames=6127 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse012_task3_approach_persp=0.npz  -> shape (150, 6127) = (6×25) × 6127
# [social_projections_seq=task3-approach-test-mouse012_task3_approach_persp=1.npz] components=6, frames=6127 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse012_task3_approach_persp=1.npz  -> shape (150, 6127) = (6×25) × 6127
# [social_projections_seq=task3-approach-test-mouse013_task3_approach_persp=0.npz] components=6, frames=8899 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse013_task3_approach_persp=0.npz  -> shape (150, 8899) = (6×25) × 8899
# [social_projections_seq=task3-approach-test-mouse013_task3_approach_persp=1.npz] components=6, frames=8899 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-approach-test-mouse013_task3_approach_persp=1.npz  -> shape (150, 8899) = (6×25) × 8899
# ...
# [social_projections_seq=task3-sniff_face-test-mouse026_task3_sniff_face_persp=1.npz] components=6, frames=3632 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse026_task3_sniff_face_persp=1.npz  -> shape (150, 3632) = (6×25) × 3632
# [social_projections_seq=task3-sniff_face-test-mouse027_task3_sniff_face_persp=0.npz] components=6, frames=1987 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse027_task3_sniff_face_persp=0.npz  -> shape (150, 1987) = (6×25) × 1987
# [social_projections_seq=task3-sniff_face-test-mouse027_task3_sniff_face_persp=1.npz] components=6, frames=1987 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse027_task3_sniff_face_persp=1.npz  -> shape (150, 1987) = (6×25) × 1987
# [social_projections_seq=task3-sniff_face-test-mouse028_task3_sniff_face_persp=0.npz] components=6, frames=1036 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse028_task3_sniff_face_persp=0.npz  -> shape (150, 1036) = (6×25) × 1036
# [social_projections_seq=task3-sniff_face-test-mouse028_task3_sniff_face_persp=1.npz] components=6, frames=1036 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse028_task3_sniff_face_persp=1.npz  -> shape (150, 1036) = (6×25) × 1036
# [social_projections_seq=task3-sniff_face-test-mouse029_task3_sniff_face_persp=0.npz] components=6, frames=3041 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse029_task3_sniff_face_persp=0.npz  -> shape (150, 3041) = (6×25) × 3041
# [social_projections_seq=task3-sniff_face-test-mouse029_task3_sniff_face_persp=1.npz] components=6, frames=3041 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse029_task3_sniff_face_persp=1.npz  -> shape (150, 3041) = (6×25) × 3041
# [social_projections_seq=task3-sniff_face-test-mouse030_task3_sniff_face_persp=0.npz] components=6, frames=1607 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse030_task3_sniff_face_persp=0.npz  -> shape (150, 1607) = (6×25) × 1607
# [social_projections_seq=task3-sniff_face-test-mouse030_task3_sniff_face_persp=1.npz] components=6, frames=1607 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse030_task3_sniff_face_persp=1.npz  -> shape (150, 1607) = (6×25) × 1607
# [social_projections_seq=task3-sniff_face-test-mouse031_task3_sniff_face_persp=0.npz] components=6, frames=5096 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse031_task3_sniff_face_persp=0.npz  -> shape (150, 5096) = (6×25) × 5096
# [social_projections_seq=task3-sniff_face-test-mouse031_task3_sniff_face_persp=1.npz] components=6, frames=5096 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse031_task3_sniff_face_persp=1.npz  -> shape (150, 5096) = (6×25) × 5096
# [social_projections_seq=task3-sniff_face-test-mouse032_task3_sniff_face_persp=0.npz] components=6, frames=5763 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse032_task3_sniff_face_persp=0.npz  -> shape (150, 5763) = (6×25) × 5763
# [social_projections_seq=task3-sniff_face-test-mouse032_task3_sniff_face_persp=1.npz] components=6, frames=5763 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse032_task3_sniff_face_persp=1.npz  -> shape (150, 5763) = (6×25) × 5763
# [social_projections_seq=task3-sniff_face-test-mouse033_task3_sniff_face_persp=0.npz] components=6, frames=2497 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse033_task3_sniff_face_persp=0.npz  -> shape (150, 2497) = (6×25) × 2497
# [social_projections_seq=task3-sniff_face-test-mouse033_task3_sniff_face_persp=1.npz] components=6, frames=2497 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse033_task3_sniff_face_persp=1.npz  -> shape (150, 2497) = (6×25) × 2497
# [social_projections_seq=task3-sniff_face-test-mouse034_task3_sniff_face_persp=0.npz] components=6, frames=4879 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse034_task3_sniff_face_persp=0.npz  -> shape (150, 4879) = (6×25) × 4879
# [social_projections_seq=task3-sniff_face-test-mouse034_task3_sniff_face_persp=1.npz] components=6, frames=4879 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse034_task3_sniff_face_persp=1.npz  -> shape (150, 4879) = (6×25) × 4879
# [social_projections_seq=task3-sniff_face-test-mouse035_task3_sniff_face_persp=0.npz] components=6, frames=5133 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse035_task3_sniff_face_persp=0.npz  -> shape (150, 5133) = (6×25) × 5133
# [social_projections_seq=task3-sniff_face-test-mouse035_task3_sniff_face_persp=1.npz] components=6, frames=5133 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse035_task3_sniff_face_persp=1.npz  -> shape (150, 5133) = (6×25) × 5133
# [social_projections_seq=task3-sniff_face-test-mouse036_task3_sniff_face_persp=0.npz] components=6, frames=2796 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse036_task3_sniff_face_persp=0.npz  -> shape (150, 2796) = (6×25) × 2796
# [social_projections_seq=task3-sniff_face-test-mouse036_task3_sniff_face_persp=1.npz] components=6, frames=2796 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse036_task3_sniff_face_persp=1.npz  -> shape (150, 2796) = (6×25) × 2796
# [social_projections_seq=task3-sniff_face-test-mouse037_task3_sniff_face_persp=0.npz] components=6, frames=3188 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse037_task3_sniff_face_persp=0.npz  -> shape (150, 3188) = (6×25) × 3188
# [social_projections_seq=task3-sniff_face-test-mouse037_task3_sniff_face_persp=1.npz] components=6, frames=3188 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse037_task3_sniff_face_persp=1.npz  -> shape (150, 3188) = (6×25) × 3188
# [social_projections_seq=task3-sniff_face-test-mouse038_task3_sniff_face_persp=0.npz] components=6, frames=2643 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse038_task3_sniff_face_persp=0.npz  -> shape (150, 2643) = (6×25) × 2643
# [social_projections_seq=task3-sniff_face-test-mouse038_task3_sniff_face_persp=1.npz] components=6, frames=2643 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse038_task3_sniff_face_persp=1.npz  -> shape (150, 2643) = (6×25) × 2643
# [social_projections_seq=task3-sniff_face-test-mouse039_task3_sniff_face_persp=0.npz] components=6, frames=3351 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse039_task3_sniff_face_persp=0.npz  -> shape (150, 3351) = (6×25) × 3351
# [social_projections_seq=task3-sniff_face-test-mouse039_task3_sniff_face_persp=1.npz] components=6, frames=3351 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse039_task3_sniff_face_persp=1.npz  -> shape (150, 3351) = (6×25) × 3351
# [social_projections_seq=task3-sniff_face-test-mouse040_task3_sniff_face_persp=0.npz] components=6, frames=974 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse040_task3_sniff_face_persp=0.npz  -> shape (150, 974) = (6×25) × 974
# [social_projections_seq=task3-sniff_face-test-mouse040_task3_sniff_face_persp=1.npz] components=6, frames=974 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse040_task3_sniff_face_persp=1.npz  -> shape (150, 974) = (6×25) × 974
# [social_projections_seq=task3-sniff_face-test-mouse041_task3_sniff_face_persp=0.npz] components=6, frames=3394 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse041_task3_sniff_face_persp=0.npz  -> shape (150, 3394) = (6×25) × 3394
# [social_projections_seq=task3-sniff_face-test-mouse041_task3_sniff_face_persp=1.npz] components=6, frames=3394 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse041_task3_sniff_face_persp=1.npz  -> shape (150, 3394) = (6×25) × 3394
# [social_projections_seq=task3-sniff_face-test-mouse042_task3_sniff_face_persp=0.npz] components=6, frames=5065 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse042_task3_sniff_face_persp=0.npz  -> shape (150, 5065) = (6×25) × 5065
# [social_projections_seq=task3-sniff_face-test-mouse042_task3_sniff_face_persp=1.npz] components=6, frames=5065 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse042_task3_sniff_face_persp=1.npz  -> shape (150, 5065) = (6×25) × 5065
# [social_projections_seq=task3-sniff_face-test-mouse043_task3_sniff_face_persp=0.npz] components=6, frames=2751 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse043_task3_sniff_face_persp=0.npz  -> shape (150, 2751) = (6×25) × 2751
# [social_projections_seq=task3-sniff_face-test-mouse043_task3_sniff_face_persp=1.npz] components=6, frames=2751 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse043_task3_sniff_face_persp=1.npz  -> shape (150, 2751) = (6×25) × 2751
# [social_projections_seq=task3-sniff_face-test-mouse044_task3_sniff_face_persp=0.npz] components=6, frames=1213 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse044_task3_sniff_face_persp=0.npz  -> shape (150, 1213) = (6×25) × 1213
# [social_projections_seq=task3-sniff_face-test-mouse044_task3_sniff_face_persp=1.npz] components=6, frames=1213 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse044_task3_sniff_face_persp=1.npz  -> shape (150, 1213) = (6×25) × 1213
# [social_projections_seq=task3-sniff_face-test-mouse045_task3_sniff_face_persp=0.npz] components=6, frames=2885 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse045_task3_sniff_face_persp=0.npz  -> shape (150, 2885) = (6×25) × 2885
# [social_projections_seq=task3-sniff_face-test-mouse045_task3_sniff_face_persp=1.npz] components=6, frames=2885 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse045_task3_sniff_face_persp=1.npz  -> shape (150, 2885) = (6×25) × 2885
# [social_projections_seq=task3-sniff_face-test-mouse046_task3_sniff_face_persp=0.npz] components=6, frames=3996 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse046_task3_sniff_face_persp=0.npz  -> shape (150, 3996) = (6×25) × 3996
# [social_projections_seq=task3-sniff_face-test-mouse046_task3_sniff_face_persp=1.npz] components=6, frames=3996 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse046_task3_sniff_face_persp=1.npz  -> shape (150, 3996) = (6×25) × 3996
# [social_projections_seq=task3-sniff_face-test-mouse047_task3_sniff_face_persp=0.npz] components=6, frames=7754 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse047_task3_sniff_face_persp=0.npz  -> shape (150, 7754) = (6×25) × 7754
# [social_projections_seq=task3-sniff_face-test-mouse047_task3_sniff_face_persp=1.npz] components=6, frames=7754 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse047_task3_sniff_face_persp=1.npz  -> shape (150, 7754) = (6×25) × 7754
# [social_projections_seq=task3-sniff_face-test-mouse048_task3_sniff_face_persp=0.npz] components=6, frames=13170 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse048_task3_sniff_face_persp=0.npz  -> shape (150, 13170) = (6×25) × 13170
# [social_projections_seq=task3-sniff_face-test-mouse048_task3_sniff_face_persp=1.npz] components=6, frames=13170 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse048_task3_sniff_face_persp=1.npz  -> shape (150, 13170) = (6×25) × 13170
# [social_projections_seq=task3-sniff_face-test-mouse049_task3_sniff_face_persp=0.npz] components=6, frames=7150 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse049_task3_sniff_face_persp=0.npz  -> shape (150, 7150) = (6×25) × 7150
# [social_projections_seq=task3-sniff_face-test-mouse049_task3_sniff_face_persp=1.npz] components=6, frames=7150 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse049_task3_sniff_face_persp=1.npz  -> shape (150, 7150) = (6×25) × 7150
# [social_projections_seq=task3-sniff_face-test-mouse050_task3_sniff_face_persp=0.npz] components=6, frames=8103 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse050_task3_sniff_face_persp=0.npz  -> shape (150, 8103) = (6×25) × 8103
# [social_projections_seq=task3-sniff_face-test-mouse050_task3_sniff_face_persp=1.npz] components=6, frames=8103 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-test-mouse050_task3_sniff_face_persp=1.npz  -> shape (150, 8103) = (6×25) × 8103
# [social_projections_seq=task3-sniff_face-train-mouse001_task3_sniff_face_persp=0.npz] components=6, frames=8994 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-train-mouse001_task3_sniff_face_persp=0.npz  -> shape (150, 8994) = (6×25) × 8994
# [social_projections_seq=task3-sniff_face-train-mouse001_task3_sniff_face_persp=1.npz] components=6, frames=8994 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-train-mouse001_task3_sniff_face_persp=1.npz  -> shape (150, 8994) = (6×25) × 8994
# [social_projections_seq=task3-sniff_face-train-mouse002_task3_sniff_face_persp=0.npz] components=6, frames=5495 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-train-mouse002_task3_sniff_face_persp=0.npz  -> shape (150, 5495) = (6×25) × 5495
# [social_projections_seq=task3-sniff_face-train-mouse002_task3_sniff_face_persp=1.npz] components=6, frames=5495 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-train-mouse002_task3_sniff_face_persp=1.npz  -> shape (150, 5495) = (6×25) × 5495
# [social_projections_seq=task3-sniff_face-train-mouse003_task3_sniff_face_persp=0.npz] components=6, frames=4755 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-train-mouse003_task3_sniff_face_persp=0.npz  -> shape (150, 4755) = (6×25) × 4755
# [social_projections_seq=task3-sniff_face-train-mouse003_task3_sniff_face_persp=1.npz] components=6, frames=4755 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-sniff_face-train-mouse003_task3_sniff_face_persp=1.npz  -> shape (150, 4755) = (6×25) × 4755
# [social_projections_seq=task3-whiterearing-test-mouse003_task3_whiterearing_persp=0.npz] components=6, frames=17939 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-whiterearing-test-mouse003_task3_whiterearing_persp=0.npz  -> shape (150, 17939) = (6×25) × 17939
# [social_projections_seq=task3-whiterearing-test-mouse003_task3_whiterearing_persp=1.npz] components=6, frames=17939 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-whiterearing-test-mouse003_task3_whiterearing_persp=1.npz  -> shape (150, 17939) = (6×25) × 17939
# [social_projections_seq=task3-whiterearing-train-mouse001_task3_whiterearing_persp=0.npz] components=6, frames=18400 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-whiterearing-train-mouse001_task3_whiterearing_persp=0.npz  -> shape (150, 18400) = (6×25) × 18400
# [social_projections_seq=task3-whiterearing-train-mouse001_task3_whiterearing_persp=1.npz] components=6, frames=18400 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-whiterearing-train-mouse001_task3_whiterearing_persp=1.npz  -> shape (150, 18400) = (6×25) × 18400
# [social_projections_seq=task3-whiterearing-train-mouse002_task3_whiterearing_persp=0.npz] components=6, frames=17781 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-whiterearing-train-mouse002_task3_whiterearing_persp=0.npz  -> shape (150, 17781) = (6×25) × 17781
# [social_projections_seq=task3-whiterearing-train-mouse002_task3_whiterearing_persp=1.npz] components=6, frames=17781 -> computing wavelets...
# [SAVE] wavelet_social_seq=task3-whiterearing-train-mouse002_task3_whiterearing_persp=1.npz  -> shape (150, 17781) = (6×25) × 17781
# All pair-level wavelet spectrograms done.

# %% [markdown]
# ## Wavelet transform on egocentric

# %%
# ============================================================
# STEP 1.6 — Wavelet spectrograms for egocentric features
#   Input:  ego_kinematics_seq=<safe_seq>_persp=<0|1>.npz
#   Output: wavelet_ego_seq=<safe_seq>_persp=<0|1>.npz
#            - spectrogram: (n_feats*n_freq, n_frames)  [float32]
#            - log_power_clamped: (n_feats, n_freq, n_frames) [float32]
#            - frequencies, scales, fps, feature_names, sequence, perspective
# ============================================================
import numpy as np
import pywt
from pathlib import Path
import re

IN_DIR   = Path(base + "socialmapper_outputs")   # same OUT_DIR as before
PATTERN  = "ego_kinematics_seq=*persp=*.npz"
OVERWRITE = True

# If you used 30 FPS for pose streams, keep it aligned; else we’ll read from file
DEFAULT_FPS = 30.0

# Frequency band like your pair-level wavelets (slower band)
f_min, f_max, n_freq = 0.2, 25.0, 10
frequencies = 2 ** np.linspace(np.log2(f_min), np.log2(f_max), n_freq)

# Complex Morlet wavelet, same as before
wavelet = pywt.ContinuousWavelet("cmor1.5-1.0")
central_f = pywt.central_frequency(wavelet)

files = sorted(IN_DIR.glob(PATTERN))
if not files:
    raise FileNotFoundError(f"No ego feature files matching {PATTERN} in {IN_DIR}")

print(f"Found {len(files)} egocentric feature files.")

for fpath in files:
    # Parse seq & perspective for output naming
    fname = fpath.stem  # e.g., "ego_kinematics_seq=task1-test-mouse071_task1_annotator1_persp=0"
    m_seq = re.search(r"seq=(.+)_persp=", fname)
    m_p   = re.search(r"persp=(\d+)", fname)
    safe_seq = m_seq.group(1) if m_seq else "unknownseq"
    persp    = int(m_p.group(1)) if m_p else 0

    out_path = IN_DIR / f"wavelet_ego_seq={safe_seq}_persp={persp}.npz"
    if out_path.exists() and not OVERWRITE:
        print(f"[SKIP] {out_path.name} exists; set OVERWRITE=True to recompute.")
        continue

    npz = np.load(fpath, allow_pickle=True)
    ego = np.asarray(npz["ego"])                 # (n_feats, n_frames)
    n_feats, n_frames = ego.shape
    fps = float(npz["fps"]) if "fps" in npz.files else DEFAULT_FPS
    feature_names = npz["feature_names"] if "feature_names" in npz.files else np.array([f"feat_{i}" for i in range(n_feats)], dtype=object)
    sequence = npz["sequence"].item() if "sequence" in npz.files else safe_seq
    perspective = int(npz["perspective"]) if "perspective" in npz.files else persp

    print(f"[{fpath.name}] ego_feats={n_feats}, frames={n_frames}, fps={fps:.3f} -> computing wavelets...")

    # Scales for the chosen band:  freq = fs / (scale * f_c)  =>  scale = fs / (freq * f_c)
    scales = fps / (frequencies * central_f)

    # Compute CWT power per ego feature
    power_stack = np.empty((n_feats, n_freq, n_frames), dtype=np.float32)
    for k in range(n_feats):
        # coeffs: (n_scales, n_frames)
        coeffs, _ = pywt.cwt(ego[k], scales, wavelet, sampling_period=1.0 / fps)
        power_stack[k] = (np.abs(coeffs) ** 2).astype(np.float32)

    # Log + clamp like your pair-level wavelets
    eps = np.finfo(np.float32).tiny
    log_power = np.log(power_stack + eps)
    log_power_clamped = np.maximum(log_power, -3.0)

    # Flatten to (n_feats * n_freq, n_frames)
    spectrogram_flat = log_power_clamped.reshape(n_feats * n_freq, n_frames)

    # Save
    np.savez_compressed(
        out_path,
        spectrogram=spectrogram_flat,        # (n_feats*n_freq, n_frames)
        log_power_clamped=log_power_clamped, # (n_feats, n_freq, n_frames)
        frequencies=frequencies,             # Hz
        scales=scales,
        fps=fps,
        wavelet=str(wavelet),
        feature_names=feature_names,
        sequence=sequence,
        perspective=perspective,
        n_feats=n_feats,
    )
    print(f"[EGO WAVELET SAVE] {out_path.name} -> shape {spectrogram_flat.shape} = ({n_feats}×{n_freq}) × {n_frames}")

print("All egocentric wavelet spectrograms done.")
# Out:
# Found 430 egocentric feature files.
# [ego_kinematics_seq=task1-test-mouse071_task1_annotator1_persp=0.npz] ego_feats=15, frames=23810, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse071_task1_annotator1_persp=0.npz -> shape (150, 23810) = (15×10) × 23810
# [ego_kinematics_seq=task1-test-mouse071_task1_annotator1_persp=1.npz] ego_feats=15, frames=23810, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse071_task1_annotator1_persp=1.npz -> shape (150, 23810) = (15×10) × 23810
# [ego_kinematics_seq=task1-test-mouse072_task1_annotator1_persp=0.npz] ego_feats=15, frames=18164, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse072_task1_annotator1_persp=0.npz -> shape (150, 18164) = (15×10) × 18164
# [ego_kinematics_seq=task1-test-mouse072_task1_annotator1_persp=1.npz] ego_feats=15, frames=18164, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse072_task1_annotator1_persp=1.npz -> shape (150, 18164) = (15×10) × 18164
# [ego_kinematics_seq=task1-test-mouse073_task1_annotator1_persp=0.npz] ego_feats=15, frames=19156, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse073_task1_annotator1_persp=0.npz -> shape (150, 19156) = (15×10) × 19156
# [ego_kinematics_seq=task1-test-mouse073_task1_annotator1_persp=1.npz] ego_feats=15, frames=19156, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse073_task1_annotator1_persp=1.npz -> shape (150, 19156) = (15×10) × 19156
# [ego_kinematics_seq=task1-test-mouse074_task1_annotator1_persp=0.npz] ego_feats=15, frames=18825, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse074_task1_annotator1_persp=0.npz -> shape (150, 18825) = (15×10) × 18825
# [ego_kinematics_seq=task1-test-mouse074_task1_annotator1_persp=1.npz] ego_feats=15, frames=18825, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse074_task1_annotator1_persp=1.npz -> shape (150, 18825) = (15×10) × 18825
# [ego_kinematics_seq=task1-test-mouse075_task1_annotator1_persp=0.npz] ego_feats=15, frames=18015, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse075_task1_annotator1_persp=0.npz -> shape (150, 18015) = (15×10) × 18015
# [ego_kinematics_seq=task1-test-mouse075_task1_annotator1_persp=1.npz] ego_feats=15, frames=18015, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse075_task1_annotator1_persp=1.npz -> shape (150, 18015) = (15×10) × 18015
# [ego_kinematics_seq=task1-test-mouse076_task1_annotator1_persp=0.npz] ego_feats=15, frames=19710, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse076_task1_annotator1_persp=0.npz -> shape (150, 19710) = (15×10) × 19710
# [ego_kinematics_seq=task1-test-mouse076_task1_annotator1_persp=1.npz] ego_feats=15, frames=19710, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse076_task1_annotator1_persp=1.npz -> shape (150, 19710) = (15×10) × 19710
# [ego_kinematics_seq=task1-test-mouse077_task1_annotator1_persp=0.npz] ego_feats=15, frames=18907, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse077_task1_annotator1_persp=0.npz -> shape (150, 18907) = (15×10) × 18907
# [ego_kinematics_seq=task1-test-mouse077_task1_annotator1_persp=1.npz] ego_feats=15, frames=18907, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse077_task1_annotator1_persp=1.npz -> shape (150, 18907) = (15×10) × 18907
# [ego_kinematics_seq=task1-test-mouse078_task1_annotator1_persp=0.npz] ego_feats=15, frames=19473, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse078_task1_annotator1_persp=0.npz -> shape (150, 19473) = (15×10) × 19473
# [ego_kinematics_seq=task1-test-mouse078_task1_annotator1_persp=1.npz] ego_feats=15, frames=19473, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse078_task1_annotator1_persp=1.npz -> shape (150, 19473) = (15×10) × 19473
# [ego_kinematics_seq=task1-test-mouse079_task1_annotator1_persp=0.npz] ego_feats=15, frames=17483, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse079_task1_annotator1_persp=0.npz -> shape (150, 17483) = (15×10) × 17483
# [ego_kinematics_seq=task1-test-mouse079_task1_annotator1_persp=1.npz] ego_feats=15, frames=17483, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse079_task1_annotator1_persp=1.npz -> shape (150, 17483) = (15×10) × 17483
# [ego_kinematics_seq=task1-test-mouse080_task1_annotator1_persp=0.npz] ego_feats=15, frames=6179, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse080_task1_annotator1_persp=0.npz -> shape (150, 6179) = (15×10) × 6179
# [ego_kinematics_seq=task1-test-mouse080_task1_annotator1_persp=1.npz] ego_feats=15, frames=6179, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse080_task1_annotator1_persp=1.npz -> shape (150, 6179) = (15×10) × 6179
# [ego_kinematics_seq=task1-test-mouse081_task1_annotator1_persp=0.npz] ego_feats=15, frames=4932, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse081_task1_annotator1_persp=0.npz -> shape (150, 4932) = (15×10) × 4932
# [ego_kinematics_seq=task1-test-mouse081_task1_annotator1_persp=1.npz] ego_feats=15, frames=4932, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse081_task1_annotator1_persp=1.npz -> shape (150, 4932) = (15×10) × 4932
# [ego_kinematics_seq=task1-test-mouse082_task1_annotator1_persp=0.npz] ego_feats=15, frames=7115, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse082_task1_annotator1_persp=0.npz -> shape (150, 7115) = (15×10) × 7115
# [ego_kinematics_seq=task1-test-mouse082_task1_annotator1_persp=1.npz] ego_feats=15, frames=7115, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse082_task1_annotator1_persp=1.npz -> shape (150, 7115) = (15×10) × 7115
# [ego_kinematics_seq=task1-test-mouse083_task1_annotator1_persp=0.npz] ego_feats=15, frames=4881, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse083_task1_annotator1_persp=0.npz -> shape (150, 4881) = (15×10) × 4881
# [ego_kinematics_seq=task1-test-mouse083_task1_annotator1_persp=1.npz] ego_feats=15, frames=4881, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse083_task1_annotator1_persp=1.npz -> shape (150, 4881) = (15×10) × 4881
# [ego_kinematics_seq=task1-test-mouse084_task1_annotator1_persp=0.npz] ego_feats=15, frames=5626, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse084_task1_annotator1_persp=0.npz -> shape (150, 5626) = (15×10) × 5626
# [ego_kinematics_seq=task1-test-mouse084_task1_annotator1_persp=1.npz] ego_feats=15, frames=5626, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse084_task1_annotator1_persp=1.npz -> shape (150, 5626) = (15×10) × 5626
# [ego_kinematics_seq=task1-test-mouse085_task1_annotator1_persp=0.npz] ego_feats=15, frames=19200, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse085_task1_annotator1_persp=0.npz -> shape (150, 19200) = (15×10) × 19200
# [ego_kinematics_seq=task1-test-mouse085_task1_annotator1_persp=1.npz] ego_feats=15, frames=19200, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse085_task1_annotator1_persp=1.npz -> shape (150, 19200) = (15×10) × 19200
# [ego_kinematics_seq=task1-test-mouse086_task1_annotator1_persp=0.npz] ego_feats=15, frames=8617, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse086_task1_annotator1_persp=0.npz -> shape (150, 8617) = (15×10) × 8617
# [ego_kinematics_seq=task1-test-mouse086_task1_annotator1_persp=1.npz] ego_feats=15, frames=8617, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse086_task1_annotator1_persp=1.npz -> shape (150, 8617) = (15×10) × 8617
# [ego_kinematics_seq=task1-test-mouse087_task1_annotator1_persp=0.npz] ego_feats=15, frames=11915, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse087_task1_annotator1_persp=0.npz -> shape (150, 11915) = (15×10) × 11915
# [ego_kinematics_seq=task1-test-mouse087_task1_annotator1_persp=1.npz] ego_feats=15, frames=11915, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse087_task1_annotator1_persp=1.npz -> shape (150, 11915) = (15×10) × 11915
# [ego_kinematics_seq=task1-test-mouse088_task1_annotator1_persp=0.npz] ego_feats=15, frames=8825, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse088_task1_annotator1_persp=0.npz -> shape (150, 8825) = (15×10) × 8825
# [ego_kinematics_seq=task1-test-mouse088_task1_annotator1_persp=1.npz] ego_feats=15, frames=8825, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse088_task1_annotator1_persp=1.npz -> shape (150, 8825) = (15×10) × 8825
# [ego_kinematics_seq=task1-test-mouse089_task1_annotator1_persp=0.npz] ego_feats=15, frames=11274, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse089_task1_annotator1_persp=0.npz -> shape (150, 11274) = (15×10) × 11274
# [ego_kinematics_seq=task1-test-mouse089_task1_annotator1_persp=1.npz] ego_feats=15, frames=11274, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-test-mouse089_task1_annotator1_persp=1.npz -> shape (150, 11274) = (15×10) × 11274
# [ego_kinematics_seq=task1-train-mouse001_task1_annotator1_persp=0.npz] ego_feats=15, frames=21364, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse001_task1_annotator1_persp=0.npz -> shape (150, 21364) = (15×10) × 21364
# [ego_kinematics_seq=task1-train-mouse001_task1_annotator1_persp=1.npz] ego_feats=15, frames=21364, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse001_task1_annotator1_persp=1.npz -> shape (150, 21364) = (15×10) × 21364
# [ego_kinematics_seq=task1-train-mouse002_task1_annotator1_persp=0.npz] ego_feats=15, frames=19343, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse002_task1_annotator1_persp=0.npz -> shape (150, 19343) = (15×10) × 19343
# [ego_kinematics_seq=task1-train-mouse002_task1_annotator1_persp=1.npz] ego_feats=15, frames=19343, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse002_task1_annotator1_persp=1.npz -> shape (150, 19343) = (15×10) × 19343
# [ego_kinematics_seq=task1-train-mouse003_task1_annotator1_persp=0.npz] ego_feats=15, frames=13222, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse003_task1_annotator1_persp=0.npz -> shape (150, 13222) = (15×10) × 13222
# [ego_kinematics_seq=task1-train-mouse003_task1_annotator1_persp=1.npz] ego_feats=15, frames=13222, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse003_task1_annotator1_persp=1.npz -> shape (150, 13222) = (15×10) × 13222
# [ego_kinematics_seq=task1-train-mouse004_task1_annotator1_persp=0.npz] ego_feats=15, frames=7433, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse004_task1_annotator1_persp=0.npz -> shape (150, 7433) = (15×10) × 7433
# [ego_kinematics_seq=task1-train-mouse004_task1_annotator1_persp=1.npz] ego_feats=15, frames=7433, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse004_task1_annotator1_persp=1.npz -> shape (150, 7433) = (15×10) × 7433
# [ego_kinematics_seq=task1-train-mouse005_task1_annotator1_persp=0.npz] ego_feats=15, frames=5641, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse005_task1_annotator1_persp=0.npz -> shape (150, 5641) = (15×10) × 5641
# [ego_kinematics_seq=task1-train-mouse005_task1_annotator1_persp=1.npz] ego_feats=15, frames=5641, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse005_task1_annotator1_persp=1.npz -> shape (150, 5641) = (15×10) × 5641
# [ego_kinematics_seq=task1-train-mouse006_task1_annotator1_persp=0.npz] ego_feats=15, frames=3029, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse006_task1_annotator1_persp=0.npz -> shape (150, 3029) = (15×10) × 3029
# [ego_kinematics_seq=task1-train-mouse006_task1_annotator1_persp=1.npz] ego_feats=15, frames=3029, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse006_task1_annotator1_persp=1.npz -> shape (150, 3029) = (15×10) × 3029
# [ego_kinematics_seq=task1-train-mouse007_task1_annotator1_persp=0.npz] ego_feats=15, frames=10025, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse007_task1_annotator1_persp=0.npz -> shape (150, 10025) = (15×10) × 10025
# [ego_kinematics_seq=task1-train-mouse007_task1_annotator1_persp=1.npz] ego_feats=15, frames=10025, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse007_task1_annotator1_persp=1.npz -> shape (150, 10025) = (15×10) × 10025
# [ego_kinematics_seq=task1-train-mouse008_task1_annotator1_persp=0.npz] ego_feats=15, frames=11407, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse008_task1_annotator1_persp=0.npz -> shape (150, 11407) = (15×10) × 11407
# [ego_kinematics_seq=task1-train-mouse008_task1_annotator1_persp=1.npz] ego_feats=15, frames=11407, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse008_task1_annotator1_persp=1.npz -> shape (150, 11407) = (15×10) × 11407
# [ego_kinematics_seq=task1-train-mouse009_task1_annotator1_persp=0.npz] ego_feats=15, frames=8332, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse009_task1_annotator1_persp=0.npz -> shape (150, 8332) = (15×10) × 8332
# [ego_kinematics_seq=task1-train-mouse009_task1_annotator1_persp=1.npz] ego_feats=15, frames=8332, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse009_task1_annotator1_persp=1.npz -> shape (150, 8332) = (15×10) × 8332
# [ego_kinematics_seq=task1-train-mouse010_task1_annotator1_persp=0.npz] ego_feats=15, frames=8666, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse010_task1_annotator1_persp=0.npz -> shape (150, 8666) = (15×10) × 8666
# [ego_kinematics_seq=task1-train-mouse010_task1_annotator1_persp=1.npz] ego_feats=15, frames=8666, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse010_task1_annotator1_persp=1.npz -> shape (150, 8666) = (15×10) × 8666
# [ego_kinematics_seq=task1-train-mouse011_task1_annotator1_persp=0.npz] ego_feats=15, frames=4260, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse011_task1_annotator1_persp=0.npz -> shape (150, 4260) = (15×10) × 4260
# [ego_kinematics_seq=task1-train-mouse011_task1_annotator1_persp=1.npz] ego_feats=15, frames=4260, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse011_task1_annotator1_persp=1.npz -> shape (150, 4260) = (15×10) × 4260
# [ego_kinematics_seq=task1-train-mouse012_task1_annotator1_persp=0.npz] ego_feats=15, frames=7190, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse012_task1_annotator1_persp=0.npz -> shape (150, 7190) = (15×10) × 7190
# [ego_kinematics_seq=task1-train-mouse012_task1_annotator1_persp=1.npz] ego_feats=15, frames=7190, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse012_task1_annotator1_persp=1.npz -> shape (150, 7190) = (15×10) × 7190
# [ego_kinematics_seq=task1-train-mouse013_task1_annotator1_persp=0.npz] ego_feats=15, frames=2263, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse013_task1_annotator1_persp=0.npz -> shape (150, 2263) = (15×10) × 2263
# [ego_kinematics_seq=task1-train-mouse013_task1_annotator1_persp=1.npz] ego_feats=15, frames=2263, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse013_task1_annotator1_persp=1.npz -> shape (150, 2263) = (15×10) × 2263
# [ego_kinematics_seq=task1-train-mouse014_task1_annotator1_persp=0.npz] ego_feats=15, frames=8994, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse014_task1_annotator1_persp=0.npz -> shape (150, 8994) = (15×10) × 8994
# [ego_kinematics_seq=task1-train-mouse014_task1_annotator1_persp=1.npz] ego_feats=15, frames=8994, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse014_task1_annotator1_persp=1.npz -> shape (150, 8994) = (15×10) × 8994
# [ego_kinematics_seq=task1-train-mouse015_task1_annotator1_persp=0.npz] ego_feats=15, frames=7406, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse015_task1_annotator1_persp=0.npz -> shape (150, 7406) = (15×10) × 7406
# [ego_kinematics_seq=task1-train-mouse015_task1_annotator1_persp=1.npz] ego_feats=15, frames=7406, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse015_task1_annotator1_persp=1.npz -> shape (150, 7406) = (15×10) × 7406
# [ego_kinematics_seq=task1-train-mouse016_task1_annotator1_persp=0.npz] ego_feats=15, frames=3692, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse016_task1_annotator1_persp=0.npz -> shape (150, 3692) = (15×10) × 3692
# [ego_kinematics_seq=task1-train-mouse016_task1_annotator1_persp=1.npz] ego_feats=15, frames=3692, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse016_task1_annotator1_persp=1.npz -> shape (150, 3692) = (15×10) × 3692
# [ego_kinematics_seq=task1-train-mouse017_task1_annotator1_persp=0.npz] ego_feats=15, frames=6200, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse017_task1_annotator1_persp=0.npz -> shape (150, 6200) = (15×10) × 6200
# [ego_kinematics_seq=task1-train-mouse017_task1_annotator1_persp=1.npz] ego_feats=15, frames=6200, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse017_task1_annotator1_persp=1.npz -> shape (150, 6200) = (15×10) × 6200
# [ego_kinematics_seq=task1-train-mouse018_task1_annotator1_persp=0.npz] ego_feats=15, frames=6127, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse018_task1_annotator1_persp=0.npz -> shape (150, 6127) = (15×10) × 6127
# [ego_kinematics_seq=task1-train-mouse018_task1_annotator1_persp=1.npz] ego_feats=15, frames=6127, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse018_task1_annotator1_persp=1.npz -> shape (150, 6127) = (15×10) × 6127
# [ego_kinematics_seq=task1-train-mouse019_task1_annotator1_persp=0.npz] ego_feats=15, frames=4461, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse019_task1_annotator1_persp=0.npz -> shape (150, 4461) = (15×10) × 4461
# [ego_kinematics_seq=task1-train-mouse019_task1_annotator1_persp=1.npz] ego_feats=15, frames=4461, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse019_task1_annotator1_persp=1.npz -> shape (150, 4461) = (15×10) × 4461
# [ego_kinematics_seq=task1-train-mouse020_task1_annotator1_persp=0.npz] ego_feats=15, frames=3714, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse020_task1_annotator1_persp=0.npz -> shape (150, 3714) = (15×10) × 3714
# [ego_kinematics_seq=task1-train-mouse020_task1_annotator1_persp=1.npz] ego_feats=15, frames=3714, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse020_task1_annotator1_persp=1.npz -> shape (150, 3714) = (15×10) × 3714
# [ego_kinematics_seq=task1-train-mouse021_task1_annotator1_persp=0.npz] ego_feats=15, frames=11322, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse021_task1_annotator1_persp=0.npz -> shape (150, 11322) = (15×10) × 11322
# [ego_kinematics_seq=task1-train-mouse021_task1_annotator1_persp=1.npz] ego_feats=15, frames=11322, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse021_task1_annotator1_persp=1.npz -> shape (150, 11322) = (15×10) × 11322
# [ego_kinematics_seq=task1-train-mouse022_task1_annotator1_persp=0.npz] ego_feats=15, frames=9792, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse022_task1_annotator1_persp=0.npz -> shape (150, 9792) = (15×10) × 9792
# [ego_kinematics_seq=task1-train-mouse022_task1_annotator1_persp=1.npz] ego_feats=15, frames=9792, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse022_task1_annotator1_persp=1.npz -> shape (150, 9792) = (15×10) × 9792
# [ego_kinematics_seq=task1-train-mouse023_task1_annotator1_persp=0.npz] ego_feats=15, frames=1838, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse023_task1_annotator1_persp=0.npz -> shape (150, 1838) = (15×10) × 1838
# [ego_kinematics_seq=task1-train-mouse023_task1_annotator1_persp=1.npz] ego_feats=15, frames=1838, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse023_task1_annotator1_persp=1.npz -> shape (150, 1838) = (15×10) × 1838
# [ego_kinematics_seq=task1-train-mouse024_task1_annotator1_persp=0.npz] ego_feats=15, frames=8899, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse024_task1_annotator1_persp=0.npz -> shape (150, 8899) = (15×10) × 8899
# [ego_kinematics_seq=task1-train-mouse024_task1_annotator1_persp=1.npz] ego_feats=15, frames=8899, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse024_task1_annotator1_persp=1.npz -> shape (150, 8899) = (15×10) × 8899
# [ego_kinematics_seq=task1-train-mouse025_task1_annotator1_persp=0.npz] ego_feats=15, frames=3770, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse025_task1_annotator1_persp=0.npz -> shape (150, 3770) = (15×10) × 3770
# [ego_kinematics_seq=task1-train-mouse025_task1_annotator1_persp=1.npz] ego_feats=15, frames=3770, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse025_task1_annotator1_persp=1.npz -> shape (150, 3770) = (15×10) × 3770
# [ego_kinematics_seq=task1-train-mouse026_task1_annotator1_persp=0.npz] ego_feats=15, frames=3632, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse026_task1_annotator1_persp=0.npz -> shape (150, 3632) = (15×10) × 3632
# [ego_kinematics_seq=task1-train-mouse026_task1_annotator1_persp=1.npz] ego_feats=15, frames=3632, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse026_task1_annotator1_persp=1.npz -> shape (150, 3632) = (15×10) × 3632
# [ego_kinematics_seq=task1-train-mouse027_task1_annotator1_persp=0.npz] ego_feats=15, frames=1987, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse027_task1_annotator1_persp=0.npz -> shape (150, 1987) = (15×10) × 1987
# [ego_kinematics_seq=task1-train-mouse027_task1_annotator1_persp=1.npz] ego_feats=15, frames=1987, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse027_task1_annotator1_persp=1.npz -> shape (150, 1987) = (15×10) × 1987
# [ego_kinematics_seq=task1-train-mouse028_task1_annotator1_persp=0.npz] ego_feats=15, frames=1036, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse028_task1_annotator1_persp=0.npz -> shape (150, 1036) = (15×10) × 1036
# [ego_kinematics_seq=task1-train-mouse028_task1_annotator1_persp=1.npz] ego_feats=15, frames=1036, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse028_task1_annotator1_persp=1.npz -> shape (150, 1036) = (15×10) × 1036
# [ego_kinematics_seq=task1-train-mouse029_task1_annotator1_persp=0.npz] ego_feats=15, frames=3041, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse029_task1_annotator1_persp=0.npz -> shape (150, 3041) = (15×10) × 3041
# [ego_kinematics_seq=task1-train-mouse029_task1_annotator1_persp=1.npz] ego_feats=15, frames=3041, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse029_task1_annotator1_persp=1.npz -> shape (150, 3041) = (15×10) × 3041
# [ego_kinematics_seq=task1-train-mouse030_task1_annotator1_persp=0.npz] ego_feats=15, frames=1607, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse030_task1_annotator1_persp=0.npz -> shape (150, 1607) = (15×10) × 1607
# [ego_kinematics_seq=task1-train-mouse030_task1_annotator1_persp=1.npz] ego_feats=15, frames=1607, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse030_task1_annotator1_persp=1.npz -> shape (150, 1607) = (15×10) × 1607
# [ego_kinematics_seq=task1-train-mouse031_task1_annotator1_persp=0.npz] ego_feats=15, frames=5096, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse031_task1_annotator1_persp=0.npz -> shape (150, 5096) = (15×10) × 5096
# [ego_kinematics_seq=task1-train-mouse031_task1_annotator1_persp=1.npz] ego_feats=15, frames=5096, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse031_task1_annotator1_persp=1.npz -> shape (150, 5096) = (15×10) × 5096
# [ego_kinematics_seq=task1-train-mouse032_task1_annotator1_persp=0.npz] ego_feats=15, frames=5763, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse032_task1_annotator1_persp=0.npz -> shape (150, 5763) = (15×10) × 5763
# [ego_kinematics_seq=task1-train-mouse032_task1_annotator1_persp=1.npz] ego_feats=15, frames=5763, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse032_task1_annotator1_persp=1.npz -> shape (150, 5763) = (15×10) × 5763
# [ego_kinematics_seq=task1-train-mouse033_task1_annotator1_persp=0.npz] ego_feats=15, frames=2497, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse033_task1_annotator1_persp=0.npz -> shape (150, 2497) = (15×10) × 2497
# [ego_kinematics_seq=task1-train-mouse033_task1_annotator1_persp=1.npz] ego_feats=15, frames=2497, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse033_task1_annotator1_persp=1.npz -> shape (150, 2497) = (15×10) × 2497
# [ego_kinematics_seq=task1-train-mouse034_task1_annotator1_persp=0.npz] ego_feats=15, frames=1062, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse034_task1_annotator1_persp=0.npz -> shape (150, 1062) = (15×10) × 1062
# [ego_kinematics_seq=task1-train-mouse034_task1_annotator1_persp=1.npz] ego_feats=15, frames=1062, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse034_task1_annotator1_persp=1.npz -> shape (150, 1062) = (15×10) × 1062
# [ego_kinematics_seq=task1-train-mouse035_task1_annotator1_persp=0.npz] ego_feats=15, frames=4879, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse035_task1_annotator1_persp=0.npz -> shape (150, 4879) = (15×10) × 4879
# [ego_kinematics_seq=task1-train-mouse035_task1_annotator1_persp=1.npz] ego_feats=15, frames=4879, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse035_task1_annotator1_persp=1.npz -> shape (150, 4879) = (15×10) × 4879
# [ego_kinematics_seq=task1-train-mouse036_task1_annotator1_persp=0.npz] ego_feats=15, frames=96, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse036_task1_annotator1_persp=0.npz -> shape (150, 96) = (15×10) × 96
# [ego_kinematics_seq=task1-train-mouse036_task1_annotator1_persp=1.npz] ego_feats=15, frames=96, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse036_task1_annotator1_persp=1.npz -> shape (150, 96) = (15×10) × 96
# [ego_kinematics_seq=task1-train-mouse037_task1_annotator1_persp=0.npz] ego_feats=15, frames=5133, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse037_task1_annotator1_persp=0.npz -> shape (150, 5133) = (15×10) × 5133
# [ego_kinematics_seq=task1-train-mouse037_task1_annotator1_persp=1.npz] ego_feats=15, frames=5133, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse037_task1_annotator1_persp=1.npz -> shape (150, 5133) = (15×10) × 5133
# [ego_kinematics_seq=task1-train-mouse038_task1_annotator1_persp=0.npz] ego_feats=15, frames=2796, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse038_task1_annotator1_persp=0.npz -> shape (150, 2796) = (15×10) × 2796
# [ego_kinematics_seq=task1-train-mouse038_task1_annotator1_persp=1.npz] ego_feats=15, frames=2796, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse038_task1_annotator1_persp=1.npz -> shape (150, 2796) = (15×10) × 2796
# [ego_kinematics_seq=task1-train-mouse039_task1_annotator1_persp=0.npz] ego_feats=15, frames=3188, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse039_task1_annotator1_persp=0.npz -> shape (150, 3188) = (15×10) × 3188
# [ego_kinematics_seq=task1-train-mouse039_task1_annotator1_persp=1.npz] ego_feats=15, frames=3188, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse039_task1_annotator1_persp=1.npz -> shape (150, 3188) = (15×10) × 3188
# [ego_kinematics_seq=task1-train-mouse040_task1_annotator1_persp=0.npz] ego_feats=15, frames=2643, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse040_task1_annotator1_persp=0.npz -> shape (150, 2643) = (15×10) × 2643
# [ego_kinematics_seq=task1-train-mouse040_task1_annotator1_persp=1.npz] ego_feats=15, frames=2643, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse040_task1_annotator1_persp=1.npz -> shape (150, 2643) = (15×10) × 2643
# [ego_kinematics_seq=task1-train-mouse041_task1_annotator1_persp=0.npz] ego_feats=15, frames=1440, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse041_task1_annotator1_persp=0.npz -> shape (150, 1440) = (15×10) × 1440
# [ego_kinematics_seq=task1-train-mouse041_task1_annotator1_persp=1.npz] ego_feats=15, frames=1440, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse041_task1_annotator1_persp=1.npz -> shape (150, 1440) = (15×10) × 1440
# [ego_kinematics_seq=task1-train-mouse042_task1_annotator1_persp=0.npz] ego_feats=15, frames=3351, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse042_task1_annotator1_persp=0.npz -> shape (150, 3351) = (15×10) × 3351
# [ego_kinematics_seq=task1-train-mouse042_task1_annotator1_persp=1.npz] ego_feats=15, frames=3351, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse042_task1_annotator1_persp=1.npz -> shape (150, 3351) = (15×10) × 3351
# [ego_kinematics_seq=task1-train-mouse043_task1_annotator1_persp=0.npz] ego_feats=15, frames=974, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse043_task1_annotator1_persp=0.npz -> shape (150, 974) = (15×10) × 974
# [ego_kinematics_seq=task1-train-mouse043_task1_annotator1_persp=1.npz] ego_feats=15, frames=974, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse043_task1_annotator1_persp=1.npz -> shape (150, 974) = (15×10) × 974
# [ego_kinematics_seq=task1-train-mouse044_task1_annotator1_persp=0.npz] ego_feats=15, frames=3394, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse044_task1_annotator1_persp=0.npz -> shape (150, 3394) = (15×10) × 3394
# [ego_kinematics_seq=task1-train-mouse044_task1_annotator1_persp=1.npz] ego_feats=15, frames=3394, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse044_task1_annotator1_persp=1.npz -> shape (150, 3394) = (15×10) × 3394
# [ego_kinematics_seq=task1-train-mouse045_task1_annotator1_persp=0.npz] ego_feats=15, frames=2713, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse045_task1_annotator1_persp=0.npz -> shape (150, 2713) = (15×10) × 2713
# [ego_kinematics_seq=task1-train-mouse045_task1_annotator1_persp=1.npz] ego_feats=15, frames=2713, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse045_task1_annotator1_persp=1.npz -> shape (150, 2713) = (15×10) × 2713
# [ego_kinematics_seq=task1-train-mouse046_task1_annotator1_persp=0.npz] ego_feats=15, frames=5065, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse046_task1_annotator1_persp=0.npz -> shape (150, 5065) = (15×10) × 5065
# [ego_kinematics_seq=task1-train-mouse046_task1_annotator1_persp=1.npz] ego_feats=15, frames=5065, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse046_task1_annotator1_persp=1.npz -> shape (150, 5065) = (15×10) × 5065
# [ego_kinematics_seq=task1-train-mouse047_task1_annotator1_persp=0.npz] ego_feats=15, frames=2751, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse047_task1_annotator1_persp=0.npz -> shape (150, 2751) = (15×10) × 2751
# [ego_kinematics_seq=task1-train-mouse047_task1_annotator1_persp=1.npz] ego_feats=15, frames=2751, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse047_task1_annotator1_persp=1.npz -> shape (150, 2751) = (15×10) × 2751
# [ego_kinematics_seq=task1-train-mouse048_task1_annotator1_persp=0.npz] ego_feats=15, frames=1213, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse048_task1_annotator1_persp=0.npz -> shape (150, 1213) = (15×10) × 1213
# [ego_kinematics_seq=task1-train-mouse048_task1_annotator1_persp=1.npz] ego_feats=15, frames=1213, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse048_task1_annotator1_persp=1.npz -> shape (150, 1213) = (15×10) × 1213
# [ego_kinematics_seq=task1-train-mouse049_task1_annotator1_persp=0.npz] ego_feats=15, frames=2885, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse049_task1_annotator1_persp=0.npz -> shape (150, 2885) = (15×10) × 2885
# [ego_kinematics_seq=task1-train-mouse049_task1_annotator1_persp=1.npz] ego_feats=15, frames=2885, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse049_task1_annotator1_persp=1.npz -> shape (150, 2885) = (15×10) × 2885
# [ego_kinematics_seq=task1-train-mouse050_task1_annotator1_persp=0.npz] ego_feats=15, frames=1283, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse050_task1_annotator1_persp=0.npz -> shape (150, 1283) = (15×10) × 1283
# [ego_kinematics_seq=task1-train-mouse050_task1_annotator1_persp=1.npz] ego_feats=15, frames=1283, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse050_task1_annotator1_persp=1.npz -> shape (150, 1283) = (15×10) × 1283
# [ego_kinematics_seq=task1-train-mouse051_task1_annotator1_persp=0.npz] ego_feats=15, frames=17326, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse051_task1_annotator1_persp=0.npz -> shape (150, 17326) = (15×10) × 17326
# [ego_kinematics_seq=task1-train-mouse051_task1_annotator1_persp=1.npz] ego_feats=15, frames=17326, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse051_task1_annotator1_persp=1.npz -> shape (150, 17326) = (15×10) × 17326
# [ego_kinematics_seq=task1-train-mouse052_task1_annotator1_persp=0.npz] ego_feats=15, frames=17946, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse052_task1_annotator1_persp=0.npz -> shape (150, 17946) = (15×10) × 17946
# [ego_kinematics_seq=task1-train-mouse052_task1_annotator1_persp=1.npz] ego_feats=15, frames=17946, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse052_task1_annotator1_persp=1.npz -> shape (150, 17946) = (15×10) × 17946
# [ego_kinematics_seq=task1-train-mouse053_task1_annotator1_persp=0.npz] ego_feats=15, frames=17472, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse053_task1_annotator1_persp=0.npz -> shape (150, 17472) = (15×10) × 17472
# [ego_kinematics_seq=task1-train-mouse053_task1_annotator1_persp=1.npz] ego_feats=15, frames=17472, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse053_task1_annotator1_persp=1.npz -> shape (150, 17472) = (15×10) × 17472
# [ego_kinematics_seq=task1-train-mouse054_task1_annotator1_persp=0.npz] ego_feats=15, frames=17319, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse054_task1_annotator1_persp=0.npz -> shape (150, 17319) = (15×10) × 17319
# [ego_kinematics_seq=task1-train-mouse054_task1_annotator1_persp=1.npz] ego_feats=15, frames=17319, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse054_task1_annotator1_persp=1.npz -> shape (150, 17319) = (15×10) × 17319
# [ego_kinematics_seq=task1-train-mouse055_task1_annotator1_persp=0.npz] ego_feats=15, frames=17637, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse055_task1_annotator1_persp=0.npz -> shape (150, 17637) = (15×10) × 17637
# [ego_kinematics_seq=task1-train-mouse055_task1_annotator1_persp=1.npz] ego_feats=15, frames=17637, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse055_task1_annotator1_persp=1.npz -> shape (150, 17637) = (15×10) × 17637
# [ego_kinematics_seq=task1-train-mouse056_task1_annotator1_persp=0.npz] ego_feats=15, frames=16420, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse056_task1_annotator1_persp=0.npz -> shape (150, 16420) = (15×10) × 16420
# [ego_kinematics_seq=task1-train-mouse056_task1_annotator1_persp=1.npz] ego_feats=15, frames=16420, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse056_task1_annotator1_persp=1.npz -> shape (150, 16420) = (15×10) × 16420
# [ego_kinematics_seq=task1-train-mouse057_task1_annotator1_persp=0.npz] ego_feats=15, frames=18617, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse057_task1_annotator1_persp=0.npz -> shape (150, 18617) = (15×10) × 18617
# [ego_kinematics_seq=task1-train-mouse057_task1_annotator1_persp=1.npz] ego_feats=15, frames=18617, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse057_task1_annotator1_persp=1.npz -> shape (150, 18617) = (15×10) × 18617
# [ego_kinematics_seq=task1-train-mouse058_task1_annotator1_persp=0.npz] ego_feats=15, frames=18423, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse058_task1_annotator1_persp=0.npz -> shape (150, 18423) = (15×10) × 18423
# [ego_kinematics_seq=task1-train-mouse058_task1_annotator1_persp=1.npz] ego_feats=15, frames=18423, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse058_task1_annotator1_persp=1.npz -> shape (150, 18423) = (15×10) × 18423
# [ego_kinematics_seq=task1-train-mouse059_task1_annotator1_persp=0.npz] ego_feats=15, frames=5495, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse059_task1_annotator1_persp=0.npz -> shape (150, 5495) = (15×10) × 5495
# [ego_kinematics_seq=task1-train-mouse059_task1_annotator1_persp=1.npz] ego_feats=15, frames=5495, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse059_task1_annotator1_persp=1.npz -> shape (150, 5495) = (15×10) × 5495
# [ego_kinematics_seq=task1-train-mouse060_task1_annotator1_persp=0.npz] ego_feats=15, frames=4755, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse060_task1_annotator1_persp=0.npz -> shape (150, 4755) = (15×10) × 4755
# [ego_kinematics_seq=task1-train-mouse060_task1_annotator1_persp=1.npz] ego_feats=15, frames=4755, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse060_task1_annotator1_persp=1.npz -> shape (150, 4755) = (15×10) × 4755
# [ego_kinematics_seq=task1-train-mouse061_task1_annotator1_persp=0.npz] ego_feats=15, frames=3996, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse061_task1_annotator1_persp=0.npz -> shape (150, 3996) = (15×10) × 3996
# [ego_kinematics_seq=task1-train-mouse061_task1_annotator1_persp=1.npz] ego_feats=15, frames=3996, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse061_task1_annotator1_persp=1.npz -> shape (150, 3996) = (15×10) × 3996
# [ego_kinematics_seq=task1-train-mouse062_task1_annotator1_persp=0.npz] ego_feats=15, frames=7754, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse062_task1_annotator1_persp=0.npz -> shape (150, 7754) = (15×10) × 7754
# [ego_kinematics_seq=task1-train-mouse062_task1_annotator1_persp=1.npz] ego_feats=15, frames=7754, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse062_task1_annotator1_persp=1.npz -> shape (150, 7754) = (15×10) × 7754
# [ego_kinematics_seq=task1-train-mouse063_task1_annotator1_persp=0.npz] ego_feats=15, frames=13170, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse063_task1_annotator1_persp=0.npz -> shape (150, 13170) = (15×10) × 13170
# [ego_kinematics_seq=task1-train-mouse063_task1_annotator1_persp=1.npz] ego_feats=15, frames=13170, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse063_task1_annotator1_persp=1.npz -> shape (150, 13170) = (15×10) × 13170
# [ego_kinematics_seq=task1-train-mouse064_task1_annotator1_persp=0.npz] ego_feats=15, frames=7150, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse064_task1_annotator1_persp=0.npz -> shape (150, 7150) = (15×10) × 7150
# [ego_kinematics_seq=task1-train-mouse064_task1_annotator1_persp=1.npz] ego_feats=15, frames=7150, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse064_task1_annotator1_persp=1.npz -> shape (150, 7150) = (15×10) × 7150
# [ego_kinematics_seq=task1-train-mouse065_task1_annotator1_persp=0.npz] ego_feats=15, frames=8103, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse065_task1_annotator1_persp=0.npz -> shape (150, 8103) = (15×10) × 8103
# [ego_kinematics_seq=task1-train-mouse065_task1_annotator1_persp=1.npz] ego_feats=15, frames=8103, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse065_task1_annotator1_persp=1.npz -> shape (150, 8103) = (15×10) × 8103
# [ego_kinematics_seq=task1-train-mouse066_task1_annotator1_persp=0.npz] ego_feats=15, frames=7410, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse066_task1_annotator1_persp=0.npz -> shape (150, 7410) = (15×10) × 7410
# [ego_kinematics_seq=task1-train-mouse066_task1_annotator1_persp=1.npz] ego_feats=15, frames=7410, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse066_task1_annotator1_persp=1.npz -> shape (150, 7410) = (15×10) × 7410
# [ego_kinematics_seq=task1-train-mouse067_task1_annotator1_persp=0.npz] ego_feats=15, frames=7024, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse067_task1_annotator1_persp=0.npz -> shape (150, 7024) = (15×10) × 7024
# [ego_kinematics_seq=task1-train-mouse067_task1_annotator1_persp=1.npz] ego_feats=15, frames=7024, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse067_task1_annotator1_persp=1.npz -> shape (150, 7024) = (15×10) × 7024
# [ego_kinematics_seq=task1-train-mouse068_task1_annotator1_persp=0.npz] ego_feats=15, frames=9838, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse068_task1_annotator1_persp=0.npz -> shape (150, 9838) = (15×10) × 9838
# [ego_kinematics_seq=task1-train-mouse068_task1_annotator1_persp=1.npz] ego_feats=15, frames=9838, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse068_task1_annotator1_persp=1.npz -> shape (150, 9838) = (15×10) × 9838
# [ego_kinematics_seq=task1-train-mouse069_task1_annotator1_persp=0.npz] ego_feats=15, frames=11431, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse069_task1_annotator1_persp=0.npz -> shape (150, 11431) = (15×10) × 11431
# [ego_kinematics_seq=task1-train-mouse069_task1_annotator1_persp=1.npz] ego_feats=15, frames=11431, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse069_task1_annotator1_persp=1.npz -> shape (150, 11431) = (15×10) × 11431
# [ego_kinematics_seq=task1-train-mouse070_task1_annotator1_persp=0.npz] ego_feats=15, frames=12537, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse070_task1_annotator1_persp=0.npz -> shape (150, 12537) = (15×10) × 12537
# [ego_kinematics_seq=task1-train-mouse070_task1_annotator1_persp=1.npz] ego_feats=15, frames=12537, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task1-train-mouse070_task1_annotator1_persp=1.npz -> shape (150, 12537) = (15×10) × 12537
# [ego_kinematics_seq=task3-approach-test-mouse004_task3_approach_persp=0.npz] ego_feats=15, frames=7433, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-approach-test-mouse004_task3_approach_persp=0.npz -> shape (150, 7433) = (15×10) × 7433
# [ego_kinematics_seq=task3-approach-test-mouse004_task3_approach_persp=1.npz] ego_feats=15, frames=7433, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-approach-test-mouse004_task3_approach_persp=1.npz -> shape (150, 7433) = (15×10) × 7433
# [ego_kinematics_seq=task3-approach-test-mouse005_task3_approach_persp=0.npz] ego_feats=15, frames=5641, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-approach-test-mouse005_task3_approach_persp=0.npz -> shape (150, 5641) = (15×10) × 5641
# [ego_kinematics_seq=task3-approach-test-mouse005_task3_approach_persp=1.npz] ego_feats=15, frames=5641, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-approach-test-mouse005_task3_approach_persp=1.npz -> shape (150, 5641) = (15×10) × 5641
# [ego_kinematics_seq=task3-approach-test-mouse006_task3_approach_persp=0.npz] ego_feats=15, frames=3029, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-approach-test-mouse006_task3_approach_persp=0.npz -> shape (150, 3029) = (15×10) × 3029
# [ego_kinematics_seq=task3-approach-test-mouse006_task3_approach_persp=1.npz] ego_feats=15, frames=3029, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-approach-test-mouse006_task3_approach_persp=1.npz -> shape (150, 3029) = (15×10) × 3029
# [ego_kinematics_seq=task3-approach-test-mouse007_task3_approach_persp=0.npz] ego_feats=15, frames=10025, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-approach-test-mouse007_task3_approach_persp=0.npz -> shape (150, 10025) = (15×10) × 10025
# [ego_kinematics_seq=task3-approach-test-mouse007_task3_approach_persp=1.npz] ego_feats=15, frames=10025, fps=30.000 -> computing wavelets...
# ...
# [ego_kinematics_seq=task3-sniff_face-test-mouse028_task3_sniff_face_persp=1.npz] ego_feats=15, frames=1036, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse028_task3_sniff_face_persp=1.npz -> shape (150, 1036) = (15×10) × 1036
# [ego_kinematics_seq=task3-sniff_face-test-mouse029_task3_sniff_face_persp=0.npz] ego_feats=15, frames=3041, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse029_task3_sniff_face_persp=0.npz -> shape (150, 3041) = (15×10) × 3041
# [ego_kinematics_seq=task3-sniff_face-test-mouse029_task3_sniff_face_persp=1.npz] ego_feats=15, frames=3041, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse029_task3_sniff_face_persp=1.npz -> shape (150, 3041) = (15×10) × 3041
# [ego_kinematics_seq=task3-sniff_face-test-mouse030_task3_sniff_face_persp=0.npz] ego_feats=15, frames=1607, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse030_task3_sniff_face_persp=0.npz -> shape (150, 1607) = (15×10) × 1607
# [ego_kinematics_seq=task3-sniff_face-test-mouse030_task3_sniff_face_persp=1.npz] ego_feats=15, frames=1607, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse030_task3_sniff_face_persp=1.npz -> shape (150, 1607) = (15×10) × 1607
# [ego_kinematics_seq=task3-sniff_face-test-mouse031_task3_sniff_face_persp=0.npz] ego_feats=15, frames=5096, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse031_task3_sniff_face_persp=0.npz -> shape (150, 5096) = (15×10) × 5096
# [ego_kinematics_seq=task3-sniff_face-test-mouse031_task3_sniff_face_persp=1.npz] ego_feats=15, frames=5096, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse031_task3_sniff_face_persp=1.npz -> shape (150, 5096) = (15×10) × 5096
# [ego_kinematics_seq=task3-sniff_face-test-mouse032_task3_sniff_face_persp=0.npz] ego_feats=15, frames=5763, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse032_task3_sniff_face_persp=0.npz -> shape (150, 5763) = (15×10) × 5763
# [ego_kinematics_seq=task3-sniff_face-test-mouse032_task3_sniff_face_persp=1.npz] ego_feats=15, frames=5763, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse032_task3_sniff_face_persp=1.npz -> shape (150, 5763) = (15×10) × 5763
# [ego_kinematics_seq=task3-sniff_face-test-mouse033_task3_sniff_face_persp=0.npz] ego_feats=15, frames=2497, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse033_task3_sniff_face_persp=0.npz -> shape (150, 2497) = (15×10) × 2497
# [ego_kinematics_seq=task3-sniff_face-test-mouse033_task3_sniff_face_persp=1.npz] ego_feats=15, frames=2497, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse033_task3_sniff_face_persp=1.npz -> shape (150, 2497) = (15×10) × 2497
# [ego_kinematics_seq=task3-sniff_face-test-mouse034_task3_sniff_face_persp=0.npz] ego_feats=15, frames=4879, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse034_task3_sniff_face_persp=0.npz -> shape (150, 4879) = (15×10) × 4879
# [ego_kinematics_seq=task3-sniff_face-test-mouse034_task3_sniff_face_persp=1.npz] ego_feats=15, frames=4879, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse034_task3_sniff_face_persp=1.npz -> shape (150, 4879) = (15×10) × 4879
# [ego_kinematics_seq=task3-sniff_face-test-mouse035_task3_sniff_face_persp=0.npz] ego_feats=15, frames=5133, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse035_task3_sniff_face_persp=0.npz -> shape (150, 5133) = (15×10) × 5133
# [ego_kinematics_seq=task3-sniff_face-test-mouse035_task3_sniff_face_persp=1.npz] ego_feats=15, frames=5133, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse035_task3_sniff_face_persp=1.npz -> shape (150, 5133) = (15×10) × 5133
# [ego_kinematics_seq=task3-sniff_face-test-mouse036_task3_sniff_face_persp=0.npz] ego_feats=15, frames=2796, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse036_task3_sniff_face_persp=0.npz -> shape (150, 2796) = (15×10) × 2796
# [ego_kinematics_seq=task3-sniff_face-test-mouse036_task3_sniff_face_persp=1.npz] ego_feats=15, frames=2796, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse036_task3_sniff_face_persp=1.npz -> shape (150, 2796) = (15×10) × 2796
# [ego_kinematics_seq=task3-sniff_face-test-mouse037_task3_sniff_face_persp=0.npz] ego_feats=15, frames=3188, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse037_task3_sniff_face_persp=0.npz -> shape (150, 3188) = (15×10) × 3188
# [ego_kinematics_seq=task3-sniff_face-test-mouse037_task3_sniff_face_persp=1.npz] ego_feats=15, frames=3188, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse037_task3_sniff_face_persp=1.npz -> shape (150, 3188) = (15×10) × 3188
# [ego_kinematics_seq=task3-sniff_face-test-mouse038_task3_sniff_face_persp=0.npz] ego_feats=15, frames=2643, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse038_task3_sniff_face_persp=0.npz -> shape (150, 2643) = (15×10) × 2643
# [ego_kinematics_seq=task3-sniff_face-test-mouse038_task3_sniff_face_persp=1.npz] ego_feats=15, frames=2643, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse038_task3_sniff_face_persp=1.npz -> shape (150, 2643) = (15×10) × 2643
# [ego_kinematics_seq=task3-sniff_face-test-mouse039_task3_sniff_face_persp=0.npz] ego_feats=15, frames=3351, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse039_task3_sniff_face_persp=0.npz -> shape (150, 3351) = (15×10) × 3351
# [ego_kinematics_seq=task3-sniff_face-test-mouse039_task3_sniff_face_persp=1.npz] ego_feats=15, frames=3351, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse039_task3_sniff_face_persp=1.npz -> shape (150, 3351) = (15×10) × 3351
# [ego_kinematics_seq=task3-sniff_face-test-mouse040_task3_sniff_face_persp=0.npz] ego_feats=15, frames=974, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse040_task3_sniff_face_persp=0.npz -> shape (150, 974) = (15×10) × 974
# [ego_kinematics_seq=task3-sniff_face-test-mouse040_task3_sniff_face_persp=1.npz] ego_feats=15, frames=974, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse040_task3_sniff_face_persp=1.npz -> shape (150, 974) = (15×10) × 974
# [ego_kinematics_seq=task3-sniff_face-test-mouse041_task3_sniff_face_persp=0.npz] ego_feats=15, frames=3394, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse041_task3_sniff_face_persp=0.npz -> shape (150, 3394) = (15×10) × 3394
# [ego_kinematics_seq=task3-sniff_face-test-mouse041_task3_sniff_face_persp=1.npz] ego_feats=15, frames=3394, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse041_task3_sniff_face_persp=1.npz -> shape (150, 3394) = (15×10) × 3394
# [ego_kinematics_seq=task3-sniff_face-test-mouse042_task3_sniff_face_persp=0.npz] ego_feats=15, frames=5065, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse042_task3_sniff_face_persp=0.npz -> shape (150, 5065) = (15×10) × 5065
# [ego_kinematics_seq=task3-sniff_face-test-mouse042_task3_sniff_face_persp=1.npz] ego_feats=15, frames=5065, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse042_task3_sniff_face_persp=1.npz -> shape (150, 5065) = (15×10) × 5065
# [ego_kinematics_seq=task3-sniff_face-test-mouse043_task3_sniff_face_persp=0.npz] ego_feats=15, frames=2751, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse043_task3_sniff_face_persp=0.npz -> shape (150, 2751) = (15×10) × 2751
# [ego_kinematics_seq=task3-sniff_face-test-mouse043_task3_sniff_face_persp=1.npz] ego_feats=15, frames=2751, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse043_task3_sniff_face_persp=1.npz -> shape (150, 2751) = (15×10) × 2751
# [ego_kinematics_seq=task3-sniff_face-test-mouse044_task3_sniff_face_persp=0.npz] ego_feats=15, frames=1213, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse044_task3_sniff_face_persp=0.npz -> shape (150, 1213) = (15×10) × 1213
# [ego_kinematics_seq=task3-sniff_face-test-mouse044_task3_sniff_face_persp=1.npz] ego_feats=15, frames=1213, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse044_task3_sniff_face_persp=1.npz -> shape (150, 1213) = (15×10) × 1213
# [ego_kinematics_seq=task3-sniff_face-test-mouse045_task3_sniff_face_persp=0.npz] ego_feats=15, frames=2885, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse045_task3_sniff_face_persp=0.npz -> shape (150, 2885) = (15×10) × 2885
# [ego_kinematics_seq=task3-sniff_face-test-mouse045_task3_sniff_face_persp=1.npz] ego_feats=15, frames=2885, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse045_task3_sniff_face_persp=1.npz -> shape (150, 2885) = (15×10) × 2885
# [ego_kinematics_seq=task3-sniff_face-test-mouse046_task3_sniff_face_persp=0.npz] ego_feats=15, frames=3996, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse046_task3_sniff_face_persp=0.npz -> shape (150, 3996) = (15×10) × 3996
# [ego_kinematics_seq=task3-sniff_face-test-mouse046_task3_sniff_face_persp=1.npz] ego_feats=15, frames=3996, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse046_task3_sniff_face_persp=1.npz -> shape (150, 3996) = (15×10) × 3996
# [ego_kinematics_seq=task3-sniff_face-test-mouse047_task3_sniff_face_persp=0.npz] ego_feats=15, frames=7754, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse047_task3_sniff_face_persp=0.npz -> shape (150, 7754) = (15×10) × 7754
# [ego_kinematics_seq=task3-sniff_face-test-mouse047_task3_sniff_face_persp=1.npz] ego_feats=15, frames=7754, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse047_task3_sniff_face_persp=1.npz -> shape (150, 7754) = (15×10) × 7754
# [ego_kinematics_seq=task3-sniff_face-test-mouse048_task3_sniff_face_persp=0.npz] ego_feats=15, frames=13170, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse048_task3_sniff_face_persp=0.npz -> shape (150, 13170) = (15×10) × 13170
# [ego_kinematics_seq=task3-sniff_face-test-mouse048_task3_sniff_face_persp=1.npz] ego_feats=15, frames=13170, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse048_task3_sniff_face_persp=1.npz -> shape (150, 13170) = (15×10) × 13170
# [ego_kinematics_seq=task3-sniff_face-test-mouse049_task3_sniff_face_persp=0.npz] ego_feats=15, frames=7150, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse049_task3_sniff_face_persp=0.npz -> shape (150, 7150) = (15×10) × 7150
# [ego_kinematics_seq=task3-sniff_face-test-mouse049_task3_sniff_face_persp=1.npz] ego_feats=15, frames=7150, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse049_task3_sniff_face_persp=1.npz -> shape (150, 7150) = (15×10) × 7150
# [ego_kinematics_seq=task3-sniff_face-test-mouse050_task3_sniff_face_persp=0.npz] ego_feats=15, frames=8103, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse050_task3_sniff_face_persp=0.npz -> shape (150, 8103) = (15×10) × 8103
# [ego_kinematics_seq=task3-sniff_face-test-mouse050_task3_sniff_face_persp=1.npz] ego_feats=15, frames=8103, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-test-mouse050_task3_sniff_face_persp=1.npz -> shape (150, 8103) = (15×10) × 8103
# [ego_kinematics_seq=task3-sniff_face-train-mouse001_task3_sniff_face_persp=0.npz] ego_feats=15, frames=8994, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-train-mouse001_task3_sniff_face_persp=0.npz -> shape (150, 8994) = (15×10) × 8994
# [ego_kinematics_seq=task3-sniff_face-train-mouse001_task3_sniff_face_persp=1.npz] ego_feats=15, frames=8994, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-train-mouse001_task3_sniff_face_persp=1.npz -> shape (150, 8994) = (15×10) × 8994
# [ego_kinematics_seq=task3-sniff_face-train-mouse002_task3_sniff_face_persp=0.npz] ego_feats=15, frames=5495, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-train-mouse002_task3_sniff_face_persp=0.npz -> shape (150, 5495) = (15×10) × 5495
# [ego_kinematics_seq=task3-sniff_face-train-mouse002_task3_sniff_face_persp=1.npz] ego_feats=15, frames=5495, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-train-mouse002_task3_sniff_face_persp=1.npz -> shape (150, 5495) = (15×10) × 5495
# [ego_kinematics_seq=task3-sniff_face-train-mouse003_task3_sniff_face_persp=0.npz] ego_feats=15, frames=4755, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-train-mouse003_task3_sniff_face_persp=0.npz -> shape (150, 4755) = (15×10) × 4755
# [ego_kinematics_seq=task3-sniff_face-train-mouse003_task3_sniff_face_persp=1.npz] ego_feats=15, frames=4755, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-sniff_face-train-mouse003_task3_sniff_face_persp=1.npz -> shape (150, 4755) = (15×10) × 4755
# [ego_kinematics_seq=task3-whiterearing-test-mouse003_task3_whiterearing_persp=0.npz] ego_feats=15, frames=17939, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-whiterearing-test-mouse003_task3_whiterearing_persp=0.npz -> shape (150, 17939) = (15×10) × 17939
# [ego_kinematics_seq=task3-whiterearing-test-mouse003_task3_whiterearing_persp=1.npz] ego_feats=15, frames=17939, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-whiterearing-test-mouse003_task3_whiterearing_persp=1.npz -> shape (150, 17939) = (15×10) × 17939
# [ego_kinematics_seq=task3-whiterearing-train-mouse001_task3_whiterearing_persp=0.npz] ego_feats=15, frames=18400, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-whiterearing-train-mouse001_task3_whiterearing_persp=0.npz -> shape (150, 18400) = (15×10) × 18400
# [ego_kinematics_seq=task3-whiterearing-train-mouse001_task3_whiterearing_persp=1.npz] ego_feats=15, frames=18400, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-whiterearing-train-mouse001_task3_whiterearing_persp=1.npz -> shape (150, 18400) = (15×10) × 18400
# [ego_kinematics_seq=task3-whiterearing-train-mouse002_task3_whiterearing_persp=0.npz] ego_feats=15, frames=17781, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-whiterearing-train-mouse002_task3_whiterearing_persp=0.npz -> shape (150, 17781) = (15×10) × 17781
# [ego_kinematics_seq=task3-whiterearing-train-mouse002_task3_whiterearing_persp=1.npz] ego_feats=15, frames=17781, fps=30.000 -> computing wavelets...
# [EGO WAVELET SAVE] wavelet_ego_seq=task3-whiterearing-train-mouse002_task3_whiterearing_persp=1.npz -> shape (150, 17781) = (15×10) × 17781
# All egocentric wavelet spectrograms done.

# %% [markdown]
# # tSNE - social

# %%
# ============================================================
# Global t-SNE with template training + mapping (openTSNE)
# Combines pair-level social wavelets + egocentric wavelets
#   - wavelet_social_seq=<SAFESEQ>_persp=<p>.npz
#   - wavelet_ego_seq=<SAFESEQ>_persp=<p>.npz
#
# pip install openTSNE joblib scikit-learn
# ============================================================
import os
import re
import numpy as np
from pathlib import Path
from sklearn.preprocessing import StandardScaler
from openTSNE import TSNEEmbedding, affinity, initialization
import joblib

# ----------------------------
# Config
# ----------------------------
IN_DIR = Path(base + "socialmapper_outputs")

SOCIAL_PATTERN = "wavelet_social_seq=*persp=*.npz"   # pair-level wavelets
EGO_PATTERN    = "wavelet_ego_seq=*persp=*.npz"      # egocentric wavelets

INCLUDE_SOCIAL = True
INCLUDE_EGO    = True

RANDOM_STATE = 42
R_SCALER   = 200_000       # cap for fitting the scaler
T          = 2000          # total number of global templates
CHUNK      = 20_000        # mapping chunk size
PERPLEXITY = 50
N_JOBS     = 8
K_PARTIAL  = 25            # neighbors for prepare_partial
PARTIAL_ITERS = 100
PARTIAL_LR    = 1.0

rng = np.random.default_rng(RANDOM_STATE)

# ----------------------------
# 0) Discover files and index by (safe_seq, persp)
# ----------------------------
def _parse_key(stem: str, fallback_seq="unknownseq", fallback_p=0):
    m_seq = re.search(r"seq=(.+)_persp=", stem)
    m_p   = re.search(r"persp=(\d+)", stem)
    safe_seq = m_seq.group(1) if m_seq else fallback_seq
    persp    = int(m_p.group(1)) if m_p else int(fallback_p)
    return str(safe_seq), int(persp)

social_files = { _parse_key(p.stem): p for p in sorted(IN_DIR.glob(SOCIAL_PATTERN)) } if INCLUDE_SOCIAL else {}
ego_files    = { _parse_key(p.stem): p for p in sorted(IN_DIR.glob(EGO_PATTERN)) }    if INCLUDE_EGO    else {}

all_keys = sorted(set(social_files.keys()) | set(ego_files.keys()))
if not all_keys:
    raise FileNotFoundError(f"No inputs found in {IN_DIR} matching {SOCIAL_PATTERN} or {EGO_PATTERN}")

print(f"Keys with social only: {len(set(social_files)-set(ego_files))} | "
      f"ego only: {len(set(ego_files)-set(social_files))} | both: {len(set(social_files)&set(ego_files))}")

# ----------------------------
# 1) Load per-key, concat features (frames, feats)
# ----------------------------
features_per_key = {}
n_total = 0

for key in all_keys:
    X_parts = []
    T_list  = []

    # Social
    if key in social_files:
        npz = np.load(social_files[key])
        Xs  = np.asarray(npz["spectrogram"]).T  # (T, D_s)
        X_parts.append(Xs); T_list.append(Xs.shape[0])
    # Ego
    if key in ego_files:
        npz = np.load(ego_files[key])
        Xe  = np.asarray(npz["spectrogram"]).T  # (T, D_e)
        X_parts.append(Xe); T_list.append(Xe.shape[0])

    if not X_parts:
        continue

    # Align lengths if needed
    T_min = min(T_list)
    X_parts = [Xp[:T_min] for Xp in X_parts]

    X_comb = np.hstack(X_parts)  # (T_min, D_total)
    features_per_key[key] = X_comb
    n_total += X_comb.shape[0]

print(f"Loaded & combined features for {len(features_per_key)} (sequence, perspective) pairs; "
      f"total frames ≈ {n_total:,}")

if not features_per_key:
    raise RuntimeError("No combined features available. Check INCLUDE_* flags and inputs.")

keys = list(features_per_key.keys())

# ----------------------------
# 2) Global standardization (fit on capped random sample)
# ----------------------------
sample_pool = []
for key in keys:
    X = features_per_key[key]
    if X.shape[0] == 0:
        continue
    take = min(X.shape[0], max(1000, int(0.05 * X.shape[0])))
    idx = rng.choice(X.shape[0], size=take, replace=False)
    sample_pool.append(X[idx])

X_scaler_sample = np.vstack(sample_pool)
if X_scaler_sample.shape[0] > R_SCALER:
    idx = rng.choice(X_scaler_sample.shape[0], size=R_SCALER, replace=False)
    X_scaler_sample = X_scaler_sample[idx]

scaler = StandardScaler().fit(X_scaler_sample)
def transform_std(X): return scaler.transform(X)

D_total = X_scaler_sample.shape[1]
print(f"Standardizer fitted on {X_scaler_sample.shape[0]:,} rows | D_total={D_total}")

# ----------------------------
# 3) Global template selection (farthest-first over a pre-sample)
#    Coverage across keys by sampling per-key first
# ----------------------------
per_key_quota = max(50, T // max(1, len(keys)))
pre_pool = []
per_key_counts = {}
for key in keys:
    X = features_per_key[key]
    if X.shape[0] == 0:
        continue
    take = min(X.shape[0], per_key_quota * 3)  # oversample per key
    idx = rng.choice(X.shape[0], size=take, replace=False)
    Xs  = transform_std(X[idx])
    pre_pool.append(Xs)
    per_key_counts[key] = Xs.shape[0]

X_pre = np.vstack(pre_pool)
print(f"Pre-pool for farthest-first: {X_pre.shape} across {len(per_key_counts)} keys")

# Farthest-first (k-means++-like) downselect to T templates
sel = [int(rng.integers(0, X_pre.shape[0]))]
d2  = np.sum((X_pre - X_pre[sel[0]])**2, axis=1)
while len(sel) < min(T, X_pre.shape[0]):
    i = int(np.argmax(d2))
    sel.append(i)
    d2 = np.minimum(d2, np.sum((X_pre - X_pre[i])**2, axis=1))

templates = X_pre[np.array(sel)]
print(f"Selected templates: {templates.shape} (T={templates.shape[0]})")

# Save standardized template features for downstream clustering
np.savez_compressed(IN_DIR / "global_templates_features.npz", templates=templates)

# ----------------------------
# 4) Fit openTSNE on templates
# ----------------------------
aff = affinity.PerplexityBasedNN(
    templates,
    perplexity=PERPLEXITY,
    metric="euclidean",
    method="annoy",
    n_jobs=N_JOBS,
    random_state=RANDOM_STATE,
)
init = initialization.pca(templates, random_state=RANDOM_STATE)

emb = TSNEEmbedding(
    init,
    aff,
    negative_gradient_method="fft",
    n_jobs=N_JOBS,
    random_state=RANDOM_STATE,
)
# Optimize (EE + final)
emb.optimize(n_iter=250, exaggeration=12, momentum=0.5, inplace=True, verbose=True)
emb.optimize(n_iter=750, momentum=0.8, inplace=True, verbose=True)

Y_templates = np.asarray(emb)
np.savez_compressed(IN_DIR / "global_tsne_templates.npz", Y=Y_templates, sel=np.array(sel))
joblib.dump(
    {
        "embedding": emb,
        "scaler": scaler,
        "perplexity": PERPLEXITY,
        "include_social": INCLUDE_SOCIAL,
        "include_ego": INCLUDE_EGO,
    },
    IN_DIR / "global_opentsne_embedding.joblib"
)
print("Saved global t-SNE embedding and scaler.")

# ----------------------------
# 5) Map all frames via prepare_partial in CHUNKs
# ----------------------------
print('Mapping frames to embedding')
def map_chunk(embedding: TSNEEmbedding, X_chunk_std: np.ndarray) -> np.ndarray:
    part = embedding.prepare_partial(
        X_chunk_std,
        initialization="median",
        k=K_PARTIAL,
        perplexity=PERPLEXITY
    )
    part = part.optimize(
        n_iter=PARTIAL_ITERS,
        learning_rate=PARTIAL_LR,
        exaggeration=2.0,
        momentum=0.0,
        inplace=False,
        verbose=False
    )
    return np.asarray(part)

mapped_coords = {}
for key in keys:
    X = features_per_key[key]
    if X.shape[0] == 0:
        continue
    Xs = transform_std(X)
    coords = []
    for start in range(0, Xs.shape[0], CHUNK):
        coords.append(map_chunk(emb, Xs[start:start+CHUNK]))
    Y_key = np.vstack(coords)
    mapped_coords[key] = Y_key

    safe_seq, persp = key
    out_name = f"global_tsne_coords_seq={safe_seq}_persp={persp}.npz"
    np.savez_compressed(IN_DIR / out_name, Y=Y_key)

print("Mapped all frames via prepare_partial.")

# %% [markdown]
# ## Clustering

# %%
# ----------------------------
# 5) Global clustering in feature space (k-means on templates) + assign all
# ----------------------------
from sklearn.cluster import KMeans
from sklearn.neighbors import NearestNeighbors
import numpy as np
import joblib
from pathlib import Path

# Assumes these already exist in your notebook from the t-SNE step:
# - IN_DIR: Path(...)
# - templates: standardized template features, shape (T, n_feats)
# - features_per_key: dict[(safe_seq, persp)] -> raw features (n_frames, n_feats)
# - transform_std(X): applies the global StandardScaler
# - keys: list(features_per_key.keys())
# - RANDOM_STATE

RANDOM_STATE = 42

K_CLUSTERS = 4  # adjust as desired

# 1) Fit k-means on standardized templates
kmeans = KMeans(n_clusters=K_CLUSTERS, n_init="auto", random_state=RANDOM_STATE)
kmeans.fit(templates)

# 2) Build a fast assigner using nearest cluster center
assigner = NearestNeighbors(n_neighbors=1).fit(kmeans.cluster_centers_)

# 3) Assign labels to ALL frames for each (sequence, perspective)
for (safe_seq, persp) in keys:
    X = features_per_key[(safe_seq, persp)]            # (n_frames, n_feats) raw
    Xs = transform_std(X)                              # standardize with global scaler
    _, idx = assigner.kneighbors(Xs)                   # nearest center
    labels = idx.ravel().astype(int)                   # 0..K-1

    out_name = f"global_kmeans_labels_seq={safe_seq}_persp={persp}.npz"
    np.savez_compressed(IN_DIR / out_name, labels=labels)

# 4) Save clustering bundle for later reuse
joblib.dump(
    {
        "scaler": scaler,                # global StandardScaler
        "kmeans": kmeans,                # fitted KMeans
        "nn": assigner,                  # NearestNeighbors assigner
        "n_clusters": K_CLUSTERS,
        "feature_space": "social_wavelet_std",  # doc tag
    },
    IN_DIR / "global_kmeans_assigner.joblib"
)

print(f"Global k-means clustering complete (K={K_CLUSTERS}) and labels saved per (sequence, perspective).")

# %%
# --- Ward hierarchy on standardized template features (no fixed K saved) ---
import numpy as np
from pathlib import Path
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# ----------------------------
# Config / I/O
# ----------------------------
IN_DIR = Path(base + "socialmapper_outputs")
IN_DIR.mkdir(exist_ok=True, parents=True)

TEMPLATES_PATH = IN_DIR / "global_templates_features.npz"   # contains 'templates' (STANDARDIZED)
LINKAGE_PATH   = IN_DIR / "global_hierarchical_linkage.joblib"

# ----------------------------
# Load standardized templates (shape: T x n_feats)
# ----------------------------
if not TEMPLATES_PATH.exists():
    raise FileNotFoundError(
        f"Missing {TEMPLATES_PATH.name}. "
        "Make sure you ran the global t-SNE/template step that saves standardized templates."
    )
templates = np.load(TEMPLATES_PATH)["templates"]
print(f"Loaded standardized templates: {templates.shape}")

# ----------------------------
# Build Ward linkage (hierarchy)
# ----------------------------
LINKAGE_METHOD = "ward"  # Ward uses Euclidean
print("Performing hierarchical clustering (Ward) on templates...")
Z = linkage(templates, method=LINKAGE_METHOD)

# ----------------------------
# Preview dendrogram (truncated for readability)
# ----------------------------
plt.figure(figsize=(10, 6))
sns.set(style="whitegrid")
dendrogram(
    Z,
    truncate_mode="level",   # show only top few levels
    p=6,                     # number of levels to display
    no_labels=True,
    color_threshold=None
)
plt.title("Hierarchical Clustering Dendrogram (Ward, truncated)")
plt.xlabel("Template samples")
plt.ylabel("Distance")
plt.tight_layout()
plt.show()

# ----------------------------
# Save ONLY the hierarchy (no fixed K)
# ----------------------------
joblib.dump(
    {
        "linkage_matrix": Z,
        "method": LINKAGE_METHOD,
        # optional provenance:
        # "template_count": templates.shape[0],
        # "feature_dim": templates.shape[1],
    },
    LINKAGE_PATH
)
print(f"Saved Ward linkage to {LINKAGE_PATH.name} (no fixed K).")

# %% [markdown]
# ## visualize results

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# assumes your helper exists: pcacomponentplots(ax, vh, ylabels, colors)
BASE = Path(base + "socialmapper_outputs")

# Force mode? options: "auto", "social", "ego"
MODE = "auto"

# Optional: pose label support for social distances
POSE_N = 7
pose_point_names = [f"P{i}" for i in range(POSE_N)]

# ---------- Detect availability ----------
social_files = sorted(BASE.glob("social_projections_seq=*persp=*.npz"))
ego_pack = BASE / "ego_ipca_global.npz"  # created by the ego IPCA step

if MODE == "auto":
    if social_files:
        mode = "social"
    elif ego_pack.exists():
        mode = "ego"
    else:
        raise FileNotFoundError("No social_projections_* or ego_ipca_global.npz found.")
else:
    mode = MODE.lower()
    if mode == "social" and not social_files:
        raise FileNotFoundError("Requested MODE='social' but no social_projections_seq=* found.")
    if mode == "ego" and not ego_pack.exists():
        raise FileNotFoundError("Requested MODE='ego' but ego_ipca_global.npz not found.")

sns.set_style("white")

if mode == "social":
    # ---- Load one social file (components are global & identical across files) ----
    pnpz = np.load(social_files[0])
    vh   = pnpz["components"]          # (n_components, feat_len) — global IPCA components
    feat_len = int(pnpz["feature_len"])

    include_intra_A = bool(pnpz.get("include_intra_A", True))
    include_intra_B = bool(pnpz.get("include_intra_B", True))
    include_inter   = bool(pnpz.get("include_inter", True))
    tri_i = pnpz["tri_i"] if "tri_i" in pnpz.files else None
    tri_j = pnpz["tri_j"] if "tri_j" in pnpz.files else None

    # Build ylabels in the exact feature order used during building:
    # [intra A (lower-tri)] + [intra B (lower-tri)] + [inter A(i)-B(j) (row-major)]
    ylabels = []

    def add_intra_labels(prefix, tri_i, tri_j):
        for i, j in zip(tri_i, tri_j):
            left  = pose_point_names[i] if i < len(pose_point_names) else f"P{i}"
            right = pose_point_names[j] if j < len(pose_point_names) else f"P{j}"
            ylabels.append(f"{prefix}:{left}–{right}")

    # If intra indices not saved, synthesize for POSE_N
    if tri_i is None or tri_j is None:
        tri_i, tri_j = np.tril_indices(POSE_N, k=-1)

    if include_intra_A:
        add_intra_labels("A", tri_i, tri_j)
    if include_intra_B:
        add_intra_labels("B", tri_i, tri_j)
    if include_inter:
        for i in range(POSE_N):
            for j in range(POSE_N):
                left  = pose_point_names[i] if i < len(pose_point_names) else f"P{i}"
                right = pose_point_names[j] if j < len(pose_point_names) else f"P{j}"
                ylabels.append(f"A:{left} – B:{right}")

    # Align label count to component width
    if len(ylabels) != vh.shape[1]:
        if len(ylabels) > vh.shape[1]:
            ylabels = ylabels[:vh.shape[1]]
        else:
            ylabels += [f"feat_{k}" for k in range(len(ylabels), vh.shape[1])]

    numev_to_show = min(6, vh.shape[0])  # social used 6 PCs in paper
    fig, axes = plt.subplots(1, numev_to_show, figsize=(1.15*numev_to_show, 5),
                             sharex=True, sharey=True)
    if numev_to_show == 1:
        axes = [axes]
    palette = np.array(sns.color_palette("tab20", max(20, numev_to_show)))
    pcacomponentplots(axes, vh[:numev_to_show], ylabels=ylabels, colors=palette[:numev_to_show])
    axes[0].set_title("Social IPCA components (intra A, intra B, inter A–B)", fontsize=13)
    axes[-1].set_xlabel("Component weight", fontsize=12)
    plt.tight_layout(); plt.show()

elif mode == "ego":
    # ---- Load the global ego IPCA pack ----
    enpz = np.load(ego_pack, allow_pickle=True)
    vh = enpz["components_"]           # (n_components, n_features_ego)
    # Names saved as an object array or str array
    if "names" in enpz.files:
        names = enpz["names"]
        try:
            # if stored as object array of strings
            ego_labels = [str(x) for x in names.tolist()]
        except Exception:
            ego_labels = [str(x) for x in names]
    else:
        # fallback: generic names
        ego_labels = [f"ego_feat_{i}" for i in range(vh.shape[1])]

    # Align just in case
    if len(ego_labels) != vh.shape[1]:
        if len(ego_labels) > vh.shape[1]:
            ego_labels = ego_labels[:vh.shape[1]]
        else:
            ego_labels += [f"ego_feat_{k}" for k in range(len(ego_labels), vh.shape[1])]

    numev_to_show = min(10, vh.shape[0])
    fig, axes = plt.subplots(1, numev_to_show, figsize=(1.15*numev_to_show, 5),
                             sharex=True, sharey=True)
    if numev_to_show == 1:
        axes = [axes]
    palette = np.array(sns.color_palette("tab20", max(20, numev_to_show)))
    pcacomponentplots(axes, vh[:numev_to_show], ylabels=ego_labels, colors=palette[:numev_to_show])
    axes[0].set_title("Egocentric IPCA components", fontsize=13)
    axes[-1].set_xlabel("Component weight", fontsize=12)
    plt.tight_layout(); plt.show()

# %%
# --- Global t-SNE scatter colored by clustering (k-means OR Ward re-cut) ---
# Works with combined (social + ego) pipeline
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from sklearn.neighbors import NearestNeighbors
from scipy.cluster.hierarchy import fcluster
import joblib
import re

# ========= CONFIG =========
BASE = Path(base + "socialmapper_outputs")
CLUSTER_MODE = "ward"         # "kmeans" or "ward"
WARD_N_CLUSTERS = 4           # used only in 'ward' mode (tree cut for display)
PLOT_MAX = 300_000            # downsample for speed if needed
# ==========================

coord_files = sorted(BASE.glob("global_tsne_coords_seq=*persp=*.npz"))
if not coord_files:
    raise FileNotFoundError("Expected global_tsne_coords_seq=*persp=*.npz files.")

pat = re.compile(r"global_tsne_coords_seq=(.*)_persp=(\d+)\.npz")


# ---- Load t-SNE coords and keys ----
Y_list, key_list = [], []
for f in coord_files:
    m = pat.match(f.name)
    if not m:
        continue
    safe_seq, persp = m.group(1), int(m.group(2))
    Y = np.load(f)["Y"]  # (n_frames_key, 2)
    Y_list.append(Y)
    key_list.append((safe_seq, persp))

Y_all = np.vstack(Y_list)

mode = CLUSTER_MODE.lower()

if mode == "kmeans":
    # unchanged: uses precomputed per-key labels
    L_list = []
    for (safe_seq, persp) in key_list:
        lab_path = BASE / f"global_kmeans_labels_seq={safe_seq}_persp={persp}.npz"
        if not lab_path.exists():
            raise FileNotFoundError(f"Missing {lab_path.name}")
        labs = np.load(lab_path)["labels"]
        if labs.min() == 1:
            labs = labs - 1
        L_list.append(labs.astype(int))
    L_all = np.concatenate(L_list)
    K = int(L_all.max()) + 1
    title_suffix = f"global k-means clusters (K={K})"

elif mode == "ward":
    # Re-cut Ward tree and assign by nearest centroid in the SAME standardized feature space
    linkage_path       = BASE / "global_hierarchical_linkage.joblib"  # must contain 'linkage_matrix'
    templates_feat_npz = BASE / "global_templates_features.npz"       # 'templates' (standardized)
    scaler_pack_path   = BASE / "global_opentsne_embedding.joblib"    # must contain 'scaler'
    if not (linkage_path.exists() and templates_feat_npz.exists() and scaler_pack_path.exists()):
        raise FileNotFoundError(
            "Ward mode needs:\n"
            f" - {linkage_path.name}\n"
            f" - {templates_feat_npz.name}\n"
            f" - {scaler_pack_path.name}"
        )

    Z = joblib.load(linkage_path)["linkage_matrix"]
    templates = np.load(templates_feat_npz)["templates"]  # (T, D_total), standardized
    labels_templates = fcluster(Z, WARD_N_CLUSTERS, criterion="maxclust")

    uniq = np.unique(labels_templates)
    centroids = np.vstack([templates[labels_templates == c].mean(axis=0) for c in uniq])
    assigner = NearestNeighbors(n_neighbors=1).fit(centroids)

    pack = joblib.load(scaler_pack_path)
    scaler = pack["scaler"]
    expected_D = scaler.n_features_in_

    # Assign each key using COMBINED (social+ego) features
    L_list = []
    for (safe_seq, persp) in key_list:
        X_comb = util.load_combined_features(BASE, safe_seq, persp)
        if X_comb is None:
            raise FileNotFoundError(f"No wavelet features (social/ego) found for seq={safe_seq}, persp={persp}")

        if X_comb.shape[1] != expected_D:
            raise ValueError(
                f"Feature dim mismatch for seq={safe_seq}, persp={persp}: "
                f"got {X_comb.shape[1]}, scaler expects {expected_D}. "
                f"Make sure you combined social+ego the same way as in the t-SNE step."
            )

        Xs = scaler.transform(X_comb)
        _, idx = assigner.kneighbors(Xs)
        L_list.append(idx.ravel().astype(int))

    L_all = np.concatenate(L_list)
    K = int(L_all.max()) + 1
    title_suffix = f"global Ward clusters (cut={WARD_N_CLUSTERS}, K={K})"

else:
    raise ValueError("CLUSTER_MODE must be 'kmeans' or 'ward'.")

# ---- Optional downsampling for plotting speed ----
if Y_all.shape[0] > PLOT_MAX:
    rng = np.random.default_rng(42)
    sel = rng.choice(Y_all.shape[0], size=PLOT_MAX, replace=False)
    Y_plot = Y_all[sel]
    L_plot = L_all[sel]
else:
    Y_plot = Y_all
    L_plot = L_all

# ---- Templates overlay (optional) ----
tmpl_file = BASE / "global_tsne_templates.npz"
Y_templates = np.load(tmpl_file)["Y"] if tmpl_file.exists() else None

# ---- Plot ----
sns.set_style("white")
fig, ax = plt.subplots(1, 1, figsize=(8, 7))
_ = viz.plot_tsne_withcolors(
    ax=ax,
    tsne_result=Y_plot,
    quantity=L_plot.astype(int),
    title=f"Global t-SNE (all sequences, perspectives) colored by {title_suffix}",
    colortype='categorical',
    qmin=0.01, qmax=0.99,
    alphaval=0.35,
    s=2,
    coloroffset=0,
    cmapname='cool',
    setxylimquantile=False
)
ax.set_xlabel("t-SNE 1"); ax.set_ylabel("t-SNE 2")

if Y_templates is not None and Y_templates.size > 0:
    ax.scatter(Y_templates[:, 0], Y_templates[:, 1],
               s=12, facecolors='none', edgecolors='k', linewidths=0.8,
               alpha=0.25, label="Templates")
    ax.legend(frameon=False, loc="best")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### raster plot

# %%
# --- Raster plot over time (pair-level seq/persp), k-means / Ward / GT ---
import os
import re
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from pathlib import Path
import seaborn as sns
from sklearn.neighbors import NearestNeighbors
from scipy.cluster.hierarchy import fcluster
import joblib

# ========= CONFIG =========
BASE = Path(base + "socialmapper_outputs")

safe_seq = "task1-test-mouse071_task1_annotator1"   # EXACT safe name used in your saved files
persp    = 0                                        # 0 or 1

# CLUSTER_MODE can be: "kmeans", "ward", or "gt"
CLUSTER_MODE    = "ward"
WARD_N_CLUSTERS = 4

CALMS21_NPYS = [
    Path(os.path.join(datadir, "calms21_task1_train.npy")),
    Path(os.path.join(datadir, "calms21_task1_test.npy")),
]
# ==========================



# ---------- Common paths ----------
linkage_path       = BASE / "global_hierarchical_linkage.joblib"
templates_feat_npz = BASE / "global_templates_features.npz"
scaler_pack_path   = BASE / "global_opentsne_embedding.joblib"
kmeans_pack_path   = BASE / "global_kmeans_assigner.joblib"

# ---------- Load features (pair + egocentric) ----------
pair_w = util.load_pair_wavelet(BASE, safe_seq, persp)
fps = util.fps_from_npz(pair_w, default=1.0)

try:
    ego_w = load_ego_wavelet(BASE, safe_seq, persp)
    X_concat, n_frames = concat_pair_ego_features(pair_w, ego_w)  # (T, F_pair+F_ego)
    print('Missing wavelets')
except FileNotFoundError as e:
    # Fall back to pair-only if ego wavelet is missing
    print(f"[WARN] {e}. Falling back to pair-only features.")
    X_pair = np.asarray(pair_w["spectrogram"]).T
    X_concat, n_frames = X_pair, X_pair.shape[0]

# ---------- Labels ----------
mode = CLUSTER_MODE.lower()
if mode == "kmeans":
    # Prefer precomputed labels that were produced on concatenated features (if you saved them)
    pre_path = BASE / f"global_kmeans_labels_seq={safe_seq}_persp={persp}.npz"
    if pre_path.exists():
        labs = np.load(pre_path)["labels"].astype(int)
        # if lengths differ due to concat truncation, align:
        if labs.shape[0] != n_frames:
            m = min(labs.shape[0], n_frames)
            labs = labs[:m]
            X_concat = X_concat[:m]
            n_frames = m
    else:
        if not kmeans_pack_path.exists():
            raise FileNotFoundError("Missing global_kmeans_assigner.joblib and no precomputed labels found.")
        pack = joblib.load(kmeans_pack_path)
        scaler = pack["scaler"]
        assigner = pack["nn"]  # NearestNeighbors over k-means centroids
        # Guard on feature count
        if getattr(scaler, "n_features_in_", None) and scaler.n_features_in_ != X_concat.shape[1]:
            raise ValueError(f"Concatenated features have {X_concat.shape[1]} dims, "
                             f"but scaler expects {scaler.n_features_in_}. "
                             f"Ensure you concatenated [pair || ego] exactly like when you fit the scaler.")
        Xs = scaler.transform(X_concat)
        _, idx = assigner.kneighbors(Xs)
        labs = idx.ravel().astype(int)
    mode_str = f"k-means (K={int(labs.max())+1})"

elif mode == "ward":
    if not (linkage_path.exists() and templates_feat_npz.exists() and scaler_pack_path.exists()):
        raise FileNotFoundError(
            "Ward mode needs:\n"
            f" - {linkage_path.name}\n - {templates_feat_npz.name}\n - {scaler_pack_path.name}"
        )
    Z = joblib.load(linkage_path)["linkage_matrix"]
    templates = np.load(templates_feat_npz)["templates"]  # standardized features used for tree
    labels_templates = fcluster(Z, WARD_N_CLUSTERS, criterion="maxclust")
    uniq = np.unique(labels_templates)
    centroids = np.vstack([templates[labels_templates == c].mean(axis=0) for c in uniq])
    assigner = NearestNeighbors(n_neighbors=1).fit(centroids)

    scaler = joblib.load(scaler_pack_path)["scaler"]
    if getattr(scaler, "n_features_in_", None) and scaler.n_features_in_ != X_concat.shape[1]:
        raise ValueError(f"Concatenated features have {X_concat.shape[1]} dims, "
                         f"but scaler expects {scaler.n_features_in_}. "
                         f"Make sure both pair AND egocentric wavelets are loaded and concatenated.")
    Xs = scaler.transform(X_concat)
    _, idx = assigner.kneighbors(Xs)
    labs = idx.ravel().astype(int)
    mode_str = f"Ward (cut={WARD_N_CLUSTERS}, K={int(labs.max())+1})"

elif mode == "gt":
    raw_seq = to_raw_seq(safe_seq)
    gt = load_gt_labels_from_many(CALMS21_NPYS, raw_seq).astype(int)
    n_use = min(n_frames, gt.shape[0])
    labs = gt[:n_use]
    n_frames = n_use
    X_concat = X_concat[:n_use]
    mode_str = "Ground truth (Task-1: attack / investigation / mount / other)"
else:
    raise ValueError("CLUSTER_MODE must be 'kmeans', 'ward', or 'gt'.")

# ---------- Normalize labels & K ----------
if labs.min() == 1:
    labs = labs - 1
K = int(labs.max()) + 1

# ---------- Raster ----------
M = np.zeros((K, n_frames), dtype=int)
for k in range(K):
    M[k, labs == k] = k + 1

Tsec = n_frames / max(fps, 1e-9)
is_gt = (mode == "gt")
yticklabels = ["attack", "investigation", "mount", "other"] if (is_gt and K == 4) else [str(k) for k in range(K)]
palette = sns.color_palette("Set2", 4) if (is_gt and K == 4) else sns.color_palette("tab20", max(20, K))[:K]
cmap = ListedColormap([(1,1,1,1)] + [tuple(c) + (1.0,) for c in palette])

fig, ax = plt.subplots(figsize=(12, 6))
ax.imshow(M, aspect="auto", interpolation="nearest", cmap=cmap, vmin=0, vmax=K,
          extent=[0, Tsec, K - 0.5, -0.5])
ax.set_title(f"Raster over time — seq={safe_seq}, persp={persp} — {mode_str}")
ax.set_xlabel("Time (s)")
ax.set_ylabel("Class" if is_gt else "Cluster ID")
ax.set_yticks(range(K))
ax.set_yticklabels(yticklabels)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Video - check pose on raw video

# %%
# Debug overlay: step through video and draw pose points on frames
# Works in JupyterLab; uses matplotlib for display and input() for stepping.

import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
from pathlib import Path
from IPython.display import clear_output, display

# -----------------------
# CONFIG
# -----------------------
video_path = '/Volumes/JD-SSD/mice_data/calms21/task1_videos_mp4/test/mouse071_task1_annotator1.mp4'
tracks_df  = df   # your DataFrame with pose + centroids
frame_col  = "frame"
id_col     = "id"

# Pose columns (7 points)
POSE_N       = 7
POSE_X_COLS  = [f"poseX{i}" for i in range(POSE_N)]
POSE_Y_COLS  = [f"poseY{i}" for i in range(POSE_N)]

# Centroid columns
CX_COL = "X#wcentroid"
CY_COL = "Y#wcentroid"

# Visualization controls
SKIP            = 50     # show every Nth frame (set 1 for frame-by-frame)
POINT_SIZE      = 30     # matplotlib scatter size
CENTROID_SIZE   = 80
ID_COLORS       = {0: 'lime', 1: 'orange'}  # color per animal id
DRAW_SKELETON   = False  # set True if you want lines between landmarks (need an order)
SKELETON_EDGES  = [(0,3),(3,4),(4,5),(5,6)]  # example chain if you enable DRAW_SKELETON

# Geometry/units
USE_CM_PER_PIXEL = False   # set True if your df coords are in *cm* and you have cm_per_pixel
CM_PER_PIXEL      = tracks_df.get('cm_per_pixel', pd.Series([1.0])).iloc[0] if 'cm_per_pixel' in tracks_df.columns else 1.0

Y_INVERT = False           # set True if df Y is bottom-origin (0=bottom) but video is top-origin (0=top)
# -----------------------

# Minimal sanity
need = [frame_col, id_col, CX_COL, CY_COL] + POSE_X_COLS + POSE_Y_COLS
missing = [c for c in need if c not in tracks_df.columns]
if missing:
    raise ValueError(f"tracks_df missing columns: {missing}")

# Keep only valid rows and cast frame to int
tdf = tracks_df[need].replace([np.inf,-np.inf], np.nan).dropna(subset=[frame_col, id_col])
tdf = tdf.copy()
tdf[frame_col] = tdf[frame_col].astype(int)
tdf[id_col]    = tdf[id_col].astype(int)

# Group by frame for fast lookup
frame_groups = tdf.groupby(frame_col)

# Open video
cap = cv2.VideoCapture(str(video_path))
if not cap.isOpened():
    raise IOError(f"Cannot open video: {video_path}")
H = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
W = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
N = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
print(f"Video: {W}x{H}, frames={N}")

def to_pixels(val):
    """Convert df coordinate to pixel coordinate if needed."""
    if USE_CM_PER_PIXEL:
        return val / CM_PER_PIXEL
    return val

def maybe_invert_y(y_pix):
    if Y_INVERT:
        return H - y_pix
    return y_pix

# Stepping loop
fidx = 0
try:
    while True:
        ret, frame_bgr = cap.read()
        if not ret:
            print("End of video.")
            break

        if fidx % SKIP != 0:
            fidx += 1
            continue

        # Convert to RGB for matplotlib
        frame_rgb = cv2.cvtColor(frame_bgr, cv2.COLOR_BGR2RGB)

        # Prepare overlay for this frame
        fig, ax = plt.subplots(figsize=(8, 6))
        ax.imshow(frame_rgb)
        ax.set_title(f"Frame {fidx}")
        ax.axis('off')

        if fidx in frame_groups.groups:
            g = frame_groups.get_group(fidx)

            for uid, g_uid in g.groupby(id_col):
                color = ID_COLORS.get(uid, 'cyan')

                # Pose points
                xs = to_pixels(g_uid[POSE_X_COLS].to_numpy().squeeze())
                ys = to_pixels(g_uid[POSE_Y_COLS].to_numpy().squeeze())
                # (handle case where group has >1 row per id due to duplicates)
                if xs.ndim == 2:  # choose first row if duplicates
                    xs = xs[0]
                    ys = ys[0]

                xs_pix = xs.astype(float)
                ys_pix = ys.astype(float)
                ys_pix = np.array([maybe_invert_y(v) for v in ys_pix])

                ax.scatter(xs_pix, ys_pix, s=POINT_SIZE, c=color, edgecolors='k', linewidths=0.5, label=f"id {uid}")

                if DRAW_SKELETON:
                    for a,b in SKELETON_EDGES:
                        ax.plot([xs_pix[a], xs_pix[b]], [ys_pix[a], ys_pix[b]], c=color, linewidth=1)

                # Centroid
                cx = to_pixels(g_uid[CX_COL].iloc[0])
                cy = to_pixels(g_uid[CY_COL].iloc[0])
                cy = maybe_invert_y(cy)
                ax.scatter([cx], [cy], s=CENTROID_SIZE, c=color, marker='x', linewidths=1.5)

                # Label near centroid
                ax.text(cx+5, cy-5, f"id {uid}", color=color, fontsize=10, weight='bold',
                        bbox=dict(facecolor='black', alpha=0.3, edgecolor='none', pad=1))

        clear_output(wait=True)
        display(fig)
        plt.close(fig)

        # Simple stepping: Enter to continue, 'q' to quit
        cmd = input("Enter=next, number=skip to frame, q=quit: ").strip().lower()
        if cmd == 'q':
            break
        elif cmd.isdigit():
            # jump to a specific frame index
            target = int(cmd)
            if 0 <= target < N:
                cap.set(cv2.CAP_PROP_POS_FRAMES, target)
                fidx = target
                continue

        fidx += 1

finally:
    cap.release()
    print("Released video.")

# %% [markdown]
# # Visualize - video output

# %% [markdown]
# ### Egocentric per-ID crops

# %%
# Egocentric per-ID crops from a video, rotated by heading to +x
# Requires: pandas as pd, numpy as np, opencv-python as cv2

import os
from pathlib import Path
import numpy as np
import pandas as pd
import cv2

# -----------------------
# CONFIG
# -----------------------
# video_path    = "/Volumes/JD-SSD/ESI-mice/concat_2024-11-11.mp4"   # <- set
video_path = '/Volumes/JD-SSD/mice_data/calms21/task1_videos_mp4/test/mouse071_task1_annotator1.mp4'
tracks_df     = df                         # <- your DataFrame already loaded in memory
x_col         = "X#wcentroid"
# df['Yinv'] = 570-df['Y#wcentroid']
y_col         = "Y#wcentroid"
angle_col     = "ANGLE"
frame_col     = "frame"
id_col        = "id"

maxframenum = 10000

# Output crop size (pixels)
L, W = 200, 340                 # height (rows), width (cols) of final crop
MARGIN_FACTOR = 1.4             # pre-rotation crop = 1.4 * max(L, W)
BORDER_MODE   = cv2.BORDER_REPLICATE  # how to pad near edges: REPLICATE, CONSTANT, REFLECT, etc.

output_root   = Path(os.path.join(base,"socialmapper_outputs","egocentric_crops"))  # root dir for outputs
output_root.mkdir(parents=True, exist_ok=True)

# -----------------------
# PREP
# -----------------------
# Minimal columns check
for c in [x_col, y_col, angle_col, frame_col, id_col]:
    if c not in tracks_df.columns:
        raise ValueError(f"tracks_df missing required column: {c}")

# Determine if ANGLE is in degrees or radians
angle_in_degrees = viz.infer_angle_degrees(tracks_df[angle_col])

# Build per-frame index: {frame_idx: rows_for_all_ids}
# Keep only rows with finite X,Y,ANGLE
tdf = tracks_df[[frame_col, id_col, x_col, y_col, angle_col]].copy()
tdf = tdf.replace([np.inf, -np.inf], np.nan).dropna(subset=[x_col, y_col, angle_col, frame_col, id_col])
tdf[frame_col] = tdf[frame_col].astype(int)
frame_groups = tdf.groupby(frame_col)

# Pre-crop square side
S = int(np.ceil(MARGIN_FACTOR * max(L, W)))
halfS = S // 2

# -----------------------
# PROCESS VIDEO SEQUENTIALLY
# -----------------------
cap = cv2.VideoCapture(video_path)
if not cap.isOpened():
    raise IOError(f"Cannot open video: {video_path}")

total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

print(f"Writing egocentric crops to: {output_root.resolve()}")
print(f"Final crop size: {L}x{W} (pre-rotation square: {S}x{S})")

fidx = 0
while True:
    ret, frame_bgr = cap.read()
    if not ret:
        break

    # If no tracks for this frame, skip fast
    if fidx not in frame_groups.groups:
        fidx += 1
        continue
    if np.mod(fidx,1000)==0:
        print(fidx,maxframenum)
    if fidx>=maxframenum:
        break
    rows = frame_groups.get_group(fidx)

    # Process each ID present at this frame
    for _, row in rows.iterrows():
        uid   = int(row[id_col])
        cx    = float(row[x_col])/cm_per_pixel
        cy    = float(row[y_col])/cm_per_pixel
        theta = -float(row[angle_col])

        # Convert angle -> degrees for cv2
        theta_deg = theta if angle_in_degrees else np.degrees(theta)
        rot_deg   = - theta_deg

        # 1) Pre-rotation crop (SxS) centered at centroid
        x0 = cx - halfS
        y0 = cy - halfS
        x1 = cx + halfS
        y1 = cy + halfS
        roi = viz.safe_crop_with_padding(frame_bgr, x0, y0, x1, y1, BORDER_MODE)

        # 2) Rotate ROI around its center so heading -> +x
        center = (S / 2.0, S / 2.0)
        M = cv2.getRotationMatrix2D(center, rot_deg, 1.0)
        roi_rot = cv2.warpAffine(roi, M, (S, S), flags=cv2.INTER_LINEAR, borderMode=BORDER_MODE)

        # 3) Center-crop to final LxW
        y_center = S // 2
        x_center = S // 2
        y0f = int(y_center - L // 2)
        y1f = y0f + L
        x0f = int(x_center - W // 2)
        x1f = x0f + W

        # Because we padded the pre-crop, these indices are valid
        crop_final = roi_rot[y0f:y1f, x0f:x1f]
        if crop_final.shape[0] != L or crop_final.shape[1] != W:
            # Safety check; pad if needed due to rounding
            crop_final = cv2.copyMakeBorder(
                crop_final,
                top=max(0, L - crop_final.shape[0]),
                bottom=0,
                left=max(0, W - crop_final.shape[1]),
                right=0,
                borderType=BORDER_MODE
            )
            crop_final = crop_final[:L, :W]

        # 4) Save
        out_dir = output_root / f"id_{uid}"
        out_dir.mkdir(parents=True, exist_ok=True)
        out_path = out_dir / f"frame_{fidx:06d}.png"
        cv2.imwrite(str(out_path), crop_final)

    fidx += 1

cap.release()
print("Done.")

# %% [markdown]
# ### composite video

# %%
# === Per-cluster social composites with fixed grid (each cell = fixed perspective/ID) ===
# One video per cluster, frames drawn from egocentric crops whose frames belong to that cluster
import numpy as np
import cv2
from pathlib import Path
from sklearn.neighbors import NearestNeighbors
from scipy.cluster.hierarchy import fcluster
import joblib
from tqdm import tqdm
import re

# ========== CONFIG ==========
BASE                = Path(base + "socialmapper_outputs")
CROPS_DIR           = BASE / "egocentric_crops"          # id_<uid>/frame_XXXXXX.png (already generated)
SEQUENCE_RAW        = "task1/test/mouse071_task1_annotator1"  # CalMS21 key for the video you’re visualizing
PERSPS              = [0, 1]                             # 0: A->B (perspective 0), 1: B->A (perspective 1)

# Map perspective -> crop ID on disk (change if your IDs differ)
PERSPECTIVE_TO_UID  = {0: 0, 1: 1}

# Grid (put perspective 0 in cell 0, perspective 1 in cell 1, others blank)
GRID_ROWS, GRID_COLS = 1, 2
GRID_POS_TO_PERSP    = [0, 1]   # length = GRID_ROWS * GRID_COLS; use None for blanks

# Clustering choice on SOCIAL features
CLUSTER_MODE        = "ward"     # "ward" or "kmeans"
WARD_N_CLUSTERS     = 12         # Ward cut level
PLOT_FPS            = 10
MAX_PAGES_PER_CLUSTER = 10_000
BG_COLOR            = (0, 0, 0)  # BGR
RANDOM_STATE        = 42
# ===========================

rng = np.random.default_rng(RANDOM_STATE)
GRID_SIZE = GRID_ROWS * GRID_COLS


# --- Infer tile size from any present crop among mapped IDs ---
tile_h = tile_w = None
for p in GRID_POS_TO_PERSP:
    if p is None:
        continue
    uid = PERSPECTIVE_TO_UID.get(p, None)
    if uid is None:
        continue
    any_crop = next((q for q in (CROPS_DIR / f"id_{uid}").glob("frame_*.png")), None)
    if any_crop is not None:
        probe = cv2.imread(str(any_crop), cv2.IMREAD_COLOR)
        if probe is not None:
            tile_h, tile_w = probe.shape[:2]
            break
if tile_h is None:
    raise FileNotFoundError("Could not infer crop size: no crops found for the mapped IDs.")

# --- Build social assigner (Ward or k-means) on SOCIAL feature space ---
safe_seq = to_safe_seq(SEQUENCE_RAW)

if CLUSTER_MODE.lower() == "ward":
    linkage_path   = BASE / "global_hierarchical_linkage.joblib"
    templates_path = BASE / "global_templates_features.npz"
    scaler_pack    = BASE / "global_opentsne_embedding.joblib"
    if not (linkage_path.exists() and templates_path.exists() and scaler_pack.exists()):
        raise FileNotFoundError(
            "Missing social Ward artifacts. Expected:\n"
            f"  - {linkage_path.name}\n  - {templates_path.name}\n  - {scaler_pack.name}"
        )
    Z = joblib.load(linkage_path)["linkage_matrix"]
    templates = np.load(templates_path)["templates"]     # standardized social templates, shape (T, F_social)
    labels_templates = fcluster(Z, WARD_N_CLUSTERS, criterion="maxclust")
    uniq = np.unique(labels_templates)
    centroids = np.vstack([templates[labels_templates == c].mean(axis=0) for c in uniq])
    assigner = NearestNeighbors(n_neighbors=1).fit(centroids)
    scaler   = joblib.load(scaler_pack)["scaler"]
    mode_str = f"ward_social_nclusters={len(uniq)}"

elif CLUSTER_MODE.lower() == "kmeans":
    # Expect a social kmeans assigner saved similar to individual:
    # {"scaler": <StandardScaler>, "kmeans": <KMeans>, "nn": <NearestNeighbors on centers>}
    pack_path = BASE / "global_kmeans_assigner_social.joblib"
    if not pack_path.exists():
        raise FileNotFoundError(
            f"Missing {pack_path.name}. Train/save a k-means assigner on SOCIAL templates first."
        )
    pack     = joblib.load(pack_path)
    scaler   = pack["scaler"]
    assigner = pack["nn"]
    # Derive K from kmeans centers
    K_centers = getattr(pack.get("kmeans", None), "cluster_centers_", None)
    mode_str = f"kmeans_social_nclusters={K_centers.shape[0] if K_centers is not None else 'UNK'}"

else:
    raise ValueError("CLUSTER_MODE must be 'ward' or 'kmeans'.")

# --- Load social wavelet features for this sequence & assign clusters per perspective ---


labels_per_persp = {}
n_frames_per_persp = {}
for persp in PERSPS:
    X = util.load_social_wavelet_frames(BASE, safe_seq, persp)
    Xs = scaler.transform(X)
    _, idx = assigner.kneighbors(Xs)
    labs = idx.ravel().astype(int)     # 0..K-1
    labels_per_persp[persp] = labs
    n_frames_per_persp[persp] = labs.shape[0]

# --- Determine K from assigned labels ---
K = max(int(labs.max()) for labs in labels_per_persp.values()) + 1

# --- Build per-cluster frame lists per perspective restricted to frames with crops on disk ---
pairs_per_cluster_per_persp = {c: {p: [] for p in PERSPS} for c in range(K)}

for persp in PERSPS:
    uid = PERSPECTIVE_TO_UID.get(persp, None)
    if uid is None:
        continue
    labs = labels_per_persp[persp]
    crop_dir = CROPS_DIR / f"id_{uid}"

    # discover available crops for this sequence: your crop filenames are just frame indices.
    # We assume frames correspond 1:1 to sequence frames.
    frame_idxs = []
    for q in crop_dir.glob("frame_*.png"):
        try:
            frame_idxs.append(int(q.stem.split("_")[-1]))
        except ValueError:
            pass
    if not frame_idxs:
        continue
    frame_idxs = np.array(sorted(frame_idxs), dtype=int)
    frame_idxs = frame_idxs[frame_idxs < len(labs)]  # guard

    # assign frames to clusters
    for fidx in frame_idxs:
        c = int(labs[fidx])
        pairs_per_cluster_per_persp[c][persp].append(fidx)

# --- Write one video per cluster; fixed grid; each cell shows its mapped perspective/ID; blanks if missing ---
out_dir = BASE / "composites_social" / f"{mode_str}__{safe_seq}"
out_dir.mkdir(parents=True, exist_ok=True)
fourcc = cv2.VideoWriter_fourcc(*"mp4v")
frame_size = (GRID_COLS * tile_w, GRID_ROWS * tile_h)

for c in range(K):
    # how many composite frames to write? as many as the longest per-perspective list
    max_len = 0
    for p in PERSPS:
        lst = pairs_per_cluster_per_persp[c].get(p, [])
        if lst is not None:
            max_len = max(max_len, len(lst))
    if max_len == 0:
        print(f"[cluster {c}] no frames; skipping.")
        continue

    video_path = out_dir / f"cluster_{c:02d}.mp4"
    writer = cv2.VideoWriter(str(video_path), fourcc, PLOT_FPS, frame_size)
    print(f"[cluster {c}] -> {video_path}")

    # per-perspective pointers
    ptr = {p: 0 for p in PERSPS}
    pages_written = 0

    while pages_written < MAX_PAGES_PER_CLUSTER:
        # stop when all perspectives exhausted
        if all(ptr[p] >= len(pairs_per_cluster_per_persp[c].get(p, [])) for p in PERSPS):
            break

        canvas = np.full((GRID_ROWS * tile_h, GRID_COLS * tile_w, 3), BG_COLOR, dtype=np.uint8)

        for cell_idx, p in enumerate(GRID_POS_TO_PERSP[:GRID_SIZE]):
            r = cell_idx // GRID_COLS
            cc = cell_idx % GRID_COLS
            y0 = r * tile_h
            x0 = cc * tile_w

            if p is None:
                # blank cell
                continue

            uid = PERSPECTIVE_TO_UID.get(p, None)
            if uid is None:
                continue

            flist = pairs_per_cluster_per_persp[c].get(p, [])
            if ptr[p] < len(flist):
                fidx = flist[ptr[p]]
                ptr[p] += 1
                img_path = CROPS_DIR / f"id_{uid}" / f"frame_{int(fidx):06d}.png"
                img = cv2.imread(str(img_path), cv2.IMREAD_COLOR)
                if img is None or img.shape[:2] != (tile_h, tile_w):
                    img = cv2.resize(img, (tile_w, tile_h), interpolation=cv2.INTER_AREA) if img is not None \
                          else np.full((tile_h, tile_w, 3), BG_COLOR, dtype=np.uint8)
                canvas[y0:y0+tile_h, x0:x0+tile_w] = img
            else:
                # this perspective ran out -> leave blank
                pass

        writer.write(canvas)
        pages_written += 1

    writer.release()
    print(f"[cluster {c}] wrote {pages_written} composite frames.")

print("All social per-cluster composites complete.")

# %% [markdown]
# # Compare predicted labels to CALMS labels

# %%
# Build global labels_df to compare CalMS21 GT vs predicted cluster labels (all sequences)
# Result columns: ['sequence', 'mode', 'id_or_persp', 'frame', 'gt_label', 'pred_label', 'cluster_mode']

import numpy as np
import pandas as pd
from pathlib import Path
from sklearn.neighbors import NearestNeighbors
from scipy.cluster.hierarchy import fcluster
import joblib
import re
import warnings

# ================== CONFIG ==================
BASE            = Path(base + "socialmapper_outputs")

# Choose stream to compare
MODE            = "pair"         # "pair" (recommended for CalMS21 Task1) or "individual"

# CalMS21 ground-truth source (.npy produced by the converter)
CALMS21_NPY     = Path(os.path.join(datadir,"calms21_task1_test.npy"))
# If you want to include train too, run this twice and concat, or point to a merged npy.

# Clustering choice
CLUSTER_MODE    = "kmeans"         # "kmeans" or "ward"
WARD_N_CLUSTERS = 6             # only used for 'ward'

# Pair-mode: which perspectives to evaluate (0: A->B, 1: B->A)
USE_PERSPS      = [0, 1]

# Individual-mode (needs df with all sequences). We'll try to auto-detect the sequence column.
# You can force it by setting:
SEQ_COL_OVERRIDE = None  # e.g., "seq" or "sequence"
# ============================================



# ---------- 1) Load all GT sequences ----------
GT_MAP = load_all_gt(CALMS21_NPY)  # dict seq_key -> (T,)
if not GT_MAP:
    raise RuntimeError(f"No GT sequences found in {CALMS21_NPY}")

# ---------- 2) Decide assigner ----------
mode = CLUSTER_MODE.lower()
if mode == "kmeans":
    scaler, nn_assigner = util.load_kmeans_assigner(BASE)
    cluster_mode_str = "kmeans"
elif mode == "ward":
    scaler, nn_assigner = util.load_ward_assigner(BASE,WARD_N_CLUSTERS)
    cluster_mode_str = f"ward_cut={WARD_N_CLUSTERS}"
else:
    raise ValueError("CLUSTER_MODE must be 'kmeans' or 'ward'.")

rows = []

if MODE.lower() == "pair":
    # Iterate all GT sequences; try to load both perspectives and compare
    for seq_key, gt in GT_MAP.items():
        T = gt.shape[0]
        safe_seq = to_safe_seq(seq_key)

        # skip sequences without wavelets
        have_any = False
        for p in USE_PERSPS:
            feat_path = util.find_pair_wavelet(safe_seq, p)
            if feat_path is None:
                continue
            have_any = True

            X = load_pair_features(safe_seq, p)   # (n_frames, n_feats)
            n = min(X.shape[0], T)
            Xs = scaler.transform(X[:n])
            _, idx = nn_assigner.kneighbors(Xs)
            pred = idx.ravel().astype(int)
            if pred.min() == 1:
                pred = pred - 1

            rows.append(pd.DataFrame({
                "sequence": seq_key,      # raw CalMS21 key with slashes
                "mode": "pair",
                "id_or_persp": p,         # store perspective here
                "frame": np.arange(n, dtype=int),
                "gt_label": gt[:n],
                "pred_label": pred[:n],
                "cluster_mode": cluster_mode_str,
            }))

        if not have_any:
            warnings.warn(f"[pair] No wavelet files found for sequence '{seq_key}' (safe='{safe_seq}') — skipping.")

elif MODE.lower() == "individual":
    # Needs df with all sequences. We will:
    #  - detect the sequence column name (SEQ_COL_OVERRIDE, or try 'seq', then 'sequence')
    #  - for each sequence, find present IDs from df, then align frames
    if 'df' not in globals():
        raise RuntimeError("MODE='individual' requires a global `df` with all sequences (columns include id, frame, and a sequence key).")

    # detect sequence column
    cand_seq_cols = [c for c in [SEQ_COL_OVERRIDE, "seq", "sequence"] if c is not None]
    seq_col = next((c for c in cand_seq_cols if c in df.columns), None)
    if seq_col is None:
        # try to sniff any column that looks like path-like CalMS21 key
        for c in df.columns:
            if df[c].astype(str).str.contains(r"task\d+/.+/.+").any():
                seq_col = c
                break
    if seq_col is None:
        raise ValueError("Could not find a sequence column in df. Set SEQ_COL_OVERRIDE to your column name (e.g., 'seq').")

    if not {"id", "frame"}.issubset(df.columns):
        raise ValueError("df must contain columns 'id' and 'frame' for individual mode.")

    # Load (or derive) per-id predictions on the fly
    # (We assign directly from features + nn_assigner to keep consistent with Ward re-cuts.)
    # Cache per-id predictions to avoid recompute
    pred_cache = {}

    for seq_key, gt in GT_MAP.items():
        sub = df[df[seq_col] == seq_key]
        if sub.empty:
            # No rows in df for this sequence, skip
            continue

        T = gt.shape[0]

        # IDs present in this sequence (from df)
        ids_in_seq = sorted(sub["id"].unique().tolist())

        for uid in ids_in_seq:
            # compute / load predictions for this id once
            if uid not in pred_cache:
                X = load_individual_features(BASE, uid)     # (n_frames_total, 250)
                Xs = scaler.transform(X)
                _, idx = nn_assigner.kneighbors(Xs)
                pred = idx.ravel().astype(int)
                if pred.min() == 1:
                    pred = pred - 1
                pred_cache[uid] = pred

            pred = pred_cache[uid]

            # frames *in this sequence* (assumes df['frame'] are 0..T-1 within each sequence)
            frames_seq = np.asarray(sorted(sub.loc[sub["id"] == uid, "frame"].unique()), dtype=int)

            # Align: keep frames < len(pred) and < T
            mask = (frames_seq >= 0) & (frames_seq < len(pred)) & (frames_seq < T)
            frames_use = frames_seq[mask]
            if frames_use.size == 0:
                continue

            rows.append(pd.DataFrame({
                "sequence": seq_key,
                "mode": "individual",
                "id_or_persp": uid,
                "frame": frames_use,
                "gt_label": gt[frames_use],
                "pred_label": pred[frames_use],
                "cluster_mode": cluster_mode_str,
            }))
else:
    raise ValueError("MODE must be 'pair' or 'individual'.")

labels_df = pd.concat(rows, ignore_index=True) if rows else pd.DataFrame(
    columns=["sequence","mode","id_or_persp","frame","gt_label","pred_label","cluster_mode"]
)

print(labels_df.head())
print("\nCounts by mode, cluster_mode:")
print(labels_df.groupby(["mode","cluster_mode"]).size())
print(f"\nlabels_df shape: {labels_df.shape}  | sequences covered: {labels_df['sequence'].nunique()}")

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# ===================== CONFIG / FILTERS =====================
# Optional: focus on a subset (e.g., one perspective or one uid)
SUBSET_MODE = None          # e.g. "pair" or "individual" or None
SUBSET_ID_OR_PERSP = None   # e.g. 0, 1, or None
# ===========================================================

# --- Behavior name map (CalMS21 task1) ---
behavior_map = {
    0: "attack",
    1: "investigation",
    2: "mount",
    3: "other_interaction",
}
# if labels outside the map exist, keep their integer as string
labels_df["gt_behavior"] = labels_df["gt_label"].map(behavior_map).fillna(labels_df["gt_label"].astype(str))

# --- Optional subsetting ---
dfp = labels_df.copy()
if SUBSET_MODE is not None:
    dfp = dfp[dfp["mode"] == SUBSET_MODE]
if SUBSET_ID_OR_PERSP is not None:
    dfp = dfp[dfp["id_or_persp"] == SUBSET_ID_OR_PERSP]

# Guard: nothing to plot?
if dfp.empty:
    raise ValueError("No rows after applying filters; adjust SUBSET_MODE / SUBSET_ID_OR_PERSP.")

cluster_mode_str = dfp["cluster_mode"].iloc[0]

# Fix category order for GT rows (consistent display)
gt_order = [behavior_map[k] for k in sorted(behavior_map.keys()) if behavior_map[k] in dfp["gt_behavior"].unique()]
# add any unexpected/extra classes at the end
extras = [g for g in dfp["gt_behavior"].unique() if g not in gt_order]
gt_order = gt_order + sorted(extras)

# ---------- 1) GT → Predicted clusters (rows normalize to 1) ----------
cont = pd.crosstab(
    index=pd.Categorical(dfp["gt_behavior"], categories=gt_order, ordered=True),
    columns=dfp["pred_label"],
    normalize="index"
).fillna(0.0)

# Sort predicted cluster columns by the GT row they align to most (visual clarity)
peak_rows = cont.values.argmax(axis=0)              # for each cluster (col), which GT row is max
order_cols = np.lexsort((cont.values.max(axis=0), peak_rows))  # first by peak row, tie-break by height
cont = cont.iloc[:, order_cols]

plt.figure(figsize=(max(8, 0.5 * cont.shape[1]), 5))
sns.heatmap(cont, cmap="mako", vmin=0, vmax=1, cbar_kws={"label": "Proportion within GT label"},
           annot=True, fmt=".2f")
plt.title(f"GT → Predicted cluster correspondence  ({cluster_mode_str})")
plt.xlabel("Predicted cluster")
plt.ylabel("Ground-truth behavior")
plt.tight_layout()
plt.show()

# ---------- 2) Predicted clusters → GT (rows normalize to 1) ----------
cont_pred = pd.crosstab(
    index=dfp["pred_label"],
    columns=pd.Categorical(dfp["gt_behavior"], categories=gt_order, ordered=True),
    normalize="index"
).fillna(0.0)

plt.figure(figsize=(8, max(4, 0.35 * cont_pred.shape[0])))
sns.heatmap(cont_pred, cmap="mako", vmin=0, vmax=1, cbar_kws={"label": "Proportion within predicted cluster"},
           annot=True, fmt=".2f")
plt.title(f"Predicted cluster → GT correspondence  ({cluster_mode_str})")
plt.xlabel("Ground-truth behavior")
plt.ylabel("Predicted cluster")
plt.tight_layout()
plt.show()

# ---------- (Optional) show support (counts) for context ----------
gt_counts = dfp.groupby("gt_behavior").size().reindex(gt_order, fill_value=0)
pred_counts = dfp["pred_label"].value_counts().sort_index()

print("\nGT support per class:")
print(gt_counts.to_string())
print("\nPredicted cluster sizes:")
print(pred_counts.to_string())

# %% [markdown]
# ## compare with tSNE plot

# %%
# --- Global t-SNE: side-by-side scatter ---
# Left: predicted clusters (k-means OR Ward re-cut on social features)
# Right: ground-truth labels (CalMS21 Task1), duplicated across perspectives
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from sklearn.neighbors import NearestNeighbors
from scipy.cluster.hierarchy import fcluster
import joblib, re

# ========= CONFIG =========
BASE = Path(base + "socialmapper_outputs")

# clustering shown on LEFT
CLUSTER_MODE     = "ward"      # "kmeans" or "ward"
WARD_N_CLUSTERS  = 4          # used only for 'ward' cut (display)

# ground-truth sources (it will try these in order)
CALMS21_NPYS = [
    Path("/Volumes/JD-SSD/mice_data/calms21/data/calms21_task1_train.npy"),
    Path("/Volumes/JD-SSD/mice_data/calms21/data/calms21_task1_test.npy"),
]

PLOT_MAX = 300_000            # optional downsample for speed
RANDOM_STATE = 42
# ==========================

rng = np.random.default_rng(RANDOM_STATE)
sns.set_style("white")


# ---- 1) Load global t-SNE coordinates for all (seq, persp) ----
coord_files = sorted(BASE.glob("global_tsne_coords_seq=*persp=*.npz"))
if not coord_files:
    raise FileNotFoundError("Expected global_tsne_coords_seq=*persp=*.npz files.")

pat = re.compile(r"global_tsne_coords_seq=(.*)_persp=(\d+)\.npz")

Y_blocks   = []  # list of arrays, one per (seq,persp)
pred_blocks = [] # to align later
gt_blocks   = [] # to align later
keys       = []  # (safe_seq, persp)
n_total = 0

# ---- 2) Prepare assigner for predictions (LEFT panel) ----
mode = CLUSTER_MODE.lower()
if mode == "kmeans":
    # Expect social kmeans assigner pack: {"scaler","kmeans","nn"}
    pack = joblib.load(BASE / "global_kmeans_assigner.joblib")
    scaler   = pack["scaler"]
    assigner = pack["nn"]
    left_title_suffix = "global k-means (social)"
elif mode == "ward":
    Z          = joblib.load(BASE / "global_hierarchical_linkage.joblib")["linkage_matrix"]
    templates  = np.load(BASE / "global_templates_features.npz")["templates"]
    labels_tmp = fcluster(Z, WARD_N_CLUSTERS, criterion="maxclust")
    uniq       = np.unique(labels_tmp)
    centroids  = np.vstack([templates[labels_tmp == c].mean(axis=0) for c in uniq])
    assigner   = NearestNeighbors(n_neighbors=1).fit(centroids)
    scaler     = joblib.load(BASE / "global_opentsne_embedding.joblib")["scaler"]
    left_title_suffix = f"global Ward (social), cut={WARD_N_CLUSTERS}"
else:
    raise ValueError("CLUSTER_MODE must be 'kmeans' or 'ward'.")

# ---- 3) Walk files in order; for each (seq,persp) get Y, predicted labels, and GT ----
for f in coord_files:
    m = pat.match(f.name)
    if not m:
        continue
    safe_seq, persp = m.group(1), int(m.group(2))
    Y = np.load(f)["Y"]                     # (n_frames_key, 2)
    n = Y.shape[0]

    # predicted labels from social features
    feat_npz = util.find_pair_wavelet(BASE, safe_seq, persp)
    X = np.load(feat_npz)["spectrogram"].T  # (n_frames, F_social)
    n_use = min(n, X.shape[0])
    Xs = scaler.transform(X[:n_use])
    _, idx = assigner.kneighbors(Xs)
    pred = idx.ravel().astype(int)          # align to n_use

    # ground truth labels for this sequence (same per perspective)
    raw_seq = to_raw_seq(safe_seq)
    gt_seq = load_gt_labels_from_many(CALMS21_NPYS, raw_seq)
    gt = gt_seq[:n_use].astype(int)

    # align Y too
    Y_blocks.append(Y[:n_use])
    pred_blocks.append(pred)
    gt_blocks.append(gt)
    keys.append((safe_seq, persp))
    n_total += n_use

# ---- 4) Concatenate and (optionally) downsample consistently ----
Y_all   = np.vstack(Y_blocks)          # (N_all, 2)
pred_all= np.concatenate(pred_blocks)  # (N_all,)
gt_all  = np.concatenate(gt_blocks)    # (N_all,)

if Y_all.shape[0] > PLOT_MAX:
    sel = rng.choice(Y_all.shape[0], size=PLOT_MAX, replace=False)
    Y_plot    = Y_all[sel]
    P_plot    = pred_all[sel]
    GT_plot   = gt_all[sel]
else:
    Y_plot, P_plot, GT_plot = Y_all, pred_all, gt_all

# ---- 5) Draw side-by-side using your helper for categorical coloring ----
fig, axes = plt.subplots(1, 2, figsize=(14, 6), constrained_layout=True)

# Left: predictions
_ = viz.plot_tsne_withcolors(
    ax=axes[0],
    tsne_result=Y_plot,
    quantity=P_plot.astype(int),
    title=f"Predicted clusters — {left_title_suffix}",
    colortype="categorical",
    qmin=0.01, qmax=0.99,
    alphaval=0.25,
    s=2,
    coloroffset=0,
    cmapname="cool",
    setxylimquantile=False
)
axes[0].set_xlabel("t-SNE 1"); axes[0].set_ylabel("t-SNE 2")

# Right: ground truth labels (categorical)
_ = viz.plot_tsne_withcolors(
    ax=axes[1],
    tsne_result=Y_plot,
    quantity=GT_plot.astype(int),
    title="Ground-truth labels (CalMS21 Task1)",
    colortype="categorical",
    qmin=0.01, qmax=0.99,
    alphaval=0.25,
    s=2,
    coloroffset=0,
    cmapname="cool",
    setxylimquantile=False
)
axes[1].set_xlabel("t-SNE 1"); axes[1].set_ylabel("t-SNE 2")

plt.show()

# %% [markdown]
# ### plot on PCA axes

# %%
# --- Global PCA(2D): side-by-side scatter ---
# Left: predicted clusters (k-means OR Ward re-cut on social features)
# Right: CalMS21 GT labels
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path
from sklearn.decomposition import PCA
from sklearn.neighbors import NearestNeighbors
from scipy.cluster.hierarchy import fcluster
import joblib, re

# ========= CONFIG =========
BASE = Path(base + "socialmapper_outputs")

CLUSTER_MODE     = "ward"   # "kmeans" or "ward"
WARD_N_CLUSTERS  = 4        # only used for 'ward' cut
PLOT_MAX         = 300_000  # optional downsample cap
RANDOM_STATE     = 42

CALMS21_NPYS = [
    Path("/Volumes/JD-SSD/mice_data/calms21/data/calms21_task1_train.npy"),
    Path("/Volumes/JD-SSD/mice_data/calms21/data/calms21_task1_test.npy"),
]
# ==========================

rng = np.random.default_rng(RANDOM_STATE)
sns.set_style("white")





# ---- 0) Load standardized templates and fit PCA(2D) on them ----
templates = np.load(BASE / "global_templates_features.npz")["templates"]  # standardized (T, F)
pca2 = PCA(n_components=2, random_state=RANDOM_STATE).fit(templates)

# We'll standardize frames with the same global scaler used in your pipeline
scaler = joblib.load(BASE / "global_opentsne_embedding.joblib")["scaler"]

# ---- 1) Prepare assigner for predictions (LEFT panel) ----
mode = CLUSTER_MODE.lower()
if mode == "kmeans":
    pack     = joblib.load(BASE / "global_kmeans_assigner.joblib")  # {"scaler","kmeans","nn"}
    assigner = pack["nn"]
    left_title_suffix = "global k-means (social)"
elif mode == "ward":
    Z          = joblib.load(BASE / "global_hierarchical_linkage.joblib")["linkage_matrix"]
    labels_tmp = fcluster(Z, WARD_N_CLUSTERS, criterion="maxclust")
    uniq       = np.unique(labels_tmp)
    centroids  = np.vstack([templates[labels_tmp == c].mean(axis=0) for c in uniq])
    assigner   = NearestNeighbors(n_neighbors=1).fit(centroids)
    left_title_suffix = f"global Ward (social), cut={WARD_N_CLUSTERS}"
else:
    raise ValueError("CLUSTER_MODE must be 'kmeans' or 'ward'.")

# ---- 2) Gather PCA2 coords, predictions, and GT for all (seq, persp) ----
coord_files = sorted(BASE.glob("global_tsne_coords_seq=*persp=*.npz"))  # just to enumerate keys/lengths
if not coord_files:
    raise FileNotFoundError("Expected global_tsne_coords_seq=*persp=*.npz files.")
pat = re.compile(r"global_tsne_coords_seq=(.*)_persp=(\d+)\.npz")

PC_blocks, pred_blocks, gt_blocks = [], [], []
for f in coord_files:
    m = pat.match(f.name)
    if not m:
        continue
    safe_seq, persp = m.group(1), int(m.group(2))

    # For length reference
    n = np.load(f)["Y"].shape[0]

    # Load social features for prediction + PCA projection
    feat_npz = find_pair_wavelet(BASE, safe_seq, persp)
    X = np.load(feat_npz)["spectrogram"].T  # (n_frames, F_social)
    n_use = min(n, X.shape[0])
    Xs = scaler.transform(X[:n_use])

    # PCA(2D) coordinates (same PCA fitted on standardized templates)
    PC2 = pca2.transform(Xs)                # (n_use, 2)

    # Predicted labels
    _, idx = assigner.kneighbors(Xs)
    pred = idx.ravel().astype(int)

    # Ground-truth labels
    raw_seq = to_raw_seq(safe_seq)
    gt_seq  = load_gt_labels_from_many(CALMS21_NPYS, raw_seq)
    gt      = gt_seq[:n_use].astype(int)

    PC_blocks.append(PC2)
    pred_blocks.append(pred)
    gt_blocks.append(gt)

# ---- 3) Concatenate and downsample consistently ----
PC_all   = np.vstack(PC_blocks)          # (N_all, 2)
pred_all = np.concatenate(pred_blocks)   # (N_all,)
gt_all   = np.concatenate(gt_blocks)     # (N_all,)

if PC_all.shape[0] > PLOT_MAX:
    sel = rng.choice(PC_all.shape[0], size=PLOT_MAX, replace=False)
    PC_plot   = PC_all[sel]
    P_plot    = pred_all[sel]
    GT_plot   = gt_all[sel]
else:
    PC_plot, P_plot, GT_plot = PC_all, pred_all, gt_all

# ---- 4) Plot side-by-side (PCA1 vs PCA2) ----
fig, axes = plt.subplots(1, 2, figsize=(14, 6), constrained_layout=True)

# LEFT: predictions
_ = viz.plot_tsne_withcolors(
    ax=axes[0],
    tsne_result=PC_plot,     # any 2D coords are fine for this helper
    quantity=P_plot.astype(int),
    title=f"PCA(2D) — Predicted clusters — {left_title_suffix}",
    colortype='categorical',
    qmin=0.01, qmax=0.99,
    alphaval=0.25,
    s=2,
    coloroffset=0,
    cmapname='cool',
    setxylimquantile=False
)
axes[0].set_xlabel("PC1"); axes[0].set_ylabel("PC2")

# RIGHT: ground truth
_ = viz.plot_tsne_withcolors(
    ax=axes[1],
    tsne_result=PC_plot,
    quantity=GT_plot.astype(int),
    title="PCA(2D) — Ground-truth labels (CalMS21 Task1)",
    colortype='categorical',
    qmin=0.01, qmax=0.99,
    alphaval=0.25,
    s=2,
    coloroffset=0,
    cmapname='cool',
    setxylimquantile=False
)
axes[1].set_xlabel("PC1"); axes[1].set_ylabel("PC2")

plt.show()

# %% [markdown]
# # Fit classifier model on embedding

# %% [markdown]
# ## Load dataset

# %% [markdown]
# ### config and load

# %%
# === Config ===
HALF = 60
SKIP = 5
ADD_POOL = True
POOL_STATS = ("mean",)
SIGMA_STACK = 30
SIGMA_POOL  = 30
use_temporal_stack = True
N_JOBS = 10

# ===================== CONFIG =====================
BASE = Path(base + "socialmapper_outputs")
CALMS21_NPYS = [
    Path(os.path.join(datadir,"calms21_task1_train.npy")),
    Path(os.path.join(datadir,"calms21_task1_test.npy")),
]

# temporal settings
FPS = 30.0
WIN_SEC = 0.5               # sliding window width (s) for stats
WIN = max(3, int(round(WIN_SEC * FPS)))  # frames, center=True

# imbalance settings
USE_UNDERSAMPLE = True
UNDER_SAMPLER_RATIO = 3.0   # keep majority ≈ ratio * minority in training
USE_SMOTE = False           # set True to also apply SMOTE after undersampling

# RF settings (SIMBA-style)
RF_PARAMS = dict(
    n_estimators=2000,
    criterion="entropy",
    max_features="sqrt",
    min_samples_leaf=1,
    n_jobs=-1,
    random_state=42,
)

# split settings
# TEST_SIZE = 0.20
RANDOM_STATE = 42

# model output dir
OUT_DIR = BASE / "rf_social_models_task1"
OUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
# ============================================================
# Task 1 loader that respects the official train/test split
# ============================================================


task1_train_path, task1_test_path = CALMS21_NPYS
task1_train_dict = calms._flatten_split_dict(calms._load_task1_split(task1_train_path))
task1_test_dict  = calms._flatten_split_dict(calms._load_task1_split(task1_test_path))

train_keys = set(task1_train_dict.keys())
test_keys  = set(task1_test_dict.keys())

# -------------------------------
# 1) Enumerate STRICT pair wavelets (seq,persp)
# -------------------------------
PAIR_FILES = sorted(BASE.glob("wavelet_social_seq=*task1*persp=*.npz"))
if not PAIR_FILES:
    raise FileNotFoundError("No pair wavelet files found (wavelet_social_seq=*persp=*.npz).")

PAIR_PAT = re.compile(r"wavelet_social_seq=(.*)_persp=(\d+)\.npz")

index = []
for p_pair in PAIR_FILES:
    m = PAIR_PAT.match(p_pair.name)
    if not m:
        continue
    safe_seq, persp = m.group(1), int(m.group(2))
    # require ego counterpart to exist
    p_ego = BASE / f"wavelet_ego_seq={safe_seq}_persp={persp}.npz"
    if p_ego.exists():
        index.append((safe_seq, persp))
index = sorted(set(index))
if not index:
    raise RuntimeError("No (seq,persp) pairs where both pair+ego wavelets exist.")

print(f"[INFO] Found {len(index)} (seq,persp) with strict pair+ego.")
# Out:
# [INFO] Found 178 (seq,persp) with strict pair+ego.

# %%
# -------------------------------
# 3) Parallel load into train/test buckets based on split
# -------------------------------
blocks = Parallel(n_jobs=N_JOBS, prefer="processes")(
    delayed(calms._process_one_block_task1)(BASE, task1_train_dict, task1_test_dict, train_keys, test_keys, 
                safe_seq, persp, HALF, SKIP, ADD_POOL, POOL_STATS, SIGMA_STACK, SIGMA_POOL, use_temporal_stack
                                           ) for (safe_seq, persp) in tqdm(index, desc="Task1: load+stack by official split")
)
blocks = [b for b in blocks if b is not None]
if not blocks:
    raise RuntimeError("No usable Task-1 blocks produced.")

train_X_list, train_y_list, train_g_list = [], [], []
test_X_list,  test_y_list,  test_g_list  = [], [], []

for split, Xb, yb, gb in blocks:
    if split == "train":
        train_X_list.append(np.ascontiguousarray(Xb, dtype=np.float32))
        train_y_list.append(np.asarray(yb, dtype=np.int32))
        train_g_list.append(np.asarray(gb, dtype=object))
    else:
        test_X_list.append(np.ascontiguousarray(Xb, dtype=np.float32))
        test_y_list.append(np.asarray(yb, dtype=np.int32))
        test_g_list.append(np.asarray(gb, dtype=object))

if not train_X_list or not test_X_list:
    raise RuntimeError("Empty train or test buckets after official-split partitioning.")

# -------------------------------
# 4) Preallocate / stack (parallel memcopies)
# -------------------------------

print("Stacking train/test arrays in parallel...")
D = int(train_X_list[0].shape[1])

train_sizes, train_offsets = calms._sizes_and_offsets(train_X_list)
test_sizes,  test_offsets  = calms._sizes_and_offsets(test_X_list)

train_total = int(train_sizes.sum())
test_total  = int(test_sizes.sum())

X_train_raw = np.empty((train_total, D), dtype=np.float32)
y_train_mc  = np.empty((train_total,),   dtype=np.int32)
X_test_raw  = np.empty((test_total,  D), dtype=np.float32)
y_test_mc   = np.empty((test_total,),    dtype=np.int32)

t0 = perf_counter()
calms._parallel_copy(X_train_raw, y_train_mc, train_X_list, train_y_list, train_offsets)
calms._parallel_copy(X_test_raw,  y_test_mc,  test_X_list,  test_y_list,  test_offsets)
t1 = perf_counter()
print(f"Parallel stack done in {t1 - t0:.2f}s "
      f"(train={train_total:,}×{D}, test={test_total:,}×{D})")

# Free lists early
del train_X_list, train_y_list, test_X_list, test_y_list

# -------------------------------
# 5) Fit scaler on TRAIN ONLY, transform both
# -------------------------------



CHUNK = 500_000
bounds = list(calms._chunk_bounds(X_train_raw.shape[0], CHUNK))

with ThreadPoolExecutor(max_workers=os.cpu_count() or 4) as ex:
    parts = list(ex.map(lambda ab: calms._sum_and_sumsq(X_train_raw, *ab), bounds))

n_total     = int(sum(p[0] for p in parts))
sum_total   = np.sum([p[1] for p in parts], axis=0, dtype=np.float64)
sumsq_total = np.sum([p[2] for p in parts], axis=0, dtype=np.float64)

mean  = sum_total / n_total
var   = (sumsq_total / n_total) - mean**2
var[var < 0] = 0.0
scale = np.sqrt(var, out=np.empty_like(var))
scale[scale == 0] = 1.0

scaler_global = StandardScaler(copy=True, with_mean=True, with_std=True)
scaler_global.mean_ = mean
scaler_global.var_ = var
scaler_global.scale_ = scale
scaler_global.n_samples_seen_ = np.array([n_total], dtype=np.int64)

# Transform
X_train = (X_train_raw - mean.astype(np.float32)) / scale.astype(np.float32)
X_test  = (X_test_raw  - mean.astype(np.float32)) / scale.astype(np.float32)

# Group keys (sequence ids) in same order as y
groups_train = np.concatenate(train_g_list)
groups_test  = np.concatenate(test_g_list)
groups_all   = np.concatenate([groups_train, groups_test])

# free raw arrays
del X_train_raw, X_test_raw

print("Data ready:",
      f"\n  X_train: {X_train.shape}, y_train_mc: {y_train_mc.shape}",
      f"\n  X_test:  {X_test.shape},  y_test_mc:  {y_test_mc.shape}")
# Out:
# Task1: load+stack by official split:  28%|██████████████▌                                     | 50/178 [00:53<02:20,  1.10s/it]
# KeyboardInterrupt

# %%
print("Training set:", X_train.shape, "Testing set:", X_test.shape)
print("Feature dimension:", X_train.shape[1])
print("Unique train groups:", len(np.unique(groups_train)))
print("Unique test groups:", len(np.unique(groups_test)))
print("Class counts (train):", np.bincount(y_train_mc))
print("Class counts (test):", np.bincount(y_test_mc))

# %% [markdown]
# ### export preprocessed

# %%
# ===== Export dataset bundle for fast re-use =====
import json, joblib
from pathlib import Path
import numpy as np

OUT_BUNDLE = Path(base + "socialmapper_outputs") / "bundles" / "task1_social_tstack"
# OUT_BUNDLE = Path('/home/jdavidson/calms21/task1_social_tstack')
OUT_BUNDLE.mkdir(parents=True, exist_ok=True)

# Save arrays in .npy for fastest reload
np.save(OUT_BUNDLE / "X_train.npy", X_train)
np.save(OUT_BUNDLE / "y_train.npy", y_train_mc)
np.save(OUT_BUNDLE / "X_test.npy",  X_test)
np.save(OUT_BUNDLE / "y_test.npy",  y_test_mc)

# Save sequence-group info (useful for grouped CV or analysis)
np.save(OUT_BUNDLE / "train_groups.npy", groups_train)
np.save(OUT_BUNDLE / "test_groups.npy",  groups_test)

# Save scaler (so new models use *exact* same normalization)
joblib.dump(scaler_global, OUT_BUNDLE / "scaler_global.joblib")

# Save metadata about how features were constructed
meta = {
    "feature_type": "social_wavelet_temporal_stack",
    "base_feats": 150,                 # per-frame base feature count; adjust if not 150
    "half": int(HALF),
    "skip": int(SKIP),
    "time_steps": len(np.arange(-HALF, HALF+1, SKIP)),
    "add_pool": bool(ADD_POOL),
    "pool_stats": list(POOL_STATS) if isinstance(POOL_STATS, (list, tuple)) else [POOL_STATS],
    "has_pool": bool(X_train.shape[1] > 150 * len(np.arange(-HALF, HALF+1, SKIP))),
    "sigma_stack": float(SIGMA_STACK),
    "sigma_pool": float(SIGMA_POOL),
    "classes": [0, 1, 2, 3],           # CalMS21 Task-1 order (you can trim if you trained subset)
    "behavior_map": {                  # update if you use a different mapping
        0: "attack",
        1: "investigation",
        2: "mount",
        3: "other",
    },
    "fps": float(FPS),
    "random_state": int(RANDOM_STATE),
    "notes": "Arrays are already standardized with scaler_global. Shapes: X_* = (N, D).",
}
with open(OUT_BUNDLE / "meta.json", "w") as f:
    json.dump(meta, f, indent=2)

print(f"Bundle saved to: {OUT_BUNDLE.resolve()}")

# %% [markdown]
# ### Load preprocessed data for reuse

# %%
# ---------- Load preprocessed dataset bundle ----------
from pathlib import Path
import numpy as np
import joblib, json

# Path to the bundle directory you saved earlier
BUNDLE_DIR = Path(base + "socialmapper_outputs") / "bundles" / "task1_social_tstack"

# === Load arrays (memory-mapped, so it’s super fast and RAM-efficient) ===
X_train = np.load(BUNDLE_DIR / "X_train.npy", mmap_mode="r")
y_train_mc = np.load(BUNDLE_DIR / "y_train.npy", mmap_mode="r")
X_test = np.load(BUNDLE_DIR / "X_test.npy", mmap_mode="r")
y_test_mc = np.load(BUNDLE_DIR / "y_test.npy", mmap_mode="r")

# Optional but useful: sequence grouping info
groups_train = np.load(BUNDLE_DIR / "train_groups.npy", allow_pickle=True)
groups_test  = np.load(BUNDLE_DIR / "test_groups.npy", allow_pickle=True)

# === Load the fitted scaler ===
scaler_global = joblib.load(BUNDLE_DIR / "scaler_global.joblib")

# === Load metadata about the temporal window / features ===
with open(BUNDLE_DIR / "meta.json", "r") as f:
    meta = json.load(f)

# For convenience
HALF         = meta["half"]
SKIP         = meta["skip"]
POOL_STATS   = tuple(meta["pool_stats"])
SIGMA_STACK  = meta["sigma_stack"]
SIGMA_POOL   = meta["sigma_pool"]
ADD_POOL     = meta["add_pool"]

print("Loaded dataset bundle:")
print(f"  X_train: {X_train.shape}, y_train: {y_train_mc.shape}")
print(f"  X_test:  {X_test.shape}, y_test:  {y_test_mc.shape}")
print(f"  HALF={HALF}, SKIP={SKIP}, POOL_STATS={POOL_STATS}, ADD_POOL={ADD_POOL}")
# Out:
# Loaded dataset bundle:
#   X_train: (1004276, 2070), y_train: (1004276,)
#   X_test:  (521174, 2070), y_test:  (521174,)
#   HALF=40, SKIP=4, POOL_STATS=('mean', 'std'), ADD_POOL=True

# %% [markdown]
# ## Train

# %% [markdown]
# ### Train: random forest

# %%
# # ---------- 3) Train one-vs-rest RF (binary per behavior) ----------
# classes = np.unique(y_all)
# models = {}
# reports = {}

# print(f"\nTraining per-behavior RFs (behaviors: {list(classes)})")
# for beh in classes:
#     y_train_bin = (y_train_mc == beh).astype(int)
#     y_test_bin  = (y_test_mc  == beh).astype(int)

#     # handle imbalance on TRAIN
#     Xt, yt = mod.undersample_then_smote(X_train, y_train_bin, USE_UNDERSAMPLE, UNDER_SAMPLER_RATIO, USE_SMOTE)

#     clf = RandomForestClassifier(**RF_PARAMS)
#     clf.fit(Xt, yt)

#     # evaluate
#     y_pred_bin = clf.predict(X_test)
#     y_prob_bin = clf.predict_proba(X_test)[:, 1]

#     rep = classification_report(
#         y_test_bin, y_pred_bin, target_names=["not_"+str(beh), str(beh)], output_dict=True, zero_division=0
#     )
#     cm  = confusion_matrix(y_test_bin, y_pred_bin)

#     models[int(beh)] = dict(model=clf)
#     reports[int(beh)] = dict(report=rep, confusion_matrix=cm)

#     print(f"\nBehavior {beh} — test report")
#     print(classification_report(y_test_bin, y_pred_bin, target_names=["neg","pos"], zero_division=0))
#     print("Confusion matrix:\n", cm)

# # ---------- 4) Save artifacts ----------
# joblib.dump(
#     {
#         "rf_params": RF_PARAMS,
#         "models": {k: v["model"] for k, v in models.items()},
#         "scaler": scaler_global,
#         "win_frames": WIN,
#         "fps": FPS,
#         "use_undersample": USE_UNDERSAMPLE,
#         "under_sampler_ratio": UNDER_SAMPLER_RATIO,
#         "use_smote": USE_SMOTE,
#         "classes": classes,
#         "train_groups": groups_all[train_idx],
#         "test_groups": groups_all[test_idx],
#     },
#     OUT_DIR / "rf_social_task1_models.joblib"
# )

# # optional: save reports
# joblib.dump(reports, OUT_DIR / "rf_social_task1_reports.joblib")

# print(f"\nSaved models and reports to: {OUT_DIR.resolve()}")
# print("Done.")

# %% [markdown]
# ### Train:  XGB

# %%
# === GPU XGBoost per-behavior classifiers (drop-in replacement for the RF loop & save) ===
from xgboost import XGBClassifier
from xgboost.callback import EarlyStopping
import joblib
import json

# %%
XGB_PARAMS = mod.XGB_PARAMS_0


callbacks=[EarlyStopping(rounds=200, save_best=True, maximize=True, metric_name="aucpr")]

    
models = {}
reports = {}
classes = [0,1,2] #np.unique(y_all)

print(f"\nTraining per-behavior XGB (GPU) classifiers (behaviors: {list(classes)})")
for beh in classes:
    y_train_bin = (y_train_mc == beh).astype(int)
    y_test_bin  = (y_test_mc  == beh).astype(int)

    # Optional: handle imbalance on TRAIN (same helper as before)
    Xt, yt = mod.undersample_then_smote(X_train, y_train_bin, USE_UNDERSAMPLE, UNDER_SAMPLER_RATIO, USE_SMOTE)

    # scale_pos_weight from ORIGINAL train split (before any resampling)
    pos = max(1, int((y_train_bin == 1).sum()))
    neg = max(1, int((y_train_bin == 0).sum()))
    spw = float(neg) / float(pos)

    # If you performed undersampling/SMOTE, data is ~balanced -> override if desired
    if USE_UNDERSAMPLE or USE_SMOTE:
        spw = 1.0

    clf = XGBClassifier(**{**XGB_PARAMS, "scale_pos_weight": spw})

    # Fit with early stopping on the (unresampled) test split as validation (if use callbacks)
    clf.fit(
        Xt, yt,
        eval_set=[(X_test, y_test_bin)],
        verbose=False, 
        # callbacks=callbacks
    )

    # evaluate
    y_prob_bin = clf.predict_proba(X_test)[:, 1]
    y_pred_bin = (y_prob_bin >= 0.5).astype(int)

    rep = classification_report(
        y_test_bin, y_pred_bin, target_names=["not_"+str(beh), str(beh)], output_dict=True, zero_division=0
    )
    cm  = confusion_matrix(y_test_bin, y_pred_bin)
    ap  = average_precision_score(y_test_bin, y_prob_bin)

    models[int(beh)] = dict(model=clf, scale_pos_weight=spw, best_iteration=getattr(clf, "best_iteration_", None))
    reports[int(beh)] = dict(report=rep, confusion_matrix=cm, average_precision=ap)

    print(f"\nBehavior {beh} — test report")
    print(classification_report(y_test_bin, y_pred_bin, target_names=["neg","pos"], zero_division=0))
    print("Confusion matrix:\n", cm)
    print("Average Precision (AP):", f"{ap:.4f}")





# Build a lightweight, JSON-safe copy of reports
reports_json = {}
for beh, payload in reports.items():
    beh_key = str(int(beh))  # ensure string key
    rep = payload.get("report", {})
    cm  = payload.get("confusion_matrix", None)

    reports_json[beh_key] = {
        "report": mod.to_jsonable(rep),
        "confusion_matrix": mod.to_jsonable(cm) if cm is not None else None,
        # include AP if you stored it alongside (optional)
        "average_precision": mod.to_jsonable(payload.get("average_precision")) if "average_precision" in payload else None,
    }

# Also create a small CSV summary per behavior (precision/recall/f1 for pos class + AP if present)
summary_rows = []
for beh, payload in reports.items():
    beh_int = int(beh)
    rep = payload['report']
    # scikit's output_dict uses class labels '0'/'1' when target_names provided -> 'neg'/'pos'
    # we'll try both
    pos_key = str(beh_int)
    prec = rep.get(pos_key, {}).get("precision", np.nan)
    rec  = rep.get(pos_key, {}).get("recall", np.nan)
    f1   = rep.get(pos_key, {}).get("f1-score", np.nan)
    support = rep.get(pos_key, {}).get("support", np.nan)
    ap   = payload.get("average_precision", np.nan)
    summary_rows.append({
        "behavior": beh_int,
        "precision_pos": float(prec),
        "recall_pos": float(rec),
        "f1_pos": float(f1),
        "support_pos": int(support) if np.isfinite(support) else None,
        "average_precision": float(ap) if ap is not None and np.isfinite(ap) else None,
    })
summary_df = pd.DataFrame(summary_rows).sort_values("behavior")
summary_csv_path = OUT_DIR / "xgb_social_task1_summary.csv"
summary_df.to_csv(summary_csv_path, index=False)

# Save models + metadata with joblib (no JSON conversion needed)
joblib.dump(
    {
        "xgb_params": XGB_PARAMS,
        "models": {int(k): v["model"] for k, v in models.items()},
        "model_meta": {
            int(k): {
                "scale_pos_weight": v.get("scale_pos_weight"),
                "best_iteration": v.get("best_iteration"),
            }
            for k, v in models.items()
        },
        "scaler": scaler_global,
        "win_frames": WIN,
        "fps": FPS,
        "use_undersample": USE_UNDERSAMPLE,
        "under_sampler_ratio": UNDER_SAMPLER_RATIO,
        "use_smote": USE_SMOTE,
        "classes": [int(c) for c in classes],
        "train_groups": groups_train,  # fine in joblib
        "test_groups": groups_test,    # fine in joblib
    },
    OUT_DIR / "xgb_social_task1_models.joblib"
)

# Save full reports as joblib (rich Python), and a JSON for quick glance
joblib.dump(reports, OUT_DIR / "xgb_social_task1_reports.joblib")

with open(OUT_DIR / "xgb_social_task1_reports.json", "w") as f:
    json.dump(reports_json, f, indent=2)

print(f"\nSaved models and reports to: {OUT_DIR.resolve()}")
print(f"Summary CSV: {summary_csv_path}")
print("Done.")

# %%
summary_df
# Out:
#    behavior  precision_pos  recall_pos    f1_pos  support_pos  \
# 0         0       0.760798    0.657096  0.705155        25252
# 1         1       0.665404    0.646896  0.656019       122420
# 2         2       0.901153    0.756330  0.822414        63668
#
#    average_precision
# 0           0.764498
# 1           0.706892
# 2           0.908065

# %% [markdown]
# ### Train: Multi-label TCN

# %%
# ===============================================
# Multi-label TCN for CalMS21 Task 1 (single model)
# - Input: your stacked arrays X_train, y_train_mc, X_test, y_test_mc
# - Output: per-behavior logits (sigmoid) with per-behavior thresholds
# ===============================================
# -----------------------
# Config (edit as needed)
# -----------------------
SAVE_DIR = Path(base + "socialmapper_outputs") / "tcn_models"
SAVE_DIR.mkdir(parents=True, exist_ok=True)
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# Behaviors present in Task 1 labels (adjust if needed)
BEHAVIORS = [0, 1, 2, 3]
N_BEH = len(BEHAVIORS)

# -------------------------------------------------
# Build multi-label targets from your multiclass y
# (If Task 1 is truly mutually-exclusive, this still works;
#  it just makes at most one "1" per row.)
# -------------------------------------------------

Y_train = util.to_multi_hot(y_train_mc, BEHAVIORS)
Y_test  = util.to_multi_hot(y_test_mc,  BEHAVIORS)


time_steps = len(np.arange(-HALF, HALF + 1, SKIP))
feat_total = X_train.shape[1]
# infer BASE_FEATS from (temporal + pooled)
# pooled_dim is a multiple of BASE_FEATS

BASE_FEATS, pooled_dim, has_pool = util.infer_base_feats(feat_total, time_steps, ADD_POOL)
in_channels = BASE_FEATS * (1 + (pooled_dim // BASE_FEATS if has_pool else 0))
mod.BASE_FEATS = BASE_FEATS

# -------------------------------------------------
# Dataset that reshapes flattened stacks -> (C,T); targets are multi-hot (N_BEH,)
# -------------------------------------------------

# -----------------------
# Split a validation part from TRAIN (for early stop + thr tuning)
# -----------------------
idx = np.arange(X_train.shape[0])

VAL_FRAC = 0.1
gss = GroupShuffleSplit(n_splits=1, test_size=VAL_FRAC, random_state=mod.SEED)
idx_tr, idx_val = next(gss.split(X_train, Y_train, groups=groups_train))
train_ds_flat = mod.FlatStackedDataset(X_train[idx_tr], Y_train[idx_tr])
val_ds_flat   = mod.FlatStackedDataset(X_train[idx_val], Y_train[idx_val])
test_ds_flat  = mod.FlatStackedDataset(X_test,          Y_test)

collate_fn = mod.make_collate_fn(time_steps, BASE_FEATS, has_pool, pooled_dim)
on_cuda = torch.cuda.is_available()

train_loader = DataLoader(train_ds_flat, batch_size=mod.BATCH_SIZE, shuffle=True,
                          num_workers=0, pin_memory=on_cuda, drop_last=True,
                          collate_fn=collate_fn)
val_loader   = DataLoader(val_ds_flat,   batch_size=max(8192, mod.BATCH_SIZE), shuffle=False,
                          num_workers=0, pin_memory=on_cuda, collate_fn=collate_fn)
test_loader  = DataLoader(test_ds_flat,  batch_size=max(8192, mod.BATCH_SIZE), shuffle=False,
                          num_workers=0, pin_memory=on_cuda, collate_fn=collate_fn)
use_both_gpus = False
if use_both_gpus:
    model = mod.MultiLabelTCN(in_channels, N_BEH)
    model = nn.DataParallel(model).to(DEVICE)    # <-- use both GPUs    
else:
    model = mod.MultiLabelTCN(in_channels, N_BEH).to(DEVICE)
P_val, Y_val = mod.collect_probs(model,val_loader)
# -----------------------
# Weighted BCE (pos_weight per behavior from TRAIN set)
# pos_weight = (#neg / #pos) per behavior
# -----------------------
pos_counts = Y_train[idx_tr].sum(axis=0) + 1e-6
neg_counts = (Y_train[idx_tr].shape[0] - Y_train[idx_tr].sum(axis=0)) + 1e-6
pos_weight_vec = torch.tensor(neg_counts / pos_counts, dtype=torch.float32, device=DEVICE)
if use_both_gpus:
    pos_weight_vec = pos_weight_vec.to(DEVICE)  # move this to cuda

criterion = nn.BCEWithLogitsLoss(pos_weight=pos_weight_vec)
opt = torch.optim.AdamW(model.parameters(), lr=mod.LR, weight_decay=mod.WEIGHT_DECAY)
scaler = GradScaler(enabled=(DEVICE == "cuda"))

# Cosine over steps
total_steps = mod.EPOCHS * max(1, math.ceil(len(train_loader)))
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=total_steps)
# -----------------------
# Train / Val loops with early stopping on macro-F1 (val, threshold=0.5 during training)
# -----------------------

best_val_f1, pat_left = -1.0, mod.PATIENCE
best_path = SAVE_DIR / "tcn_task1_multilabel_best.pt"

print('Defined DataLoader')

# %%
print(f"Training multi-label TCN on {DEVICE} | in_ch={in_channels}, T={time_steps}, behaviors={BEHAVIORS}")
for epoch in range(1, mod.EPOCHS + 1):
    tr_loss, tr_f1, _, _ = mod.run_epoch(model, criterion, opt, scaler, scheduler, train_loader, train=True,  epoch_idx=epoch, phase="train")
    va_loss, va_f1, P_val, Y_val = mod.run_epoch(model, criterion, opt, scaler, scheduler, val_loader, train=False, epoch_idx=epoch, phase="val")
    print(f"Epoch {epoch:02d} | train loss {tr_loss:.4f} | train F1 {tr_f1:.4f} | val loss {va_loss:.4f} | val F1 {va_f1:.4f}")

    if va_f1 > best_val_f1 + 1e-4:
        best_val_f1 = va_f1
        pat_left = mod.PATIENCE
        torch.save({
            "model": model.state_dict(),
            "in_channels": in_channels,
            "time_steps": time_steps,
            "behaviors": BEHAVIORS,
            "base_feats": BASE_FEATS,
            "has_pool": has_pool,
            "pooled_dim": pooled_dim
        }, best_path)
    else:
        pat_left -= 1
        if pat_left <= 0:
            print("Early stopping.")
            break

# %%
# -----------------------
# Load best & tune thresholds on VAL (per behavior, maximize F1)
# -----------------------
ckpt = torch.load(best_path, map_location=DEVICE)
model.load_state_dict(ckpt["model"])
model.eval()

thr_val = mod.tune_thresholds(P_val, Y_val, N_BEH)
thr_map = {int(b): float(t) for b, t in zip(BEHAVIORS, thr_val)}
print("Per-behavior tuned thresholds (val):", thr_map)

# -----------------------
# Final evaluation on TEST with tuned thresholds
# -----------------------
P_test, Y_test_bin = mod.collect_probs(model,test_loader)
Yhat_test = (P_test >= thr_val[None, :]).astype(int)

# Per-behavior reports
per_class = {}
APs = []
for j, b in enumerate(BEHAVIORS):
    ap = average_precision_score(Y_test_bin[:, j], P_test[:, j])
    APs.append(ap)
    rep = classification_report(Y_test_bin[:, j], Yhat_test[:, j], target_names=[f"not_{b}", f"{b}"], output_dict=True, zero_division=0)
    per_class[int(b)] = {
        "threshold": float(thr_val[j]),
        "average_precision": float(ap),
        "report": rep
    }
    print(f"\n=== Behavior {b} (TEST) ===")
    print(classification_report(Y_test_bin[:, j], Yhat_test[:, j], target_names=[f"not_{b}", f"{b}"], digits=3, zero_division=0))
    print(f"AP: {ap:.4f}")

macro_f1 = f1_score(Y_test_bin, Yhat_test, average="macro", zero_division=0)
macro_ap = float(np.mean(APs))
print(f"\n=== Multi-label TEST summary ===\nMacro F1={macro_f1:.4f} | Macro AP={macro_ap:.4f}")

# Save artifacts
with open(SAVE_DIR / "tcn_task1_multilabel_thresholds.json", "w") as f:
    json.dump(thr_map, f, indent=2)

summary = {
    "macro_f1": float(macro_f1),
    "macro_ap": float(macro_ap),
    "per_behavior": per_class,
    "behaviors": BEHAVIORS,
    "in_channels": in_channels,
    "time_steps": time_steps,
    "base_feats": BASE_FEATS,
    "has_pool": has_pool,
    "pooled_dim": pooled_dim
}
with open(SAVE_DIR / "tcn_task1_multilabel_report.json", "w") as f:
    json.dump(summary, f, indent=2)

print(f"\nSaved best model: {best_path}")
print(f"Thresholds JSON: {SAVE_DIR/'tcn_task1_multilabel_thresholds.json'}")
print(f"Report JSON:     {SAVE_DIR/'tcn_task1_multilabel_report.json'}")

# %%
# Per-behavior reports
per_class = {}
APs = []
for j, b in enumerate(BEHAVIORS):
    ap = average_precision_score(Y_test_bin[:, j], P_test[:, j])
    APs.append(ap)
    rep = classification_report(Y_test_bin[:, j], Yhat_test[:, j], target_names=[f"not_{b}", f"{b}"], output_dict=True, zero_division=0)
    per_class[int(b)] = {
        "threshold": float(thr_val[j]),
        "average_precision": float(ap),
        "report": rep
    }
    print(f"\n=== Behavior {b} (TEST) ===")
    print(classification_report(Y_test_bin[:, j], Yhat_test[:, j], target_names=[f"not_{b}", f"{b}"], digits=3, zero_division=0))
    print(f"AP: {ap:.4f}")

macro_f1 = f1_score(Y_test_bin, Yhat_test, average="macro", zero_division=0)
macro_ap = float(np.mean(APs))
print(f"\n=== Multi-label TEST summary ===\nMacro F1={macro_f1:.4f} | Macro AP={macro_ap:.4f}")
# Out:
# === Behavior 0 (TEST) ===
#               precision    recall  f1-score   support
#
#        not_0      0.970     0.995     0.982    498582
#            0      0.795     0.392     0.525     25252
#
#     accuracy                          0.966    523834
#    macro avg      0.882     0.693     0.754    523834
# weighted avg      0.962     0.966     0.960    523834
#
# AP: 0.6402
#
# === Behavior 1 (TEST) ===
#               precision    recall  f1-score   support
#
#        not_1      0.891     0.858     0.874    401414
#            1      0.585     0.657     0.619    122420
#
#     accuracy                          0.811    523834
#    macro avg      0.738     0.757     0.747    523834
# weighted avg      0.820     0.811     0.815    523834
#
# AP: 0.6072
#
# === Behavior 2 (TEST) ===
#               precision    recall  f1-score   support
#
#        not_2      0.956     0.985     0.970    460166
#            2      0.864     0.670     0.755     63668
#
#     accuracy                          0.947    523834
#    macro avg      0.910     0.828     0.863    523834
# weighted avg      0.945     0.947     0.944    523834
#
# AP: 0.7988
#
# === Behavior 3 (TEST) ===
#               precision    recall  f1-score   support
#
#        not_3      0.823     0.776     0.799    211340
#            3      0.854     0.887     0.870    312494
#
#     accuracy                          0.842    523834
#    macro avg      0.839     0.831     0.835    523834
# weighted avg      0.842     0.842     0.841    523834
#
# AP: 0.9209
#
# === Multi-label TEST summary ===
# Macro F1=0.6923 | Macro AP=0.7418

# %% [markdown]
# ### Train:  TCN classifier per-behavior

# %%
# ===============================================
# TCN classifier for CalMS21 Task 1 (feature-flexible)
# Compatible with extended features: pair+ego wavelets, arbitrary HALF/SKIP, pooled stats
# Requires: X_train, y_train_mc, X_test, y_test_mc already built; optional 'meta' dict
# ===============================================
import os, time, math, json
from pathlib import Path
import numpy as np
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.cuda.amp import autocast, GradScaler
from sklearn.metrics import classification_report, confusion_matrix

# -----------------------
# Config
# -----------------------
SAVE_DIR = Path(base + "socialmapper_outputs") / "tcn_models"
SAVE_DIR.mkdir(parents=True, exist_ok=True)

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
N_GPUS = torch.cuda.device_count() if DEVICE == "cuda" else 0

# -------------------------------------------------
# Infer stack geometry — prefer meta if available
# -------------------------------------------------
# Expect (optionally) a dict called 'meta' from your bundling step.
# meta keys that help: base_feats, time_steps, add_pool, pool_stats, has_pool
_meta = None
try:
    _meta = meta  # if you kept it around from your bundler
except NameError:
    _meta = None

feat_total = int(X_train.shape[1])

# (1) time_steps
if _meta is not None and "time_steps" in _meta:
    time_steps = int(_meta["time_steps"])
else:
    # derive from HALF / SKIP you used during temporal_stack_features
    time_steps = len(np.arange(-HALF, HALF + 1, SKIP))

# (2) pooled stats config
if _meta is not None:
    meta_add_pool   = bool(_meta.get("add_pool", ADD_POOL))
    meta_pool_stats = tuple(_meta.get("pool_stats", POOL_STATS if ADD_POOL else ()))
    meta_has_pool   = bool(_meta.get("has_pool", meta_add_pool and len(meta_pool_stats) > 0))
else:
    meta_add_pool   = ADD_POOL
    meta_pool_stats = tuple(POOL_STATS if ADD_POOL else ())
    meta_has_pool   = ADD_POOL and (len(meta_pool_stats) > 0)

# (3) base_feats (per-frame features BEFORE stacking; includes pair+ego if concatenated)
if _meta is not None and "base_feats" in _meta:
    BASE_FEATS = int(_meta["base_feats"])
else:
    # infer from total feature dimension and time/pool layout
    # feat_total = BASE_FEATS * time_steps + BASE_FEATS * n_pool_stats
    n_pool_stats = len(meta_pool_stats) if meta_has_pool else 0
    denom = (time_steps + n_pool_stats)
    if denom <= 0 or (feat_total % denom) != 0:
        # fallback heuristic: try to split assuming pooled block aligns to BASE_FEATS
        inferred = (feat_total - 0) / max(1, time_steps)  # assume no pool first
        if float(inferred).is_integer():
            BASE_FEATS = int(inferred)
        else:
            raise ValueError(
                f"Could not infer BASE_FEATS from X_train.shape[1]={feat_total}, "
                f"time_steps={time_steps}, n_pool_stats={n_pool_stats}."
            )
    else:
        BASE_FEATS = feat_total // denom

# recompute pooled_dim / flags with the resolved BASE_FEATS
n_pool_stats = len(meta_pool_stats) if meta_has_pool else 0
temporal_flat_dim = BASE_FEATS * time_steps
pooled_dim = BASE_FEATS * n_pool_stats
has_pool = pooled_dim > 0
assert temporal_flat_dim + pooled_dim == feat_total, \
    f"Shape mismatch: temporal({temporal_flat_dim}) + pooled({pooled_dim}) != feat_total({feat_total})"

# -------------------------------------------------
# Dataset: reshape flattened stacks -> (C,T)
# -------------------------------------------------

num_classes = int(np.max(y_train_mc)) + 1
train_ds = mod.StackedTCNDataset(X_train, y_train_mc, time_steps, has_pool, pooled_dim)
val_ds   = mod.StackedTCNDataset(X_test,  y_test_mc, time_steps, has_pool, pooled_dim)

# A few safe worker threads; increase if I/O bound and RAM allows
num_workers = 8
train_loader = DataLoader(train_ds, batch_size=mod.BATCH_SIZE, shuffle=True,
                          num_workers=num_workers, pin_memory=(DEVICE=="cuda"))
val_loader   = DataLoader(val_ds,   batch_size=mod.BATCH_SIZE, shuffle=False,
                          num_workers=num_workers, pin_memory=(DEVICE=="cuda"))

# -------------------------------------------------
# TCN blocks
# -------------------------------------------------


# Model (with optional DataParallel)
in_channels = BASE_FEATS * (1 + n_pool_stats)
_base_model = mod.SimpleTCN(in_ch=in_channels, n_classes=num_classes).to(DEVICE)
model = nn.DataParallel(_base_model) if (DEVICE == "cuda" and N_GPUS > 1) else _base_model

# Optimizer / Loss / Scheduler
opt = torch.optim.AdamW(model.parameters(), lr=mod.LR, weight_decay=mod.WEIGHT_DECAY)
scaler = GradScaler(enabled=(DEVICE == "cuda"))
criterion = nn.CrossEntropyLoss()

# Use cosine per-epoch schedule (step each batch)
total_steps = mod.EPOCHS * max(1, len(train_loader))
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=total_steps)

best_val_f1 = -1.0
pat_left = mod.PATIENCE
best_path = SAVE_DIR / "tcn_task1_best.pt"


# -----------------------
# Training loop
# -----------------------
gpu_note = f"on {N_GPUS} GPUs" if (DEVICE == 'cuda' and N_GPUS > 1) else f"on {DEVICE}"
print(f"Training TCN {gpu_note} | classes={num_classes} | in_ch={in_channels}, T={time_steps}, "
      f"F={BASE_FEATS}, pooled_stats={n_pool_stats}")

best_payload = None
for epoch in range(1, mod.EPOCHS + 1):
    tr_loss, tr_f1, _, _ = mod.run_epoch(model, train_loader, train=True,  epoch_idx=epoch, phase="train")
    va_loss, va_f1, y_true, y_pred = mod.run_epoch(model, val_loader,   train=False, epoch_idx=epoch, phase="val")

    print(f"Epoch {epoch:02d} | train loss {tr_loss:.4f} | train F1 {tr_f1:.4f} "
          f"| val loss {va_loss:.4f} | val F1 {va_f1:.4f}")

    if va_f1 > best_val_f1 + 1e-4:
        best_val_f1 = va_f1
        pat_left = mod.PATIENCE
        best_payload = {
            "model": mod._state_dict_for_save(model),
            "in_channels": in_channels,
            "time_steps": time_steps,
            "num_classes": num_classes,
            "base_feats": BASE_FEATS,
            "has_pool": has_pool,
            "pooled_dim": pooled_dim,
            "n_pool_stats": n_pool_stats,
            "pool_stats": meta_pool_stats,
            "add_pool": meta_add_pool,
        }
        torch.save(best_payload, best_path)
    else:
        pat_left -= 1
        if pat_left <= 0:
            print("Early stopping.")
            break

# -----------------------
# Final evaluation
# -----------------------
ckpt = torch.load(best_path, map_location=DEVICE)
models._load_state_dict(model, ckpt["model"])

model.eval()
all_logits, all_y = [], []
with torch.no_grad():
    for xb, yb in val_loader:
        xb = xb.to(DEVICE, non_blocking=True)
        with amp.autocast(device_type="cuda", enabled=(DEVICE == "cuda")):
            lg = model(xb)
        all_logits.append(lg.cpu())
        all_y.append(yb)

logits = torch.cat(all_logits, dim=0).numpy()
y_true = torch.cat(all_y, dim=0).numpy()
y_pred = logits.argmax(axis=1)

print("\n=== Test set report (TCN) ===")
print(classification_report(y_true, y_pred, digits=3, zero_division=0))
print("Confusion matrix:\n", confusion_matrix(y_true, y_pred))

rep = classification_report(y_true, y_pred, digits=4, output_dict=True, zero_division=0)
with open(SAVE_DIR / "tcn_task1_report.json", "w") as f:
    json.dump(rep, f, indent=2)

print(f"\nSaved best model to: {best_path}")
print(f"Report JSON: {SAVE_DIR/'tcn_task1_report.json'}")
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[44], line 93
#      91 pooled_dim = BASE_FEATS * n_pool_stats
#      92 has_pool = pooled_dim > 0
# ---> 93 assert temporal_flat_dim + pooled_dim == feat_total, \
#      94     f"Shape mismatch: temporal({temporal_flat_dim}) + pooled({pooled_dim}) != feat_total({feat_total})"
#      96 # -------------------------------------------------
#      97 # Dataset: reshape flattened stacks -> (C,T)
#      98 # -------------------------------------------------
#     100 num_classes = int(np.max(y_train_mc)) + 1
#
# AssertionError: Shape mismatch: temporal(3150) + pooled(0) != feat_total(2070)

# %%
print("\n=== Test set report (TCN) ===")
print(classification_report(y_true, y_pred, digits=3, zero_division=0))
print("Confusion matrix:\n", confusion_matrix(y_true, y_pred))

# %%
summary_df

# %%
summary_df

# %%
# --- Compare to paper: mean F1 excluding 'other' ---
df_nonother = summary_df[summary_df["behavior"] <= 2]
mean_f1 = df_nonother["f1_pos"].mean()
print(f"Mean F1 (excluding 'other'): {mean_f1:.3f}")

# %%
# --- Evaluate saved RF models (SIMBA-style) ---
import joblib
import numpy as np
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import seaborn as sns

# =============== CONFIG ===============
BASE = Path(base + "socialmapper_outputs")
OUT_DIR = BASE / "rf_social_models_task1"
# ======================================

reports = joblib.load(OUT_DIR / "rf_social_task1_reports.joblib")
bundle  = joblib.load(OUT_DIR / "rf_social_task1_mod.joblib")

# Extract F1-scores for quick overview
summary = []
for beh, rep in reports.items():
    rep_dict = rep["report"]
    summary.append({
        "behavior": beh,
        "precision": rep_dict[str(beh)]["precision"],
        "recall": rep_dict[str(beh)]["recall"],
        "f1_score": rep_dict[str(beh)]["f1-score"],
        "support": rep_dict[str(beh)]["support"],
    })

df = pd.DataFrame(summary).sort_values("f1_score", ascending=False)
print("\n=== Behavior-wise performance summary ===")
print(df.to_string(index=False, float_format="%.3f"))

# Optional: visualize
sns.set_style("whitegrid")
plt.figure(figsize=(8, 5))
sns.barplot(data=df, y="behavior", x="f1_score", color="steelblue")
plt.xlabel("F1-score (test set)")
plt.ylabel("Behavior")
plt.title("Random Forest performance (CalMS21 Task1 behaviors)")
plt.tight_layout()
plt.show()

# Show a confusion matrix for one example behavior (e.g. top F1)
best_beh = df.iloc[0]["behavior"]
cm = np.array(reports[int(best_beh)]["confusion_matrix"])
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues",
            xticklabels=["Pred 0", "Pred 1"], yticklabels=["True 0", "True 1"])
plt.title(f"Confusion matrix for behavior {best_beh}")
plt.show()
